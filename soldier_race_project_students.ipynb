# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %%
# If you are using Anaconda, you can create a new environment with use of Anaconda terminal and codes below:
# conda create --name soldier
# conda install -c conda-forge ipykernel scikit-learn "numpy<1.25" pandas shap matplotlib "seaborn==0.12.2" xgboost scikit-plot imbalanced-learn numba jinja2 ipywidgets

# %% [markdown]
# In this project, you must apply EDA processes for the development of predictive models. Handling outliers, domain knowledge and feature engineering will be challenges.
#
# Also, this project aims to improve your ability to implement algorithms for Multi-Class Classification. Thus, you will have the opportunity to implement many algorithms commonly used for Multi-Class Classification problems.
#
# Before diving into the project, please take a look at the determines and tasks.

# %% [markdown]
# # Determines

# %% [markdown]
# The 2012 US Army Anthropometric Survey (ANSUR II) was executed by the Natick Soldier Research, Development and Engineering Center (NSRDEC) from October 2010 to April 2012 and is comprised of personnel representing the total US Army force to include the US Army Active Duty, Reserves, and National Guard. In addition to the anthropometric and demographic data described below, the ANSUR II database also consists of 3D whole body, foot, and head scans of Soldier participants. These 3D data are not publicly available out of respect for the privacy of ANSUR II participants. The data from this survey are used for a wide range of equipment design, sizing, and tariffing applications within the military and has many potential commercial, industrial, and academic applications.
#
# The ANSUR II working databases contain 93 anthropometric measurements which were directly measured, and 15 demographic/administrative variables explained below. The ANSUR II Male working database contains a total sample of 4,082 subjects. The ANSUR II Female working database contains a total sample of 1,986 subjects.
#
#
# DATA DICT:
# https://data.world/datamil/ansur-ii-data-dictionary/workspace/file?filename=ANSUR+II+Databases+Overview.pdf
#
# ---
#
# To achieve high prediction success, you must understand the data well and develop different approaches that can affect the dependent variable.
#
# Firstly, try to understand the dataset column by column using pandas module. Do research within the scope of domain (body scales, and race characteristics) knowledge on the internet to get to know the data set in the fastest way.
#
# You will implement ***Logistic Regression, Support Vector Machine, XGBoost, Random Forest*** algorithms. Also, evaluate the success of your models with appropriate performance metrics.
#
# At the end of the project, choose the most successful model and try to enhance the scores with ***SMOTE*** make it ready to deploy. Furthermore, use ***SHAP*** to explain how the best model you choose works.

# %% [markdown]
# # Tasks

# %% [markdown]
# #### 1. Exploratory Data Analysis (EDA)
# - Import Libraries, Load Dataset, Exploring Data
#
#     *i. Import Libraries*
#
#     *ii. Ingest Data *
#
#     *iii. Explore Data*
#
#     *iv. Outlier Detection*
#
#     *v.  Drop unnecessary features*
#
# #### 2. Data Preprocessing
# - Scale (if needed)
# - Separete the data frame for evaluation purposes
#
# #### 3. Multi-class Classification
# - Import libraries
# - Implement SVM Classifer
# - Implement Decision Tree Classifier
# - Implement Random Forest Classifer
# - Implement XGBoost Classifer
# - Compare The Models
#
# #### 4. SMOTE
# - Apply Imbalance Learning Techniques
#
# #### 5. SHAP
# - Apply Feature selection with SHAP

# %% [markdown]
# # EDA
# - Drop unnecessary colums
# - Drop DODRace class if value count below 500 (we assume that our data model can't learn if it is below 500)

# %% [markdown]
# ## Import Libraries
# Besides Numpy and Pandas, you need to import the necessary modules for data visualization, data preprocessing, Model building and tuning.
#
# *Note: Check out the course materials.*

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams["figure.figsize"] = (10,6)
import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")
pd.set_option('display.float_format', lambda x: '%.3f' % x)
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 100)

# %% [markdown]
# ## Ingest Data from links below and make a dataframe
# - Soldiers Male : https://query.data.world/s/h3pbhckz5ck4rc7qmt2wlknlnn7esr
# - Soldiers Female : https://query.data.world/s/sq27zz4hawg32yfxksqwijxmpwmynq

# %%
data = pd.read_csv('ANSUR II FEMALE Public.csv')
df1 = data.copy()

# %%
df1.head()
# Out:
#    SubjectId  abdominalextensiondepthsitting  acromialheight  \
# 0      10037                             231            1282
# 1      10038                             194            1379
# 2      10042                             183            1369
# 3      10043                             261            1356
# 4      10051                             309            1303
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    301                 204          1180
# 1                    320                 207          1292
# 2                    329                 233          1271
# 3                    306                 214          1250
# 4                    308                 214          1210
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      222               177                373
# 1                      225               178                372
# 2                      237               196                397
# 3                      240               188                384
# 4                      217               182                378
#
#    bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  \
# 0                        315               263               466
# 1                        272               250               430
# 2                        300               276               450
# 3                        364               276               484
# 4                        320               336               525
#
#    bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  \
# 0                  65               338                        301
# 1                  64               294                        270
# 2                  69               309                        270
# 3                  68               340                        294
# 4                  67               300                        295
#
#    bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  \
# 0                 141                  1011           223            836
# 1                 126                   893           186            900
# 2                 128                   987           204            861
# 3                 144                  1012           253            897
# 4                 135                  1281           284            811
#
#    buttockkneelength  buttockpopliteallength  calfcircumference  \
# 0                587                     476                360
# 1                583                     483                350
# 2                583                     466                384
# 3                599                     471                372
# 4                607                     467                433
#
#    cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  \
# 0             1336           274                 922         245         1095
# 1             1440           261                 839         206         1234
# 2             1451           287                 874         223         1226
# 3             1430           269                1008         285         1170
# 4             1362           305                1089         290         1112
#
#    crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion  \
# 0           759                    557                             310
# 1           835                    549                             329
# 2           821                    643                             374
# 3           804                    640                             351
# 4           726                    686                             356
#
#    earbreadth  earlength  earprotrusion  elbowrestheight  eyeheightsitting  \
# 0          35         65             16              220               713
# 1          32         60             23              208               726
# 2          36         65             26              204               790
# 3          38         62             22              244               775
# 4          34         65             18              233               732
#
#    footbreadthhorizontal  footlength  forearmcenterofgriplength  \
# 0                     91         246                        316
# 1                     91         249                        341
# 2                    100         265                        343
# 3                     97         265                        331
# 4                     88         247                        339
#
#    forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  \
# 0                         265                    517                432
# 1                         247                    468                463
# 2                         262                    488                469
# 3                         309                    529                455
# 4                         260                    596                447
#
#    functionalleglength  handbreadth  handcircumference  handlength  \
# 0                 1028           75                182         184
# 1                 1117           78                187         189
# 2                 1060           84                198         195
# 3                 1069           80                192         186
# 4                 1039           78                183         187
#
#    headbreadth  headcircumference  headlength  heelanklecircumference  \
# 0          141                548         191                     314
# 1          138                535         180                     307
# 2          146                588         207                     331
# 3          153                593         206                     332
# 4          140                522         181                     308
#
#    heelbreadth  hipbreadth  hipbreadthsitting  iliocristaleheight  \
# 0           69         345                388                 966
# 1           60         315                335                1048
# 2           70         356                399                1043
# 3           68         337                402                1029
# 4           63         448                499                 964
#
#    interpupillarybreadth  interscyei  interscyeii  kneeheightmidpatella  \
# 0                    645         363          399                   435
# 1                    595         340          375                   483
# 2                    655         345          399                   470
# 3                    655         392          435                   469
# 4                    635         428          435                   440
#
#    kneeheightsitting  lateralfemoralepicondyleheight  lateralmalleolusheight  \
# 0                496                             447                      55
# 1                532                             492                      69
# 2                530                             469                      64
# 3                520                             478                      67
# 4                491                             441                      63
#
#    lowerthighcircumference  mentonsellionlength  neckcircumference  \
# 0                      404                  118                335
# 1                      334                  115                302
# 2                      401                  135                325
# 3                      402                  118                357
# 4                      479                  114                340
#
#    neckcircumferencebase  overheadfingertipreachsitting  palmlength  \
# 0                    368                           1268         113
# 1                    345                           1389         110
# 2                    369                           1414         122
# 3                    386                           1329         115
# 4                    358                           1350         116
#
#    poplitealheight  radialestylionlength  shouldercircumference  \
# 0              362                   235                   1062
# 1              426                   259                   1014
# 2              398                   258                   1049
# 3              394                   250                   1121
# 4              345                   242                   1151
#
#    shoulderelbowlength  shoulderlength  sittingheight  sleevelengthspinewrist  \
# 0                  327             148            803                     809
# 1                  346             142            835                     810
# 2                  362             164            904                     855
# 3                  333             157            875                     815
# 4                  329             156            824                     810
#
#    sleeveoutseam  span  stature  suprasternaleheight  tenthribheight  \
# 0            513  1647     1560                 1280            1013
# 1            575  1751     1665                 1372            1107
# 2            568  1779     1711                 1383            1089
# 3            536  1708     1660                 1358            1065
# 4            559  1702     1572                 1292            1030
#
#    thighcircumference  thighclearance  thumbtipreach  tibialheight  \
# 0                 622             174            736           430
# 1                 524             152            771           475
# 2                 577             164            814           458
# 3                 679             187            736           463
# 4                 766             197            766           429
#
#    tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  \
# 0               110                  844                           1488
# 1               125                  901                           1470
# 2               129                  882                           1542
# 3               125                  866                           1627
# 4               116                  800                           1698
#
#    waistbacklength  waistbreadth  waistcircumference  waistdepth  \
# 0              406           295                 850         217
# 1              422           254                 708         168
# 2              419           269                 727         159
# 3              451           302                 923         235
# 4              452           405                1163         300
#
#    waistfrontlengthsitting  waistheightomphalion  weightkg  \
# 0                      345                   942       657
# 1                      329                  1032       534
# 2                      367                  1035       663
# 3                      371                   999       782
# 4                      380                   911       886
#
#    wristcircumference  wristheight  Gender      Date Installation  \
# 0                 152          756  Female  5-Oct-10    Fort Hood
# 1                 155          815  Female  5-Oct-10    Fort Hood
# 2                 162          799  Female  5-Oct-10    Fort Hood
# 3                 173          818  Female  5-Oct-10    Fort Hood
# 4                 152          762  Female  5-Oct-10    Fort Hood
#
#       Component                  Branch PrimaryMOS SubjectsBirthLocation  \
# 0  Regular Army          Combat Support        92Y               Germany
# 1  Regular Army  Combat Service Support        25U            California
# 2  Regular Army  Combat Service Support        35D                 Texas
# 3  Regular Army  Combat Service Support        25U  District of Columbia
# 4  Regular Army             Combat Arms        42A                 Texas
#
#    SubjectNumericRace           Ethnicity  DODRace  Age  Heightin  Weightlbs  \
# 0                   2                 NaN        2   26        61        142
# 1                   3             Mexican        3   21        64        120
# 2                   1                 NaN        1   23        68        147
# 3                   8  Caribbean Islander        2   22        66        175
# 4                   1                 NaN        1   45        63        195
#
#   WritingPreference
# 0        Right hand
# 1        Right hand
# 2        Right hand
# 3        Right hand
# 4        Right hand

# %%
data1= pd.read_csv('ANSUR II MALE Public.csv', encoding='latin-1')
df2 = data1.copy()

# %%
df2.head()
# Out:
#    subjectid  abdominalextensiondepthsitting  acromialheight  \
# 0      10027                             266            1467
# 1      10032                             233            1395
# 2      10033                             287            1430
# 3      10092                             234            1347
# 4      10093                             250            1585
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    337                 222          1347
# 1                    326                 220          1293
# 2                    341                 230          1327
# 3                    310                 230          1239
# 4                    372                 247          1478
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      253               202                401
# 1                      245               193                394
# 2                      256               196                427
# 3                      262               199                401
# 4                      267               224                435
#
#    bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  \
# 0                        369               274               493
# 1                        338               257               479
# 2                        408               261               544
# 3                        359               262               518
# 4                        356               263               524
#
#    bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  \
# 0                  71               319                        291
# 1                  67               344                        320
# 2                  75               345                        330
# 3                  73               328                        309
# 4                  80               340                        310
#
#    bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  \
# 0                 142                   979           240            882
# 1                 135                   944           232            870
# 2                 135                  1054           258            901
# 3                 143                   991           242            821
# 4                 138                  1029           275           1080
#
#    buttockkneelength  buttockpopliteallength  calfcircumference  \
# 0                619                     509                373
# 1                584                     468                357
# 2                623                     506                412
# 3                560                     437                395
# 4                706                     567                425
#
#    cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  \
# 0             1535           291                1074         259         1292
# 1             1471           269                1021         253         1244
# 2             1501           288                1120         267         1288
# 3             1423           296                1114         262         1205
# 4             1684           304                1048         232         1452
#
#    crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion  \
# 0           877                    607                             351
# 1           851                    615                             376
# 2           854                    636                             359
# 3           769                    590                             341
# 4          1014                    682                             382
#
#    earbreadth  earlength  earprotrusion  elbowrestheight  eyeheightsitting  \
# 0          36         71             19              247               802
# 1          33         62             18              232               781
# 2          40         61             23              237               810
# 3          39         66             25              272               794
# 4          32         56             19              188               814
#
#    footbreadthhorizontal  footlength  forearmcenterofgriplength  \
# 0                    101         273                        349
# 1                     98         263                        348
# 2                    103         270                        355
# 3                    106         267                        352
# 4                    111         305                        399
#
#    forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  \
# 0                         299                    575                477
# 1                         289                    523                476
# 2                         357                    575                491
# 3                         318                    593                467
# 4                         324                    605                550
#
#    functionalleglength  handbreadth  handcircumference  handlength  \
# 0                 1136           90                214         193
# 1                 1096           86                203         195
# 2                 1115           93                220         203
# 3                 1034           91                217         194
# 4                 1279           94                222         218
#
#    headbreadth  headcircumference  headlength  heelanklecircumference  \
# 0          150                583         206                     326
# 1          146                568         201                     334
# 2          148                573         202                     356
# 3          158                576         199                     341
# 4          153                566         197                     374
#
#    heelbreadth  hipbreadth  hipbreadthsitting  iliocristaleheight  \
# 0           70         332                366                1071
# 1           72         312                356                1046
# 2           70         349                393                1053
# 3           68         338                367                 986
# 4           69         332                372                1251
#
#    interpupillarybreadth  interscyei  interscyeii  kneeheightmidpatella  \
# 0                    685         422          441                   502
# 1                    620         441          447                   490
# 2                    665         462          475                   496
# 3                    640         458          461                   460
# 4                    675         481          505                   612
#
#    kneeheightsitting  lateralfemoralepicondyleheight  lateralmalleolusheight  \
# 0                560                             500                      77
# 1                540                             488                      73
# 2                556                             482                      72
# 3                511                             452                      76
# 4                666                             585                      85
#
#    lowerthighcircumference  mentonsellionlength  neckcircumference  \
# 0                      391                  118                400
# 1                      371                  131                380
# 2                      409                  123                403
# 3                      393                  106                407
# 4                      458                  135                398
#
#    neckcircumferencebase  overheadfingertipreachsitting  palmlength  \
# 0                    436                           1447         113
# 1                    420                           1380         118
# 2                    434                           1447         121
# 3                    446                           1357         118
# 4                    430                           1572         132
#
#    poplitealheight  radialestylionlength  shouldercircumference  \
# 0              437                   273                   1151
# 1              417                   254                   1119
# 2              431                   268                   1276
# 3              393                   249                   1155
# 4              523                   302                   1231
#
#    shoulderelbowlength  shoulderlength  sittingheight  sleevelengthspinewrist  \
# 0                  368             145            928                     883
# 1                  353             141            884                     868
# 2                  367             167            917                     910
# 3                  330             148            903                     848
# 4                  400             180            919                     995
#
#    sleeveoutseam  span  stature  suprasternaleheight  tenthribheight  \
# 0            600  1782     1776                 1449            1092
# 1            564  1745     1702                 1387            1076
# 2            604  1867     1735                 1438            1105
# 3            550  1708     1655                 1346            1021
# 4            641  2035     1914                 1596            1292
#
#    thighcircumference  thighclearance  thumbtipreach  tibialheight  \
# 0                 610             164            786           491
# 1                 572             169            822           476
# 2                 685             198            807           477
# 3                 604             180            803           445
# 4                 672             194            962           584
#
#    tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  \
# 0               140                  919                           1700
# 1               120                  918                           1627
# 2               125                  918                           1678
# 3               127                  847                           1625
# 4               122                 1090                           1679
#
#    waistbacklength  waistbreadth  waistcircumference  waistdepth  \
# 0              501           329                 933         240
# 1              432           316                 870         225
# 2              472           329                 964         255
# 3              461           315                 857         205
# 4              467           303                 868         214
#
#    waistfrontlengthsitting  waistheightomphalion  weightkg  \
# 0                      440                  1054       815
# 1                      371                  1054       726
# 2                      411                  1041       929
# 3                      399                   968       794
# 4                      379                  1245       946
#
#    wristcircumference  wristheight Gender       Date Installation  \
# 0                 175          853   Male   4-Oct-10    Fort Hood
# 1                 167          815   Male   4-Oct-10    Fort Hood
# 2                 180          831   Male   4-Oct-10    Fort Hood
# 3                 176          793   Male  12-Oct-10    Fort Hood
# 4                 188          954   Male  12-Oct-10    Fort Hood
#
#       Component                  Branch PrimaryMOS SubjectsBirthLocation  \
# 0  Regular Army             Combat Arms        19D          North Dakota
# 1  Regular Army          Combat Support        68W              New York
# 2  Regular Army          Combat Support        68W              New York
# 3  Regular Army  Combat Service Support        88M             Wisconsin
# 4  Regular Army  Combat Service Support        92G        North Carolina
#
#    SubjectNumericRace Ethnicity  DODRace  Age  Heightin  Weightlbs  \
# 0                   1       NaN        1   41        71        180
# 1                   1       NaN        1   35        68        160
# 2                   2       NaN        2   42        68        205
# 3                   1       NaN        1   31        66        175
# 4                   2       NaN        2   21        77        213
#
#   WritingPreference
# 0        Right hand
# 1         Left hand
# 2         Left hand
# 3        Right hand
# 4        Right hand

# %% [markdown]
# ##

# %%
df = pd.concat([df1, df2], axis=1)

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4082 entries, 0 to 4081
# Data columns (total 216 columns):
#  #    Column                          Dtype
# ---   ------                          -----
#  0    SubjectId                       float64
#  1    abdominalextensiondepthsitting  float64
#  2    acromialheight                  float64
#  3    acromionradialelength           float64
#  4    anklecircumference              float64
#  5    axillaheight                    float64
#  6    balloffootcircumference         float64
#  7    balloffootlength                float64
#  8    biacromialbreadth               float64
#  9    bicepscircumferenceflexed       float64
#  10   bicristalbreadth                float64
#  11   bideltoidbreadth                float64
#  12   bimalleolarbreadth              float64
#  13   bitragionchinarc                float64
#  14   bitragionsubmandibulararc       float64
#  15   bizygomaticbreadth              float64
#  16   buttockcircumference            float64
#  17   buttockdepth                    float64
#  18   buttockheight                   float64
#  19   buttockkneelength               float64
#  20   buttockpopliteallength          float64
#  21   calfcircumference               float64
#  22   cervicaleheight                 float64
#  23   chestbreadth                    float64
#  24   chestcircumference              float64
#  25   chestdepth                      float64
#  26   chestheight                     float64
#  27   crotchheight                    float64
#  28   crotchlengthomphalion           float64
#  29   crotchlengthposterioromphalion  float64
#  30   earbreadth                      float64
#  31   earlength                       float64
#  32   earprotrusion                   float64
#  33   elbowrestheight                 float64
#  34   eyeheightsitting                float64
#  35   footbreadthhorizontal           float64
#  36   footlength                      float64
#  37   forearmcenterofgriplength       float64
#  38   forearmcircumferenceflexed      float64
#  39   forearmforearmbreadth           float64
#  40   forearmhandlength               float64
#  41   functionalleglength             float64
#  42   handbreadth                     float64
#  43   handcircumference               float64
#  44   handlength                      float64
#  45   headbreadth                     float64
#  46   headcircumference               float64
#  47   headlength                      float64
#  48   heelanklecircumference          float64
#  49   heelbreadth                     float64
#  50   hipbreadth                      float64
#  51   hipbreadthsitting               float64
#  52   iliocristaleheight              float64
#  53   interpupillarybreadth           float64
#  54   interscyei                      float64
#  55   interscyeii                     float64
#  56   kneeheightmidpatella            float64
#  57   kneeheightsitting               float64
#  58   lateralfemoralepicondyleheight  float64
#  59   lateralmalleolusheight          float64
#  60   lowerthighcircumference         float64
#  61   mentonsellionlength             float64
#  62   neckcircumference               float64
#  63   neckcircumferencebase           float64
#  64   overheadfingertipreachsitting   float64
#  65   palmlength                      float64
#  66   poplitealheight                 float64
#  67   radialestylionlength            float64
#  68   shouldercircumference           float64
#  69   shoulderelbowlength             float64
#  70   shoulderlength                  float64
#  71   sittingheight                   float64
#  72   sleevelengthspinewrist          float64
#  73   sleeveoutseam                   float64
#  74   span                            float64
#  75   stature                         float64
#  76   suprasternaleheight             float64
#  77   tenthribheight                  float64
#  78   thighcircumference              float64
#  79   thighclearance                  float64
#  80   thumbtipreach                   float64
#  81   tibialheight                    float64
#  82   tragiontopofhead                float64
#  83   trochanterionheight             float64
#  84   verticaltrunkcircumferenceusa   float64
#  85   waistbacklength                 float64
#  86   waistbreadth                    float64
#  87   waistcircumference              float64
#  88   waistdepth                      float64
#  89   waistfrontlengthsitting         float64
#  90   waistheightomphalion            float64
#  91   weightkg                        float64
#  92   wristcircumference              float64
#  93   wristheight                     float64
#  94   Gender                          object
#  95   Date                            object
#  96   Installation                    object
#  97   Component                       object
#  98   Branch                          object
#  99   PrimaryMOS                      object
#  100  SubjectsBirthLocation           object
#  101  SubjectNumericRace              float64
#  102  Ethnicity                       object
#  103  DODRace                         float64
#  104  Age                             float64
#  105  Heightin                        float64
#  106  Weightlbs                       float64
#  107  WritingPreference               object
#  108  subjectid                       int64
#  109  abdominalextensiondepthsitting  int64
#  110  acromialheight                  int64
#  111  acromionradialelength           int64
#  112  anklecircumference              int64
#  113  axillaheight                    int64
#  114  balloffootcircumference         int64
#  115  balloffootlength                int64
#  116  biacromialbreadth               int64
#  117  bicepscircumferenceflexed       int64
#  118  bicristalbreadth                int64
#  119  bideltoidbreadth                int64
#  120  bimalleolarbreadth              int64
#  121  bitragionchinarc                int64
#  122  bitragionsubmandibulararc       int64
#  123  bizygomaticbreadth              int64
#  124  buttockcircumference            int64
#  125  buttockdepth                    int64
#  126  buttockheight                   int64
#  127  buttockkneelength               int64
#  128  buttockpopliteallength          int64
#  129  calfcircumference               int64
#  130  cervicaleheight                 int64
#  131  chestbreadth                    int64
#  132  chestcircumference              int64
#  133  chestdepth                      int64
#  134  chestheight                     int64
#  135  crotchheight                    int64
#  136  crotchlengthomphalion           int64
#  137  crotchlengthposterioromphalion  int64
#  138  earbreadth                      int64
#  139  earlength                       int64
#  140  earprotrusion                   int64
#  141  elbowrestheight                 int64
#  142  eyeheightsitting                int64
#  143  footbreadthhorizontal           int64
#  144  footlength                      int64
#  145  forearmcenterofgriplength       int64
#  146  forearmcircumferenceflexed      int64
#  147  forearmforearmbreadth           int64
#  148  forearmhandlength               int64
#  149  functionalleglength             int64
#  150  handbreadth                     int64
#  151  handcircumference               int64
#  152  handlength                      int64
#  153  headbreadth                     int64
#  154  headcircumference               int64
#  155  headlength                      int64
#  156  heelanklecircumference          int64
#  157  heelbreadth                     int64
#  158  hipbreadth                      int64
#  159  hipbreadthsitting               int64
#  160  iliocristaleheight              int64
#  161  interpupillarybreadth           int64
#  162  interscyei                      int64
#  163  interscyeii                     int64
#  164  kneeheightmidpatella            int64
#  165  kneeheightsitting               int64
#  166  lateralfemoralepicondyleheight  int64
#  167  lateralmalleolusheight          int64
#  168  lowerthighcircumference         int64
#  169  mentonsellionlength             int64
#  170  neckcircumference               int64
#  171  neckcircumferencebase           int64
#  172  overheadfingertipreachsitting   int64
#  173  palmlength                      int64
#  174  poplitealheight                 int64
#  175  radialestylionlength            int64
#  176  shouldercircumference           int64
#  177  shoulderelbowlength             int64
#  178  shoulderlength                  int64
#  179  sittingheight                   int64
#  180  sleevelengthspinewrist          int64
#  181  sleeveoutseam                   int64
#  182  span                            int64
#  183  stature                         int64
#  184  suprasternaleheight             int64
#  185  tenthribheight                  int64
#  186  thighcircumference              int64
#  187  thighclearance                  int64
#  188  thumbtipreach                   int64
#  189  tibialheight                    int64
#  190  tragiontopofhead                int64
#  191  trochanterionheight             int64
#  192  verticaltrunkcircumferenceusa   int64
#  193  waistbacklength                 int64
#  194  waistbreadth                    int64
#  195  waistcircumference              int64
#  196  waistdepth                      int64
#  197  waistfrontlengthsitting         int64
#  198  waistheightomphalion            int64
#  199  weightkg                        int64
#  200  wristcircumference              int64
#  201  wristheight                     int64
#  202  Gender                          object
#  203  Date                            object
#  204  Installation                    object
#  205  Component                       object
#  206  Branch                          object
#  207  PrimaryMOS                      object
#  208  SubjectsBirthLocation           object
#  209  SubjectNumericRace              int64
#  210  Ethnicity                       object
#  211  DODRace                         int64
#  212  Age                             int64
#  213  Heightin                        int64
#  214  Weightlbs                       int64
#  215  WritingPreference               object
# dtypes: float64(99), int64(99), object(18)
# memory usage: 6.7+ MB

# %%
df.columns = df.columns.str.lower()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum().any()
# Out:
# True

# %%
nan_columns = df.columns[df.isna().any()].tolist()
nan_columns
# Out:
# ['subjectid',
#  'abdominalextensiondepthsitting',
#  'acromialheight',
#  'acromionradialelength',
#  'anklecircumference',
#  'axillaheight',
#  'balloffootcircumference',
#  'balloffootlength',
#  'biacromialbreadth',
#  'bicepscircumferenceflexed',
#  'bicristalbreadth',
#  'bideltoidbreadth',
#  'bimalleolarbreadth',
#  'bitragionchinarc',
#  'bitragionsubmandibulararc',
#  'bizygomaticbreadth',
#  'buttockcircumference',
#  'buttockdepth',
#  'buttockheight',
#  'buttockkneelength',
#  'buttockpopliteallength',
#  'calfcircumference',
#  'cervicaleheight',
#  'chestbreadth',
#  'chestcircumference',
#  'chestdepth',
#  'chestheight',
#  'crotchheight',
#  'crotchlengthomphalion',
#  'crotchlengthposterioromphalion',
#  'earbreadth',
#  'earlength',
#  'earprotrusion',
#  'elbowrestheight',
#  'eyeheightsitting',
#  'footbreadthhorizontal',
#  'footlength',
#  'forearmcenterofgriplength',
#  'forearmcircumferenceflexed',
#  'forearmforearmbreadth',
#  'forearmhandlength',
#  'functionalleglength',
#  'handbreadth',
#  'handcircumference',
#  'handlength',
#  'headbreadth',
#  'headcircumference',
#  'headlength',
#  'heelanklecircumference',
#  'heelbreadth',
#  'hipbreadth',
#  'hipbreadthsitting',
#  'iliocristaleheight',
#  'interpupillarybreadth',
#  'interscyei',
#  'interscyeii',
#  'kneeheightmidpatella',
#  'kneeheightsitting',
#  'lateralfemoralepicondyleheight',
#  'lateralmalleolusheight',
#  'lowerthighcircumference',
#  'mentonsellionlength',
#  'neckcircumference',
#  'neckcircumferencebase',
#  'overheadfingertipreachsitting',
#  'palmlength',
#  'poplitealheight',
#  'radialestylionlength',
#  'shouldercircumference',
#  'shoulderelbowlength',
#  'shoulderlength',
#  'sittingheight',
#  'sleevelengthspinewrist',
#  'sleeveoutseam',
#  'span',
#  'stature',
#  'suprasternaleheight',
#  'tenthribheight',
#  'thighcircumference',
#  'thighclearance',
#  'thumbtipreach',
#  'tibialheight',
#  'tragiontopofhead',
#  'trochanterionheight',
#  'verticaltrunkcircumferenceusa',
#  'waistbacklength',
#  'waistbreadth',
#  'waistcircumference',
#  'waistdepth',
#  'waistfrontlengthsitting',
#  'waistheightomphalion',
#  'weightkg',
#  'wristcircumference',
#  'wristheight',
#  'gender',
#  'date',
#  'installation',
#  'component',
#  'branch',
#  'primarymos',
#  'subjectsbirthlocation',
#  'subjectnumericrace',
#  'ethnicity',
#  'dodrace',
#  'age',
#  'heightin',
#  'weightlbs',
#  'writingpreference',
#  'ethnicity']

# %%
df.drop(columns=['primarymos', 'component', 'branch', 'installation', 'date', 'ethnicity'], inplace=True)

# %%
ax = sns.countplot(x='dodrace', data=df)

# Bar etiketlerini eklemek için matplotlib'in patch'lerini kullanın
for container in ax.containers:
    ax.bar_label(container)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29988\872986424.py in ?()
# ----> 1 ax = sns.countplot(x='dodrace', data=df)
#       2
#       3 # Bar etiketlerini eklemek için matplotlib'in patch'lerini kullanın
#       4 for container in ax.containers:
#
# ~\anaconda3\Lib\site-packages\seaborn\categorical.py in ?(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2939         y = x
#    2940     elif x is not None and y is not None:
#    2941         raise ValueError("Cannot pass values for both `x` and `y`")
#    2942
# -> 2943     plotter = _CountPlotter(
#    2944         x, y, hue, data, order, hue_order,
#    2945         estimator, errorbar, n_boot, units, seed,
#    2946         orient, color, palette, saturation,
#
# ~\anaconda3\Lib\site-packages\seaborn\categorical.py in ?(self, x, y, hue, data, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge)
#    1526                  estimator, errorbar, n_boot, units, seed,
#    1527                  orient, color, palette, saturation, width,
#    1528                  errcolor, errwidth, capsize, dodge):
#    1529         """Initialize the plotter."""
# -> 1530         self.establish_variables(x, y, hue, data, orient,
#    1531                                  order, hue_order, units)
#    1532         self.establish_colors(color, palette, saturation)
#    1533         self.estimate_statistic(estimator, errorbar, n_boot, seed)
#
# ~\anaconda3\Lib\site-packages\seaborn\categorical.py in ?(self, x, y, hue, data, orient, order, hue_order, units)
#     540                     err = f"Could not interpret input '{var}'"
#     541                     raise ValueError(err)
#     542
#     543             # Figure out the plotting orientation
# --> 544             orient = infer_orient(
#     545                 x, y, orient, require_numeric=self.require_numeric
#     546             )
#     547
#
# ~\anaconda3\Lib\site-packages\seaborn\_oldcore.py in ?(x, y, orient, require_numeric)
#    1580     TypeError: When dependent variable is not numeric, with `require_numeric`
#    1581
#    1582     """
#    1583
# -> 1584     x_type = None if x is None else variable_type(x)
#    1585     y_type = None if y is None else variable_type(y)
#    1586
#    1587     nonnumeric_dv_error = "{} orientation requires numeric `{}` variable."
#
# ~\anaconda3\Lib\site-packages\seaborn\_oldcore.py in ?(vector, boolean_type)
#    1498     if pd.api.types.is_categorical_dtype(vector):
#    1499         return VariableType("categorical")
#    1500
#    1501     # Special-case all-na data, which is always "numeric"
# -> 1502     if pd.isna(vector).all():
#    1503         return VariableType("numeric")
#    1504
#    1505     # Special-case binary/boolean data, allow caller to determine
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1517     @final
#    1518     def __nonzero__(self) -> NoReturn:
# -> 1519         raise ValueError(
#    1520             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1521             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1522         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %% [markdown]
# ## Explore Data

# %% [markdown]
# # DATA Preprocessing
# - In this step we divide our data to X(Features) and y(Target) then ,
# - To train and evaluation purposes we create train and test sets,
# - Lastly, scale our data if features not in same scale. Why?

# %% [markdown]
# # Modelling
# - Fit the model with train dataset
# - Get predict from vanilla model on both train and test sets to examine if there is over/underfitting
# - Apply GridseachCV for both hyperparemeter tuning and sanity test of our model.
# - Use hyperparameters that you find from gridsearch and make final prediction and evaluate the result according to chosen metric.

# %% [markdown]
# ## 1. Logistic model

# %% [markdown]
# ### Vanilla Logistic Model

# %% [markdown]
# ### Logistic Model GridsearchCV

# %% [markdown]
# ## 2. SVC

# %% [markdown]
# ### Vanilla SVC model

# %% [markdown]
# ###  SVC Model GridsearchCV

# %% [markdown]
# ## 3. RF

# %% [markdown]
# ### Vanilla RF Model

# %% [markdown]
# ### RF Model GridsearchCV

# %% [markdown]
# ## 4. XGBoost

# %% [markdown]
# ### Vanilla XGBoost Model

# %% [markdown]
# ### XGBoost Model GridsearchCV

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Other Evaluation Metrics for Multiclass Classification

# %% [markdown]
# - Evaluation metrics
# https://towardsdatascience.com/comprehensive-guide-on-multiclass-classification-metrics-af94cfb83fbd

# %%
from sklearn.metrics import matthews_corrcoef
matthews_corrcoef?
matthews_corrcoef(y_test, y_pred)
# Out:
# 0.7380728719663084

# %%
from sklearn.metrics import cohen_kappa_score
cohen_kappa_score?
cohen_kappa_score(y_test, y_pred)
# Out:
# 0.7376215262514891

# %% [markdown]
# ## Before the Deployment
# - Choose the model that works best based on your chosen metric
# - For final step, fit the best model with whole dataset to get better performance.
# - And your model ready to deploy, dump your model and scaler.

# %% [markdown]
# ---
# ---

# %% [markdown]
# # SMOTE
# https://machinelearningmastery.com/smote-oversampling-for-imbalanced-classification/

# %% [markdown]
# ##  Smote implement

# %%
# !pip install imblearn

# %%
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline

# %% [markdown]
# ## Logistic Regression Over/ Under Sampling

# %% [markdown]
# #  SHAP
# - http://archive.today/2024.02.04-155206/https://towardsdatascience.com/shapley-values-clearly-explained-a7f7ef22b104
# - https://towardsdatascience.com/shap-explain-any-machine-learning-model-in-python-24207127cad7

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
