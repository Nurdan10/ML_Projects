# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %%
# If you are using Anaconda, you can create a new environment with use of Anaconda terminal and codes below:
# conda create --name soldier
# conda install -c conda-forge ipykernel scikit-learn "numpy<1.25" pandas "shap== 0.35.0" matplotlib "seaborn==0.12.2" xgboost scikit-plot imbalanced-learn numba jinja2 ipywidgets

# %% [markdown]
# In this project, you must apply EDA processes for the development of predictive models. Handling outliers, domain knowledge and feature engineering will be challenges.
#
# Also, this project aims to improve your ability to implement algorithms for Multi-Class Classification. Thus, you will have the opportunity to implement many algorithms commonly used for Multi-Class Classification problems.
#
# Before diving into the project, please take a look at the determines and tasks.

# %% [markdown]
# # Determines

# %% [markdown]
# The 2012 US Army Anthropometric Survey (ANSUR II) was executed by the Natick Soldier Research, Development and Engineering Center (NSRDEC) from October 2010 to April 2012 and is comprised of personnel representing the total US Army force to include the US Army Active Duty, Reserves, and National Guard. In addition to the anthropometric and demographic data described below, the ANSUR II database also consists of 3D whole body, foot, and head scans of Soldier participants. These 3D data are not publicly available out of respect for the privacy of ANSUR II participants. The data from this survey are used for a wide range of equipment design, sizing, and tariffing applications within the military and has many potential commercial, industrial, and academic applications.
#
# The ANSUR II working databases contain 93 anthropometric measurements which were directly measured, and 15 demographic/administrative variables explained below. The ANSUR II Male working database contains a total sample of 4,082 subjects. The ANSUR II Female working database contains a total sample of 1,986 subjects.
#
#
# DATA DICT:
# https://data.world/datamil/ansur-ii-data-dictionary/workspace/file?filename=ANSUR+II+Databases+Overview.pdf
#
# ---
#
# To achieve high prediction success, you must understand the data well and develop different approaches that can affect the dependent variable.
#
# Firstly, try to understand the dataset column by column using pandas module. Do research within the scope of domain (body scales, and race characteristics) knowledge on the internet to get to know the data set in the fastest way.
#
# You will implement ***Logistic Regression, Support Vector Machine, XGBoost, Random Forest*** algorithms. Also, evaluate the success of your models with appropriate performance metrics.
#
# At the end of the project, choose the most successful model and try to enhance the scores with ***SMOTE*** make it ready to deploy. Furthermore, use ***SHAP*** to explain how the best model you choose works.

# %% [markdown]
# # Tasks

# %% [markdown]
# #### 1. Exploratory Data Analysis (EDA)
# - Import Libraries, Load Dataset, Exploring Data
#
#     *i. Import Libraries*
#
#     *ii. Ingest Data *
#
#     *iii. Explore Data*
#
#     *iv. Outlier Detection*
#
#     *v.  Drop unnecessary features*
#
# #### 2. Data Preprocessing
# - Scale (if needed)
# - Separete the data frame for evaluation purposes
#
# #### 3. Multi-class Classification
# - Import libraries
# - Implement SVM Classifer
# - Implement Decision Tree Classifier
# - Implement Random Forest Classifer
# - Implement XGBoost Classifer
# - Compare The Models
#
# #### 4. SMOTE
# - Apply Imbalance Learning Techniques
#
# #### 5. SHAP
# - Apply Feature selection with SHAP

# %% [markdown]
# # EDA
# - Drop unnecessary colums
# - Drop DODRace class if value count below 500 (we assume that our data model can't learn if it is below 500)

# %% [markdown]
# ## Import Libraries
# Besides Numpy and Pandas, you need to import the necessary modules for data visualization, data preprocessing, Model building and tuning.
#
# *Note: Check out the course materials.*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor, GradientBoostingClassifier, GradientBoostingRegressor
from sklearn.svm import SVC, SVR
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.naive_bayes import GaussianNB
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score



import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %%
pip install xgboost lightgbm catboost
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: xgboost in c:\users\hasan\appdata\roaming\python\python311\site-packages (2.1.0)
# Requirement already satisfied: lightgbm in c:\users\hasan\appdata\roaming\python\python311\site-packages (4.4.0)
# Requirement already satisfied: catboost in c:\users\hasan\appdata\roaming\python\python311\site-packages (1.2.5)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from xgboost) (1.24.3)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from xgboost) (1.11.1)
# Requirement already satisfied: graphviz in c:\users\hasan\appdata\roaming\python\python311\site-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (from catboost) (3.7.2)
# Requirement already satisfied: pandas>=0.24 in c:\programdata\anaconda3\lib\site-packages (from catboost) (2.0.3)
# Requirement already satisfied: plotly in c:\programdata\anaconda3\lib\site-packages (from catboost) (5.9.0)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>=0.24->catboost) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>=0.24->catboost) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->catboost) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->catboost) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->catboost) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->catboost) (10.2.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from plotly->catboost) (8.2.2)

# %%
import scipy.stats as stats
import statsmodels.api as sm
import xgboost as xgb
import lightgbm as lgb
import catboost as cb

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %% [markdown]
# ## Ingest Data from links below and make a dataframe
# - Soldiers Male : https://query.data.world/s/h3pbhckz5ck4rc7qmt2wlknlnn7esr
# - Soldiers Female : https://query.data.world/s/sq27zz4hawg32yfxksqwijxmpwmynq

# %%
df_female = pd.read_csv('ANSUR II FEMALE Public.csv')

# %%
df_male = pd.read_csv('ANSUR II MALE Public.csv', encoding = " ISO-8859-1")

# %% [markdown]
# ## Explore Data

# %%
df_female.head().T
# Out:
#                                              0                       1  \
# SubjectId                                10037                   10038
# abdominalextensiondepthsitting             231                     194
# acromialheight                            1282                    1379
# acromionradialelength                      301                     320
# anklecircumference                         204                     207
# axillaheight                              1180                    1292
# balloffootcircumference                    222                     225
# balloffootlength                           177                     178
# biacromialbreadth                          373                     372
# bicepscircumferenceflexed                  315                     272
# bicristalbreadth                           263                     250
# bideltoidbreadth                           466                     430
# bimalleolarbreadth                          65                      64
# bitragionchinarc                           338                     294
# bitragionsubmandibulararc                  301                     270
# bizygomaticbreadth                         141                     126
# buttockcircumference                      1011                     893
# buttockdepth                               223                     186
# buttockheight                              836                     900
# buttockkneelength                          587                     583
# buttockpopliteallength                     476                     483
# calfcircumference                          360                     350
# cervicaleheight                           1336                    1440
# chestbreadth                               274                     261
# chestcircumference                         922                     839
# chestdepth                                 245                     206
# chestheight                               1095                    1234
# crotchheight                               759                     835
# crotchlengthomphalion                      557                     549
# crotchlengthposterioromphalion             310                     329
# earbreadth                                  35                      32
# earlength                                   65                      60
# earprotrusion                               16                      23
# elbowrestheight                            220                     208
# eyeheightsitting                           713                     726
# footbreadthhorizontal                       91                      91
# footlength                                 246                     249
# forearmcenterofgriplength                  316                     341
# forearmcircumferenceflexed                 265                     247
# forearmforearmbreadth                      517                     468
# forearmhandlength                          432                     463
# functionalleglength                       1028                    1117
# handbreadth                                 75                      78
# handcircumference                          182                     187
# handlength                                 184                     189
# headbreadth                                141                     138
# headcircumference                          548                     535
# headlength                                 191                     180
# heelanklecircumference                     314                     307
# heelbreadth                                 69                      60
# hipbreadth                                 345                     315
# hipbreadthsitting                          388                     335
# iliocristaleheight                         966                    1048
# interpupillarybreadth                      645                     595
# interscyei                                 363                     340
# interscyeii                                399                     375
# kneeheightmidpatella                       435                     483
# kneeheightsitting                          496                     532
# lateralfemoralepicondyleheight             447                     492
# lateralmalleolusheight                      55                      69
# lowerthighcircumference                    404                     334
# mentonsellionlength                        118                     115
# neckcircumference                          335                     302
# neckcircumferencebase                      368                     345
# overheadfingertipreachsitting             1268                    1389
# palmlength                                 113                     110
# poplitealheight                            362                     426
# radialestylionlength                       235                     259
# shouldercircumference                     1062                    1014
# shoulderelbowlength                        327                     346
# shoulderlength                             148                     142
# sittingheight                              803                     835
# sleevelengthspinewrist                     809                     810
# sleeveoutseam                              513                     575
# span                                      1647                    1751
# stature                                   1560                    1665
# suprasternaleheight                       1280                    1372
# tenthribheight                            1013                    1107
# thighcircumference                         622                     524
# thighclearance                             174                     152
# thumbtipreach                              736                     771
# tibialheight                               430                     475
# tragiontopofhead                           110                     125
# trochanterionheight                        844                     901
# verticaltrunkcircumferenceusa             1488                    1470
# waistbacklength                            406                     422
# waistbreadth                               295                     254
# waistcircumference                         850                     708
# waistdepth                                 217                     168
# waistfrontlengthsitting                    345                     329
# waistheightomphalion                       942                    1032
# weightkg                                   657                     534
# wristcircumference                         152                     155
# wristheight                                756                     815
# Gender                                  Female                  Female
# Date                                  5-Oct-10                5-Oct-10
# Installation                         Fort Hood               Fort Hood
# Component                         Regular Army            Regular Army
# Branch                          Combat Support  Combat Service Support
# PrimaryMOS                                 92Y                     25U
# SubjectsBirthLocation                  Germany              California
# SubjectNumericRace                           2                       3
# Ethnicity                                  NaN                 Mexican
# DODRace                                      2                       3
# Age                                         26                      21
# Heightin                                    61                      64
# Weightlbs                                  142                     120
# WritingPreference                   Right hand              Right hand
#
#                                                      2  \
# SubjectId                                        10042
# abdominalextensiondepthsitting                     183
# acromialheight                                    1369
# acromionradialelength                              329
# anklecircumference                                 233
# axillaheight                                      1271
# balloffootcircumference                            237
# balloffootlength                                   196
# biacromialbreadth                                  397
# bicepscircumferenceflexed                          300
# bicristalbreadth                                   276
# bideltoidbreadth                                   450
# bimalleolarbreadth                                  69
# bitragionchinarc                                   309
# bitragionsubmandibulararc                          270
# bizygomaticbreadth                                 128
# buttockcircumference                               987
# buttockdepth                                       204
# buttockheight                                      861
# buttockkneelength                                  583
# buttockpopliteallength                             466
# calfcircumference                                  384
# cervicaleheight                                   1451
# chestbreadth                                       287
# chestcircumference                                 874
# chestdepth                                         223
# chestheight                                       1226
# crotchheight                                       821
# crotchlengthomphalion                              643
# crotchlengthposterioromphalion                     374
# earbreadth                                          36
# earlength                                           65
# earprotrusion                                       26
# elbowrestheight                                    204
# eyeheightsitting                                   790
# footbreadthhorizontal                              100
# footlength                                         265
# forearmcenterofgriplength                          343
# forearmcircumferenceflexed                         262
# forearmforearmbreadth                              488
# forearmhandlength                                  469
# functionalleglength                               1060
# handbreadth                                         84
# handcircumference                                  198
# handlength                                         195
# headbreadth                                        146
# headcircumference                                  588
# headlength                                         207
# heelanklecircumference                             331
# heelbreadth                                         70
# hipbreadth                                         356
# hipbreadthsitting                                  399
# iliocristaleheight                                1043
# interpupillarybreadth                              655
# interscyei                                         345
# interscyeii                                        399
# kneeheightmidpatella                               470
# kneeheightsitting                                  530
# lateralfemoralepicondyleheight                     469
# lateralmalleolusheight                              64
# lowerthighcircumference                            401
# mentonsellionlength                                135
# neckcircumference                                  325
# neckcircumferencebase                              369
# overheadfingertipreachsitting                     1414
# palmlength                                         122
# poplitealheight                                    398
# radialestylionlength                               258
# shouldercircumference                             1049
# shoulderelbowlength                                362
# shoulderlength                                     164
# sittingheight                                      904
# sleevelengthspinewrist                             855
# sleeveoutseam                                      568
# span                                              1779
# stature                                           1711
# suprasternaleheight                               1383
# tenthribheight                                    1089
# thighcircumference                                 577
# thighclearance                                     164
# thumbtipreach                                      814
# tibialheight                                       458
# tragiontopofhead                                   129
# trochanterionheight                                882
# verticaltrunkcircumferenceusa                     1542
# waistbacklength                                    419
# waistbreadth                                       269
# waistcircumference                                 727
# waistdepth                                         159
# waistfrontlengthsitting                            367
# waistheightomphalion                              1035
# weightkg                                           663
# wristcircumference                                 162
# wristheight                                        799
# Gender                                          Female
# Date                                          5-Oct-10
# Installation                                 Fort Hood
# Component                                 Regular Army
# Branch                          Combat Service Support
# PrimaryMOS                                         35D
# SubjectsBirthLocation                            Texas
# SubjectNumericRace                                   1
# Ethnicity                                          NaN
# DODRace                                              1
# Age                                                 23
# Heightin                                            68
# Weightlbs                                          147
# WritingPreference                           Right hand
#
#                                                      3             4
# SubjectId                                        10043         10051
# abdominalextensiondepthsitting                     261           309
# acromialheight                                    1356          1303
# acromionradialelength                              306           308
# anklecircumference                                 214           214
# axillaheight                                      1250          1210
# balloffootcircumference                            240           217
# balloffootlength                                   188           182
# biacromialbreadth                                  384           378
# bicepscircumferenceflexed                          364           320
# bicristalbreadth                                   276           336
# bideltoidbreadth                                   484           525
# bimalleolarbreadth                                  68            67
# bitragionchinarc                                   340           300
# bitragionsubmandibulararc                          294           295
# bizygomaticbreadth                                 144           135
# buttockcircumference                              1012          1281
# buttockdepth                                       253           284
# buttockheight                                      897           811
# buttockkneelength                                  599           607
# buttockpopliteallength                             471           467
# calfcircumference                                  372           433
# cervicaleheight                                   1430          1362
# chestbreadth                                       269           305
# chestcircumference                                1008          1089
# chestdepth                                         285           290
# chestheight                                       1170          1112
# crotchheight                                       804           726
# crotchlengthomphalion                              640           686
# crotchlengthposterioromphalion                     351           356
# earbreadth                                          38            34
# earlength                                           62            65
# earprotrusion                                       22            18
# elbowrestheight                                    244           233
# eyeheightsitting                                   775           732
# footbreadthhorizontal                               97            88
# footlength                                         265           247
# forearmcenterofgriplength                          331           339
# forearmcircumferenceflexed                         309           260
# forearmforearmbreadth                              529           596
# forearmhandlength                                  455           447
# functionalleglength                               1069          1039
# handbreadth                                         80            78
# handcircumference                                  192           183
# handlength                                         186           187
# headbreadth                                        153           140
# headcircumference                                  593           522
# headlength                                         206           181
# heelanklecircumference                             332           308
# heelbreadth                                         68            63
# hipbreadth                                         337           448
# hipbreadthsitting                                  402           499
# iliocristaleheight                                1029           964
# interpupillarybreadth                              655           635
# interscyei                                         392           428
# interscyeii                                        435           435
# kneeheightmidpatella                               469           440
# kneeheightsitting                                  520           491
# lateralfemoralepicondyleheight                     478           441
# lateralmalleolusheight                              67            63
# lowerthighcircumference                            402           479
# mentonsellionlength                                118           114
# neckcircumference                                  357           340
# neckcircumferencebase                              386           358
# overheadfingertipreachsitting                     1329          1350
# palmlength                                         115           116
# poplitealheight                                    394           345
# radialestylionlength                               250           242
# shouldercircumference                             1121          1151
# shoulderelbowlength                                333           329
# shoulderlength                                     157           156
# sittingheight                                      875           824
# sleevelengthspinewrist                             815           810
# sleeveoutseam                                      536           559
# span                                              1708          1702
# stature                                           1660          1572
# suprasternaleheight                               1358          1292
# tenthribheight                                    1065          1030
# thighcircumference                                 679           766
# thighclearance                                     187           197
# thumbtipreach                                      736           766
# tibialheight                                       463           429
# tragiontopofhead                                   125           116
# trochanterionheight                                866           800
# verticaltrunkcircumferenceusa                     1627          1698
# waistbacklength                                    451           452
# waistbreadth                                       302           405
# waistcircumference                                 923          1163
# waistdepth                                         235           300
# waistfrontlengthsitting                            371           380
# waistheightomphalion                               999           911
# weightkg                                           782           886
# wristcircumference                                 173           152
# wristheight                                        818           762
# Gender                                          Female        Female
# Date                                          5-Oct-10      5-Oct-10
# Installation                                 Fort Hood     Fort Hood
# Component                                 Regular Army  Regular Army
# Branch                          Combat Service Support   Combat Arms
# PrimaryMOS                                         25U           42A
# SubjectsBirthLocation             District of Columbia         Texas
# SubjectNumericRace                                   8             1
# Ethnicity                           Caribbean Islander           NaN
# DODRace                                              2             1
# Age                                                 22            45
# Heightin                                            66            63
# Weightlbs                                          175           195
# WritingPreference                           Right hand    Right hand

# %%
df_male.head()
# Out:
#    subjectid  abdominalextensiondepthsitting  acromialheight  \
# 0      10027                             266            1467
# 1      10032                             233            1395
# 2      10033                             287            1430
# 3      10092                             234            1347
# 4      10093                             250            1585
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    337                 222          1347
# 1                    326                 220          1293
# 2                    341                 230          1327
# 3                    310                 230          1239
# 4                    372                 247          1478
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      253               202                401
# 1                      245               193                394
# 2                      256               196                427
# 3                      262               199                401
# 4                      267               224                435
#
#    bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  \
# 0                        369               274               493
# 1                        338               257               479
# 2                        408               261               544
# 3                        359               262               518
# 4                        356               263               524
#
#    bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  \
# 0                  71               319                        291
# 1                  67               344                        320
# 2                  75               345                        330
# 3                  73               328                        309
# 4                  80               340                        310
#
#    bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  \
# 0                 142                   979           240            882
# 1                 135                   944           232            870
# 2                 135                  1054           258            901
# 3                 143                   991           242            821
# 4                 138                  1029           275           1080
#
#    buttockkneelength  buttockpopliteallength  calfcircumference  \
# 0                619                     509                373
# 1                584                     468                357
# 2                623                     506                412
# 3                560                     437                395
# 4                706                     567                425
#
#    cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  \
# 0             1535           291                1074         259         1292
# 1             1471           269                1021         253         1244
# 2             1501           288                1120         267         1288
# 3             1423           296                1114         262         1205
# 4             1684           304                1048         232         1452
#
#    crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion  \
# 0           877                    607                             351
# 1           851                    615                             376
# 2           854                    636                             359
# 3           769                    590                             341
# 4          1014                    682                             382
#
#    earbreadth  earlength  earprotrusion  elbowrestheight  eyeheightsitting  \
# 0          36         71             19              247               802
# 1          33         62             18              232               781
# 2          40         61             23              237               810
# 3          39         66             25              272               794
# 4          32         56             19              188               814
#
#    footbreadthhorizontal  footlength  forearmcenterofgriplength  \
# 0                    101         273                        349
# 1                     98         263                        348
# 2                    103         270                        355
# 3                    106         267                        352
# 4                    111         305                        399
#
#    forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  \
# 0                         299                    575                477
# 1                         289                    523                476
# 2                         357                    575                491
# 3                         318                    593                467
# 4                         324                    605                550
#
#    functionalleglength  handbreadth  handcircumference  handlength  \
# 0                 1136           90                214         193
# 1                 1096           86                203         195
# 2                 1115           93                220         203
# 3                 1034           91                217         194
# 4                 1279           94                222         218
#
#    headbreadth  headcircumference  headlength  heelanklecircumference  \
# 0          150                583         206                     326
# 1          146                568         201                     334
# 2          148                573         202                     356
# 3          158                576         199                     341
# 4          153                566         197                     374
#
#    heelbreadth  ...  lateralfemoralepicondyleheight  lateralmalleolusheight  \
# 0           70  ...                             500                      77
# 1           72  ...                             488                      73
# 2           70  ...                             482                      72
# 3           68  ...                             452                      76
# 4           69  ...                             585                      85
#
#    lowerthighcircumference  mentonsellionlength  neckcircumference  \
# 0                      391                  118                400
# 1                      371                  131                380
# 2                      409                  123                403
# 3                      393                  106                407
# 4                      458                  135                398
#
#    neckcircumferencebase  overheadfingertipreachsitting  palmlength  \
# 0                    436                           1447         113
# 1                    420                           1380         118
# 2                    434                           1447         121
# 3                    446                           1357         118
# 4                    430                           1572         132
#
#    poplitealheight  radialestylionlength  shouldercircumference  \
# 0              437                   273                   1151
# 1              417                   254                   1119
# 2              431                   268                   1276
# 3              393                   249                   1155
# 4              523                   302                   1231
#
#    shoulderelbowlength  shoulderlength  sittingheight  sleevelengthspinewrist  \
# 0                  368             145            928                     883
# 1                  353             141            884                     868
# 2                  367             167            917                     910
# 3                  330             148            903                     848
# 4                  400             180            919                     995
#
#    sleeveoutseam  span  stature  suprasternaleheight  tenthribheight  \
# 0            600  1782     1776                 1449            1092
# 1            564  1745     1702                 1387            1076
# 2            604  1867     1735                 1438            1105
# 3            550  1708     1655                 1346            1021
# 4            641  2035     1914                 1596            1292
#
#    thighcircumference  thighclearance  thumbtipreach  tibialheight  \
# 0                 610             164            786           491
# 1                 572             169            822           476
# 2                 685             198            807           477
# 3                 604             180            803           445
# 4                 672             194            962           584
#
#    tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  \
# 0               140                  919                           1700
# 1               120                  918                           1627
# 2               125                  918                           1678
# 3               127                  847                           1625
# 4               122                 1090                           1679
#
#    waistbacklength  waistbreadth  waistcircumference  waistdepth  \
# 0              501           329                 933         240
# 1              432           316                 870         225
# 2              472           329                 964         255
# 3              461           315                 857         205
# 4              467           303                 868         214
#
#    waistfrontlengthsitting  waistheightomphalion  weightkg  \
# 0                      440                  1054       815
# 1                      371                  1054       726
# 2                      411                  1041       929
# 3                      399                   968       794
# 4                      379                  1245       946
#
#    wristcircumference  wristheight  Gender       Date  Installation  \
# 0                 175          853    Male   4-Oct-10     Fort Hood
# 1                 167          815    Male   4-Oct-10     Fort Hood
# 2                 180          831    Male   4-Oct-10     Fort Hood
# 3                 176          793    Male  12-Oct-10     Fort Hood
# 4                 188          954    Male  12-Oct-10     Fort Hood
#
#       Component                  Branch  PrimaryMOS  SubjectsBirthLocation  \
# 0  Regular Army             Combat Arms         19D           North Dakota
# 1  Regular Army          Combat Support         68W               New York
# 2  Regular Army          Combat Support         68W               New York
# 3  Regular Army  Combat Service Support         88M              Wisconsin
# 4  Regular Army  Combat Service Support         92G         North Carolina
#
#    SubjectNumericRace Ethnicity DODRace Age Heightin Weightlbs  \
# 0                   1       NaN       1  41       71       180
# 1                   1       NaN       1  35       68       160
# 2                   2       NaN       2  42       68       205
# 3                   1       NaN       1  31       66       175
# 4                   2       NaN       2  21       77       213
#
#   WritingPreference
# 0        Right hand
# 1         Left hand
# 2         Left hand
# 3        Right hand
# 4        Right hand
#
# [5 rows x 108 columns]

# %%
df_female.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1986 entries, 0 to 1985
# Data columns (total 108 columns):
#  #    Column                          Dtype
# ---   ------                          -----
#  0    SubjectId                       int64
#  1    abdominalextensiondepthsitting  int64
#  2    acromialheight                  int64
#  3    acromionradialelength           int64
#  4    anklecircumference              int64
#  5    axillaheight                    int64
#  6    balloffootcircumference         int64
#  7    balloffootlength                int64
#  8    biacromialbreadth               int64
#  9    bicepscircumferenceflexed       int64
#  10   bicristalbreadth                int64
#  11   bideltoidbreadth                int64
#  12   bimalleolarbreadth              int64
#  13   bitragionchinarc                int64
#  14   bitragionsubmandibulararc       int64
#  15   bizygomaticbreadth              int64
#  16   buttockcircumference            int64
#  17   buttockdepth                    int64
#  18   buttockheight                   int64
#  19   buttockkneelength               int64
#  20   buttockpopliteallength          int64
#  21   calfcircumference               int64
#  22   cervicaleheight                 int64
#  23   chestbreadth                    int64
#  24   chestcircumference              int64
#  25   chestdepth                      int64
#  26   chestheight                     int64
#  27   crotchheight                    int64
#  28   crotchlengthomphalion           int64
#  29   crotchlengthposterioromphalion  int64
#  30   earbreadth                      int64
#  31   earlength                       int64
#  32   earprotrusion                   int64
#  33   elbowrestheight                 int64
#  34   eyeheightsitting                int64
#  35   footbreadthhorizontal           int64
#  36   footlength                      int64
#  37   forearmcenterofgriplength       int64
#  38   forearmcircumferenceflexed      int64
#  39   forearmforearmbreadth           int64
#  40   forearmhandlength               int64
#  41   functionalleglength             int64
#  42   handbreadth                     int64
#  43   handcircumference               int64
#  44   handlength                      int64
#  45   headbreadth                     int64
#  46   headcircumference               int64
#  47   headlength                      int64
#  48   heelanklecircumference          int64
#  49   heelbreadth                     int64
#  50   hipbreadth                      int64
#  51   hipbreadthsitting               int64
#  52   iliocristaleheight              int64
#  53   interpupillarybreadth           int64
#  54   interscyei                      int64
#  55   interscyeii                     int64
#  56   kneeheightmidpatella            int64
#  57   kneeheightsitting               int64
#  58   lateralfemoralepicondyleheight  int64
#  59   lateralmalleolusheight          int64
#  60   lowerthighcircumference         int64
#  61   mentonsellionlength             int64
#  62   neckcircumference               int64
#  63   neckcircumferencebase           int64
#  64   overheadfingertipreachsitting   int64
#  65   palmlength                      int64
#  66   poplitealheight                 int64
#  67   radialestylionlength            int64
#  68   shouldercircumference           int64
#  69   shoulderelbowlength             int64
#  70   shoulderlength                  int64
#  71   sittingheight                   int64
#  72   sleevelengthspinewrist          int64
#  73   sleeveoutseam                   int64
#  74   span                            int64
#  75   stature                         int64
#  76   suprasternaleheight             int64
#  77   tenthribheight                  int64
#  78   thighcircumference              int64
#  79   thighclearance                  int64
#  80   thumbtipreach                   int64
#  81   tibialheight                    int64
#  82   tragiontopofhead                int64
#  83   trochanterionheight             int64
#  84   verticaltrunkcircumferenceusa   int64
#  85   waistbacklength                 int64
#  86   waistbreadth                    int64
#  87   waistcircumference              int64
#  88   waistdepth                      int64
#  89   waistfrontlengthsitting         int64
#  90   waistheightomphalion            int64
#  91   weightkg                        int64
#  92   wristcircumference              int64
#  93   wristheight                     int64
#  94   Gender                          object
#  95   Date                            object
#  96   Installation                    object
#  97   Component                       object
#  98   Branch                          object
#  99   PrimaryMOS                      object
#  100  SubjectsBirthLocation           object
#  101  SubjectNumericRace              int64
#  102  Ethnicity                       object
#  103  DODRace                         int64
#  104  Age                             int64
#  105  Heightin                        int64
#  106  Weightlbs                       int64
#  107  WritingPreference               object
# dtypes: int64(99), object(9)
# memory usage: 1.6+ MB

# %%
df_female.columns
# Out:
# Index(['SubjectId', 'abdominalextensiondepthsitting', 'acromialheight',
#        'acromionradialelength', 'anklecircumference', 'axillaheight',
#        'balloffootcircumference', 'balloffootlength', 'biacromialbreadth',
#        'bicepscircumferenceflexed',
#        ...
#        'Branch', 'PrimaryMOS', 'SubjectsBirthLocation', 'SubjectNumericRace',
#        'Ethnicity', 'DODRace', 'Age', 'Heightin', 'Weightlbs',
#        'WritingPreference'],
#       dtype='object', length=108)

# %%
df_male.columns
# Out:
# Index(['subjectid', 'abdominalextensiondepthsitting', 'acromialheight',
#        'acromionradialelength', 'anklecircumference', 'axillaheight',
#        'balloffootcircumference', 'balloffootlength', 'biacromialbreadth',
#        'bicepscircumferenceflexed',
#        ...
#        'Branch', 'PrimaryMOS', 'SubjectsBirthLocation', 'SubjectNumericRace',
#        'Ethnicity', 'DODRace', 'Age', 'Heightin', 'Weightlbs',
#        'WritingPreference'],
#       dtype='object', length=108)

# %%
pd.options.display.max_rows = 300
pd.options.display.max_columns = 100

# %%
df_female.isna().sum()
# Out:
# SubjectId                            0
# abdominalextensiondepthsitting       0
# acromialheight                       0
# acromionradialelength                0
# anklecircumference                   0
# axillaheight                         0
# balloffootcircumference              0
# balloffootlength                     0
# biacromialbreadth                    0
# bicepscircumferenceflexed            0
# bicristalbreadth                     0
# bideltoidbreadth                     0
# bimalleolarbreadth                   0
# bitragionchinarc                     0
# bitragionsubmandibulararc            0
# bizygomaticbreadth                   0
# buttockcircumference                 0
# buttockdepth                         0
# buttockheight                        0
# buttockkneelength                    0
# buttockpopliteallength               0
# calfcircumference                    0
# cervicaleheight                      0
# chestbreadth                         0
# chestcircumference                   0
# chestdepth                           0
# chestheight                          0
# crotchheight                         0
# crotchlengthomphalion                0
# crotchlengthposterioromphalion       0
# earbreadth                           0
# earlength                            0
# earprotrusion                        0
# elbowrestheight                      0
# eyeheightsitting                     0
# footbreadthhorizontal                0
# footlength                           0
# forearmcenterofgriplength            0
# forearmcircumferenceflexed           0
# forearmforearmbreadth                0
# forearmhandlength                    0
# functionalleglength                  0
# handbreadth                          0
# handcircumference                    0
# handlength                           0
# headbreadth                          0
# headcircumference                    0
# headlength                           0
# heelanklecircumference               0
# heelbreadth                          0
# hipbreadth                           0
# hipbreadthsitting                    0
# iliocristaleheight                   0
# interpupillarybreadth                0
# interscyei                           0
# interscyeii                          0
# kneeheightmidpatella                 0
# kneeheightsitting                    0
# lateralfemoralepicondyleheight       0
# lateralmalleolusheight               0
# lowerthighcircumference              0
# mentonsellionlength                  0
# neckcircumference                    0
# neckcircumferencebase                0
# overheadfingertipreachsitting        0
# palmlength                           0
# poplitealheight                      0
# radialestylionlength                 0
# shouldercircumference                0
# shoulderelbowlength                  0
# shoulderlength                       0
# sittingheight                        0
# sleevelengthspinewrist               0
# sleeveoutseam                        0
# span                                 0
# stature                              0
# suprasternaleheight                  0
# tenthribheight                       0
# thighcircumference                   0
# thighclearance                       0
# thumbtipreach                        0
# tibialheight                         0
# tragiontopofhead                     0
# trochanterionheight                  0
# verticaltrunkcircumferenceusa        0
# waistbacklength                      0
# waistbreadth                         0
# waistcircumference                   0
# waistdepth                           0
# waistfrontlengthsitting              0
# waistheightomphalion                 0
# weightkg                             0
# wristcircumference                   0
# wristheight                          0
# Gender                               0
# Date                                 0
# Installation                         0
# Component                            0
# Branch                               0
# PrimaryMOS                           0
# SubjectsBirthLocation                0
# SubjectNumericRace                   0
# Ethnicity                         1467
# DODRace                              0
# Age                                  0
# Heightin                             0
# Weightlbs                            0
# WritingPreference                    0
# dtype: int64

# %%
df_male.isna().sum()
# Out:
# subjectid                            0
# abdominalextensiondepthsitting       0
# acromialheight                       0
# acromionradialelength                0
# anklecircumference                   0
# axillaheight                         0
# balloffootcircumference              0
# balloffootlength                     0
# biacromialbreadth                    0
# bicepscircumferenceflexed            0
# bicristalbreadth                     0
# bideltoidbreadth                     0
# bimalleolarbreadth                   0
# bitragionchinarc                     0
# bitragionsubmandibulararc            0
# bizygomaticbreadth                   0
# buttockcircumference                 0
# buttockdepth                         0
# buttockheight                        0
# buttockkneelength                    0
# buttockpopliteallength               0
# calfcircumference                    0
# cervicaleheight                      0
# chestbreadth                         0
# chestcircumference                   0
# chestdepth                           0
# chestheight                          0
# crotchheight                         0
# crotchlengthomphalion                0
# crotchlengthposterioromphalion       0
# earbreadth                           0
# earlength                            0
# earprotrusion                        0
# elbowrestheight                      0
# eyeheightsitting                     0
# footbreadthhorizontal                0
# footlength                           0
# forearmcenterofgriplength            0
# forearmcircumferenceflexed           0
# forearmforearmbreadth                0
# forearmhandlength                    0
# functionalleglength                  0
# handbreadth                          0
# handcircumference                    0
# handlength                           0
# headbreadth                          0
# headcircumference                    0
# headlength                           0
# heelanklecircumference               0
# heelbreadth                          0
# hipbreadth                           0
# hipbreadthsitting                    0
# iliocristaleheight                   0
# interpupillarybreadth                0
# interscyei                           0
# interscyeii                          0
# kneeheightmidpatella                 0
# kneeheightsitting                    0
# lateralfemoralepicondyleheight       0
# lateralmalleolusheight               0
# lowerthighcircumference              0
# mentonsellionlength                  0
# neckcircumference                    0
# neckcircumferencebase                0
# overheadfingertipreachsitting        0
# palmlength                           0
# poplitealheight                      0
# radialestylionlength                 0
# shouldercircumference                0
# shoulderelbowlength                  0
# shoulderlength                       0
# sittingheight                        0
# sleevelengthspinewrist               0
# sleeveoutseam                        0
# span                                 0
# stature                              0
# suprasternaleheight                  0
# tenthribheight                       0
# thighcircumference                   0
# thighclearance                       0
# thumbtipreach                        0
# tibialheight                         0
# tragiontopofhead                     0
# trochanterionheight                  0
# verticaltrunkcircumferenceusa        0
# waistbacklength                      0
# waistbreadth                         0
# waistcircumference                   0
# waistdepth                           0
# waistfrontlengthsitting              0
# waistheightomphalion                 0
# weightkg                             0
# wristcircumference                   0
# wristheight                          0
# Gender                               0
# Date                                 0
# Installation                         0
# Component                            0
# Branch                               0
# PrimaryMOS                           0
# SubjectsBirthLocation                0
# SubjectNumericRace                   0
# Ethnicity                         3180
# DODRace                              0
# Age                                  0
# Heightin                             0
# Weightlbs                            0
# WritingPreference                    0
# dtype: int64

# %%
df_female.shape
# Out:
# (1986, 108)

# %%
df_male.shape
# Out:
# (4082, 108)

# %%
df_female = df_female.rename(columns = {"SubjectId":"subjectid"})

# %%
df = pd.concat([df_male, df_female], ignore_index=True)

# %%
df.shape
# Out:
# (6068, 108)

# %%
df.isnull().sum().any()
# Out:
# True

# %%
df.isnull().sum()
# Out:
# subjectid                            0
# abdominalextensiondepthsitting       0
# acromialheight                       0
# acromionradialelength                0
# anklecircumference                   0
# axillaheight                         0
# balloffootcircumference              0
# balloffootlength                     0
# biacromialbreadth                    0
# bicepscircumferenceflexed            0
# bicristalbreadth                     0
# bideltoidbreadth                     0
# bimalleolarbreadth                   0
# bitragionchinarc                     0
# bitragionsubmandibulararc            0
# bizygomaticbreadth                   0
# buttockcircumference                 0
# buttockdepth                         0
# buttockheight                        0
# buttockkneelength                    0
# buttockpopliteallength               0
# calfcircumference                    0
# cervicaleheight                      0
# chestbreadth                         0
# chestcircumference                   0
# chestdepth                           0
# chestheight                          0
# crotchheight                         0
# crotchlengthomphalion                0
# crotchlengthposterioromphalion       0
# earbreadth                           0
# earlength                            0
# earprotrusion                        0
# elbowrestheight                      0
# eyeheightsitting                     0
# footbreadthhorizontal                0
# footlength                           0
# forearmcenterofgriplength            0
# forearmcircumferenceflexed           0
# forearmforearmbreadth                0
# forearmhandlength                    0
# functionalleglength                  0
# handbreadth                          0
# handcircumference                    0
# handlength                           0
# headbreadth                          0
# headcircumference                    0
# headlength                           0
# heelanklecircumference               0
# heelbreadth                          0
# hipbreadth                           0
# hipbreadthsitting                    0
# iliocristaleheight                   0
# interpupillarybreadth                0
# interscyei                           0
# interscyeii                          0
# kneeheightmidpatella                 0
# kneeheightsitting                    0
# lateralfemoralepicondyleheight       0
# lateralmalleolusheight               0
# lowerthighcircumference              0
# mentonsellionlength                  0
# neckcircumference                    0
# neckcircumferencebase                0
# overheadfingertipreachsitting        0
# palmlength                           0
# poplitealheight                      0
# radialestylionlength                 0
# shouldercircumference                0
# shoulderelbowlength                  0
# shoulderlength                       0
# sittingheight                        0
# sleevelengthspinewrist               0
# sleeveoutseam                        0
# span                                 0
# stature                              0
# suprasternaleheight                  0
# tenthribheight                       0
# thighcircumference                   0
# thighclearance                       0
# thumbtipreach                        0
# tibialheight                         0
# tragiontopofhead                     0
# trochanterionheight                  0
# verticaltrunkcircumferenceusa        0
# waistbacklength                      0
# waistbreadth                         0
# waistcircumference                   0
# waistdepth                           0
# waistfrontlengthsitting              0
# waistheightomphalion                 0
# weightkg                             0
# wristcircumference                   0
# wristheight                          0
# Gender                               0
# Date                                 0
# Installation                         0
# Component                            0
# Branch                               0
# PrimaryMOS                           0
# SubjectsBirthLocation                0
# SubjectNumericRace                   0
# Ethnicity                         4647
# DODRace                              0
# Age                                  0
# Heightin                             0
# Weightlbs                            0
# WritingPreference                    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
NaN_list =[]
for col in df.columns:
    if df[col].isnull().sum()>0:
        print("{name} = {qty}".format(name = col, qty = df[col].isnull().sum()))
        NaN_list.append(col)
# Out:
# Ethnicity = 4647

# %%
df.drop(columns='Ethnicity', inplace = True)

# %%
df.shape
# Out:
# (6068, 107)

# %%
df.head().T
# Out:
#                                            0               1               2  \
# subjectid                              10027           10032           10033
# abdominalextensiondepthsitting           266             233             287
# acromialheight                          1467            1395            1430
# acromionradialelength                    337             326             341
# anklecircumference                       222             220             230
# axillaheight                            1347            1293            1327
# balloffootcircumference                  253             245             256
# balloffootlength                         202             193             196
# biacromialbreadth                        401             394             427
# bicepscircumferenceflexed                369             338             408
# bicristalbreadth                         274             257             261
# bideltoidbreadth                         493             479             544
# bimalleolarbreadth                        71              67              75
# bitragionchinarc                         319             344             345
# bitragionsubmandibulararc                291             320             330
# bizygomaticbreadth                       142             135             135
# buttockcircumference                     979             944            1054
# buttockdepth                             240             232             258
# buttockheight                            882             870             901
# buttockkneelength                        619             584             623
# buttockpopliteallength                   509             468             506
# calfcircumference                        373             357             412
# cervicaleheight                         1535            1471            1501
# chestbreadth                             291             269             288
# chestcircumference                      1074            1021            1120
# chestdepth                               259             253             267
# chestheight                             1292            1244            1288
# crotchheight                             877             851             854
# crotchlengthomphalion                    607             615             636
# crotchlengthposterioromphalion           351             376             359
# earbreadth                                36              33              40
# earlength                                 71              62              61
# earprotrusion                             19              18              23
# elbowrestheight                          247             232             237
# eyeheightsitting                         802             781             810
# footbreadthhorizontal                    101              98             103
# footlength                               273             263             270
# forearmcenterofgriplength                349             348             355
# forearmcircumferenceflexed               299             289             357
# forearmforearmbreadth                    575             523             575
# forearmhandlength                        477             476             491
# functionalleglength                     1136            1096            1115
# handbreadth                               90              86              93
# handcircumference                        214             203             220
# handlength                               193             195             203
# headbreadth                              150             146             148
# headcircumference                        583             568             573
# headlength                               206             201             202
# heelanklecircumference                   326             334             356
# heelbreadth                               70              72              70
# hipbreadth                               332             312             349
# hipbreadthsitting                        366             356             393
# iliocristaleheight                      1071            1046            1053
# interpupillarybreadth                    685             620             665
# interscyei                               422             441             462
# interscyeii                              441             447             475
# kneeheightmidpatella                     502             490             496
# kneeheightsitting                        560             540             556
# lateralfemoralepicondyleheight           500             488             482
# lateralmalleolusheight                    77              73              72
# lowerthighcircumference                  391             371             409
# mentonsellionlength                      118             131             123
# neckcircumference                        400             380             403
# neckcircumferencebase                    436             420             434
# overheadfingertipreachsitting           1447            1380            1447
# palmlength                               113             118             121
# poplitealheight                          437             417             431
# radialestylionlength                     273             254             268
# shouldercircumference                   1151            1119            1276
# shoulderelbowlength                      368             353             367
# shoulderlength                           145             141             167
# sittingheight                            928             884             917
# sleevelengthspinewrist                   883             868             910
# sleeveoutseam                            600             564             604
# span                                    1782            1745            1867
# stature                                 1776            1702            1735
# suprasternaleheight                     1449            1387            1438
# tenthribheight                          1092            1076            1105
# thighcircumference                       610             572             685
# thighclearance                           164             169             198
# thumbtipreach                            786             822             807
# tibialheight                             491             476             477
# tragiontopofhead                         140             120             125
# trochanterionheight                      919             918             918
# verticaltrunkcircumferenceusa           1700            1627            1678
# waistbacklength                          501             432             472
# waistbreadth                             329             316             329
# waistcircumference                       933             870             964
# waistdepth                               240             225             255
# waistfrontlengthsitting                  440             371             411
# waistheightomphalion                    1054            1054            1041
# weightkg                                 815             726             929
# wristcircumference                       175             167             180
# wristheight                              853             815             831
# Gender                                  Male            Male            Male
# Date                                4-Oct-10        4-Oct-10        4-Oct-10
# Installation                       Fort Hood       Fort Hood       Fort Hood
# Component                       Regular Army    Regular Army    Regular Army
# Branch                           Combat Arms  Combat Support  Combat Support
# PrimaryMOS                               19D             68W             68W
# SubjectsBirthLocation           North Dakota        New York        New York
# SubjectNumericRace                         1               1               2
# DODRace                                    1               1               2
# Age                                       41              35              42
# Heightin                                  71              68              68
# Weightlbs                                180             160             205
# WritingPreference                 Right hand       Left hand       Left hand
#
#                                                      3                       4
# subjectid                                        10092                   10093
# abdominalextensiondepthsitting                     234                     250
# acromialheight                                    1347                    1585
# acromionradialelength                              310                     372
# anklecircumference                                 230                     247
# axillaheight                                      1239                    1478
# balloffootcircumference                            262                     267
# balloffootlength                                   199                     224
# biacromialbreadth                                  401                     435
# bicepscircumferenceflexed                          359                     356
# bicristalbreadth                                   262                     263
# bideltoidbreadth                                   518                     524
# bimalleolarbreadth                                  73                      80
# bitragionchinarc                                   328                     340
# bitragionsubmandibulararc                          309                     310
# bizygomaticbreadth                                 143                     138
# buttockcircumference                               991                    1029
# buttockdepth                                       242                     275
# buttockheight                                      821                    1080
# buttockkneelength                                  560                     706
# buttockpopliteallength                             437                     567
# calfcircumference                                  395                     425
# cervicaleheight                                   1423                    1684
# chestbreadth                                       296                     304
# chestcircumference                                1114                    1048
# chestdepth                                         262                     232
# chestheight                                       1205                    1452
# crotchheight                                       769                    1014
# crotchlengthomphalion                              590                     682
# crotchlengthposterioromphalion                     341                     382
# earbreadth                                          39                      32
# earlength                                           66                      56
# earprotrusion                                       25                      19
# elbowrestheight                                    272                     188
# eyeheightsitting                                   794                     814
# footbreadthhorizontal                              106                     111
# footlength                                         267                     305
# forearmcenterofgriplength                          352                     399
# forearmcircumferenceflexed                         318                     324
# forearmforearmbreadth                              593                     605
# forearmhandlength                                  467                     550
# functionalleglength                               1034                    1279
# handbreadth                                         91                      94
# handcircumference                                  217                     222
# handlength                                         194                     218
# headbreadth                                        158                     153
# headcircumference                                  576                     566
# headlength                                         199                     197
# heelanklecircumference                             341                     374
# heelbreadth                                         68                      69
# hipbreadth                                         338                     332
# hipbreadthsitting                                  367                     372
# iliocristaleheight                                 986                    1251
# interpupillarybreadth                              640                     675
# interscyei                                         458                     481
# interscyeii                                        461                     505
# kneeheightmidpatella                               460                     612
# kneeheightsitting                                  511                     666
# lateralfemoralepicondyleheight                     452                     585
# lateralmalleolusheight                              76                      85
# lowerthighcircumference                            393                     458
# mentonsellionlength                                106                     135
# neckcircumference                                  407                     398
# neckcircumferencebase                              446                     430
# overheadfingertipreachsitting                     1357                    1572
# palmlength                                         118                     132
# poplitealheight                                    393                     523
# radialestylionlength                               249                     302
# shouldercircumference                             1155                    1231
# shoulderelbowlength                                330                     400
# shoulderlength                                     148                     180
# sittingheight                                      903                     919
# sleevelengthspinewrist                             848                     995
# sleeveoutseam                                      550                     641
# span                                              1708                    2035
# stature                                           1655                    1914
# suprasternaleheight                               1346                    1596
# tenthribheight                                    1021                    1292
# thighcircumference                                 604                     672
# thighclearance                                     180                     194
# thumbtipreach                                      803                     962
# tibialheight                                       445                     584
# tragiontopofhead                                   127                     122
# trochanterionheight                                847                    1090
# verticaltrunkcircumferenceusa                     1625                    1679
# waistbacklength                                    461                     467
# waistbreadth                                       315                     303
# waistcircumference                                 857                     868
# waistdepth                                         205                     214
# waistfrontlengthsitting                            399                     379
# waistheightomphalion                               968                    1245
# weightkg                                           794                     946
# wristcircumference                                 176                     188
# wristheight                                        793                     954
# Gender                                            Male                    Male
# Date                                         12-Oct-10               12-Oct-10
# Installation                                 Fort Hood               Fort Hood
# Component                                 Regular Army            Regular Army
# Branch                          Combat Service Support  Combat Service Support
# PrimaryMOS                                         88M                     92G
# SubjectsBirthLocation                        Wisconsin          North Carolina
# SubjectNumericRace                                   1                       2
# DODRace                                              1                       2
# Age                                                 31                      21
# Heightin                                            66                      77
# Weightlbs                                          175                     213
# WritingPreference                           Right hand              Right hand

# %% [markdown]
# SubjectNumericRace – Subject Numeric Race; a single or multi-digit code
# indicating a subject’s self-reported race or races (verified through interview).
# Where 1 = White, 2 = Black, 3 = Hispanic, 4 = Asian, 5 = Native American,
# 6 = Pacific Islander, 8 = Other
#
# DODRace – Department of Defense Race; a single digit indicating a subject’s
# self-reported preferred single race where selecting multiple races is not an option.
# This variable is intended to be comparable to the Defense Manpower Data Center
# demographic data. Where 1 = White, 2 = Black, 3 = Hispanic, 4 = Asian,
# 5 = Native American, 6 = Pacific Islander, 8 = Other

# %%
df[["DODRace","SubjectNumericRace"]]
# Out:
#       DODRace  SubjectNumericRace
# 0           1                   1
# 1           1                   1
# 2           2                   2
# 3           1                   1
# 4           2                   2
# ...       ...                 ...
# 6063        3                   3
# 6064        3                   3
# 6065        2                   2
# 6066        3                   3
# 6067        3                   3
#
# [6068 rows x 2 columns]

# %%
df.drop("SubjectNumericRace", axis = 1, inplace = True)

# %%
df.DODRace.value_counts(dropna=False)
# Out:
# DODRace
# 1    3792
# 2    1298
# 3     679
# 4     188
# 6      59
# 5      49
# 8       3
# Name: count, dtype: int64

# %% [markdown]
# Drop DODRace class if value count below 500 (we assume that our data model can't learn if it is below 500)

# %%
# Count the values in the 'DODRace' column
race_counts = df['DODRace'].value_counts()

# Filter out the 'DODRace' values that have counts less than 500
filtered_races = race_counts[race_counts >= 500].index

# Keep only the rows where 'DODRace' is in the filtered_races
df = df[df['DODRace'].isin(filtered_races)]

# %%
df.DODRace.value_counts(dropna = False)
# Out:
# DODRace
# 1    3792
# 2    1298
# 3     679
# Name: count, dtype: int64

# %% [markdown]
# Heightin – Height in Inches; self-reported, comparable to measured “stature”
# Weightlbs – Weight in Pounds; self-reported, comparable to measured “weightkg”

# %% [markdown]
# https://www.thesoldiersproject.org/us-military-height-and-weight-requirements/#:~:text=The%20Minimum%20Height%20is%205%20feet%201%20inch,lbs%20while%20the%20Maximum%20Weight%20is%20241%20lbs
# ![Screenshot%202024-07-01%20010915.png](attachment:Screenshot%202024-07-01%20010915.png)

# %% [markdown]
# ![Screenshot%202024-07-01%20010922.png](attachment:Screenshot%202024-07-01%20010922.png)

# %%
df[['Weightlbs','weightkg']]
# Out:
#       Weightlbs  weightkg
# 0           180       815
# 1           160       726
# 2           205       929
# 3           175       794
# 4           213       946
# ...         ...       ...
# 6063        180       832
# 6064        150       717
# 6065        168       762
# 6066        133       632
# 6067        132       610
#
# [5769 rows x 2 columns]

# %%
df.Weightlbs.value_counts()
# Out:
# Weightlbs
# 170    224
# 180    219
# 150    216
# 175    204
# 160    203
# 185    202
# 165    194
# 190    186
# 200    173
# 155    154
# 210    147
# 140    146
# 195    142
# 145    140
# 135    117
# 220    113
# 215    109
# 130    100
# 205     96
# 225     76
# 230     71
# 148     55
# 125     53
# 168     53
# 178     52
# 120     49
# 240     48
# 158     46
# 187     44
# 138     43
# 235     42
# 198     41
# 153     41
# 167     35
# 174     35
# 162     35
# 173     34
# 128     34
# 127     33
# 250     33
# 147     33
# 143     32
# 172     32
# 169     32
# 152     31
# 183     31
# 156     31
# 188     31
# 182     31
# 157     31
# 154     30
# 137     30
# 193     29
# 184     28
# 194     28
# 197     28
# 163     28
# 196     28
# 142     27
# 192     26
# 181     26
# 177     26
# 132     25
# 176     24
# 245     22
# 161     22
# 212     22
# 115     21
# 203     21
# 133     21
# 186     21
# 164     21
# 218     21
# 189     20
# 110     20
# 204     20
# 208     19
# 166     19
# 171     19
# 124     18
# 139     18
# 118     18
# 149     18
# 136     18
# 179     18
# 141     18
# 206     18
# 207     18
# 260     17
# 144     17
# 134     16
# 255     16
# 116     16
# 209     15
# 213     15
# 126     14
# 146     13
# 202     13
# 214     12
# 122     12
# 123     12
# 201     12
# 159     12
# 129     11
# 191     11
# 242     10
# 270     10
# 228     10
# 211     10
# 131      9
# 238      9
# 223      9
# 217      9
# 222      9
# 114      8
# 105      8
# 265      8
# 117      8
# 247      7
# 226      7
# 280      7
# 224      7
# 103      6
# 227      6
# 199      6
# 151      6
# 219      6
# 236      6
# 275      6
# 221      6
# 112      6
# 119      6
# 108      5
# 100      5
# 229      5
# 121      5
# 111      4
# 233      4
# 239      4
# 237      4
# 248      4
# 241      4
# 285      4
# 257      3
# 216      3
# 95       3
# 113      3
# 244      3
# 109      3
# 253      3
# 232      3
# 106      3
# 300      3
# 107      2
# 102      2
# 234      2
# 104      2
# 246      2
# 231      2
# 249      2
# 279      2
# 310      2
# 254      2
# 259      1
# 96       1
# 86       1
# 90       1
# 98       1
# 283      1
# 268      1
# 315      1
# 290      1
# 256      1
# 252      1
# 243      1
# 251      1
# 258      1
# 276      1
# 267      1
# 88       1
# 293      1
# 272      1
# 321      1
# 0        1
# 274      1
# 295      1
# 292      1
# 101      1
# Name: count, dtype: int64

# %%
df.weightkg.value_counts()
# Out:
# weightkg
# 791     24
# 842     23
# 882     23
# 695     22
# 809     21
#         ..
# 1301     1
# 1202     1
# 1219     1
# 1265     1
# 464      1
# Name: count, Length: 774, dtype: int64

# %%
df. weightkg = df.weightkg / 10

# %%
df = df[(df.Weightlbs >=90) & (df.Weightlbs <= 220)]
df
# Out:
#       subjectid  abdominalextensiondepthsitting  acromialheight  \
# 0         10027                             266            1467
# 1         10032                             233            1395
# 2         10033                             287            1430
# 3         10092                             234            1347
# 4         10093                             250            1585
# ...         ...                             ...             ...
# 6063      29501                             285            1392
# 6064      29502                             262            1324
# 6065      29503                             260            1334
# 6066      29511                             205            1293
# 6067     920103                             238            1346
#
#       acromionradialelength  anklecircumference  axillaheight  \
# 0                       337                 222          1347
# 1                       326                 220          1293
# 2                       341                 230          1327
# 3                       310                 230          1239
# 4                       372                 247          1478
# ...                     ...                 ...           ...
# 6063                    335                 223          1297
# 6064                    301                 202          1204
# 6065                    318                 213          1259
# 6066                    302                 199          1207
# 6067                    308                 210          1256
#
#       balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                         253               202                401
# 1                         245               193                394
# 2                         256               196                427
# 3                         262               199                401
# 4                         267               224                435
# ...                       ...               ...                ...
# 6063                      252               196                368
# 6064                      236               181                378
# 6065                      234               183                363
# 6066                      213               163                376
# 6067                      236               188                361
#
#       bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  \
# 0                           369               274               493
# 1                           338               257               479
# 2                           408               261               544
# 3                           359               262               518
# 4                           356               263               524
# ...                         ...               ...               ...
# 6063                        299               312               477
# 6064                        294               287               468
# 6065                        332               299               460
# 6066                        276               280               426
# 6067                        285               279               433
#
#       bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  \
# 0                     71               319                        291
# 1                     67               344                        320
# 2                     75               345                        330
# 3                     73               328                        309
# 4                     80               340                        310
# ...                  ...               ...                        ...
# 6063                  72               306                        282
# 6064                  66               309                        311
# 6065                  70               317                        311
# 6066                  62               282                        267
# 6067                  71               304                        278
#
#       bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  \
# 0                    142                   979           240            882
# 1                    135                   944           232            870
# 2                    135                  1054           258            901
# 3                    143                   991           242            821
# 4                    138                  1029           275           1080
# ...                  ...                   ...           ...            ...
# 6063                 136                  1089           255            856
# 6064                 145                  1016           246            818
# 6065                 139                  1063           262            846
# 6066                 137                  1051           225            786
# 6067                 129                   974           217            820
#
#       buttockkneelength  buttockpopliteallength  calfcircumference  \
# 0                   619                     509                373
# 1                   584                     468                357
# 2                   623                     506                412
# 3                   560                     437                395
# 4                   706                     567                425
# ...                 ...                     ...                ...
# 6063                652                     541                373
# 6064                572                     464                375
# 6065                637                     525                370
# 6066                582                     480                370
# 6067                586                     479                343
#
#       cervicaleheight  chestbreadth  chestcircumference  chestdepth  \
# 0                1535           291                1074         259
# 1                1471           269                1021         253
# 2                1501           288                1120         267
# 3                1423           296                1114         262
# 4                1684           304                1048         232
# ...               ...           ...                 ...         ...
# 6063             1457           290                1082         293
# 6064             1390           291                1016         269
# 6065             1412           285                1093         286
# 6066             1377           270                 922         243
# 6067             1401           272                 902         219
#
#       chestheight  crotchheight  crotchlengthomphalion  \
# 0            1292           877                    607
# 1            1244           851                    615
# 2            1288           854                    636
# 3            1205           769                    590
# 4            1452          1014                    682
# ...           ...           ...                    ...
# 6063         1258           779                    732
# 6064         1151           732                    647
# 6065         1166           793                    609
# 6066         1137           763                    575
# 6067         1186           783                    536
#
#       crotchlengthposterioromphalion  earbreadth  earlength  earprotrusion  \
# 0                                351          36         71             19
# 1                                376          33         62             18
# 2                                359          40         61             23
# 3                                341          39         66             25
# 4                                382          32         56             19
# ...                              ...         ...        ...            ...
# 6063                             382          36         60             19
# 6064                             331          36         65             23
# 6065                             326          39         62             18
# 6066                             310          35         62             21
# 6067                             307          35         58             23
#
#       elbowrestheight  eyeheightsitting  footbreadthhorizontal  footlength  \
# 0                 247               802                    101         273
# 1                 232               781                     98         263
# 2                 237               810                    103         270
# 3                 272               794                    106         267
# 4                 188               814                    111         305
# ...               ...               ...                    ...         ...
# 6063              210               746                    103         259
# 6064              274               770                    101         245
# 6065              204               739                     97         249
# 6066              222               738                     91         226
# 6067              243               754                    100         239
#
#       forearmcenterofgriplength  forearmcircumferenceflexed  \
# 0                           349                         299
# 1                           348                         289
# 2                           355                         357
# 3                           352                         318
# 4                           399                         324
# ...                         ...                         ...
# 6063                        328                         262
# 6064                        319                         261
# 6065                        338                         288
# 6066                        306                         258
# 6067                        314                         259
#
#       forearmforearmbreadth  forearmhandlength  functionalleglength  \
# 0                       575                477                 1136
# 1                       523                476                 1096
# 2                       575                491                 1115
# 3                       593                467                 1034
# 4                       605                550                 1279
# ...                     ...                ...                  ...
# 6063                    514                456                 1085
# 6064                    514                440                  985
# 6065                    530                459                 1050
# 6066                    430                425                  995
# 6067                    464                439                 1053
#
#       handbreadth  handcircumference  handlength  headbreadth  \
# 0              90                214         193          150
# 1              86                203         195          146
# 2              93                220         203          148
# 3              91                217         194          158
# 4              94                222         218          153
# ...           ...                ...         ...          ...
# 6063           81                197         193          151
# 6064           81                196         183          160
# 6065           82                192         191          144
# 6066           74                177         176          149
# 6067           78                187         177          148
#
#       headcircumference  headlength  heelanklecircumference  heelbreadth  ...  \
# 0                   583         206                     326           70  ...
# 1                   568         201                     334           72  ...
# 2                   573         202                     356           70  ...
# 3                   576         199                     341           68  ...
# 4                   566         197                     374           69  ...
# ...                 ...         ...                     ...          ...  ...
# 6063                582         205                     321           75  ...
# 6064                570         186                     296           61  ...
# 6065                559         190                     318           72  ...
# 6066                558         186                     280           59  ...
# 6067                561         189                     310           78  ...
#
#       kneeheightmidpatella  kneeheightsitting  lateralfemoralepicondyleheight  \
# 0                      502                560                             500
# 1                      490                540                             488
# 2                      496                556                             482
# 3                      460                511                             452
# 4                      612                666                             585
# ...                    ...                ...                             ...
# 6063                   462                535                             486
# 6064                   433                483                             457
# 6065                   450                517                             476
# 6066                   432                491                             445
# 6067                   444                504                             445
#
#       lateralmalleolusheight  lowerthighcircumference  mentonsellionlength  \
# 0                         77                      391                  118
# 1                         73                      371                  131
# 2                         72                      409                  123
# 3                         76                      393                  106
# 4                         85                      458                  135
# ...                      ...                      ...                  ...
# 6063                      61                      423                  121
# 6064                      58                      383                  130
# 6065                      57                      412                  111
# 6066                      58                      400                  119
# 6067                      66                      372                  114
#
#       neckcircumference  neckcircumferencebase  overheadfingertipreachsitting  \
# 0                   400                    436                           1447
# 1                   380                    420                           1380
# 2                   403                    434                           1447
# 3                   407                    446                           1357
# 4                   398                    430                           1572
# ...                 ...                    ...                            ...
# 6063                369                    391                           1307
# 6064                359                    399                           1323
# 6065                352                    402                           1318
# 6066                326                    380                           1286
# 6067                325                    381                           1372
#
#       palmlength  poplitealheight  radialestylionlength  \
# 0            113              437                   273
# 1            118              417                   254
# 2            121              431                   268
# 3            118              393                   249
# 4            132              523                   302
# ...          ...              ...                   ...
# 6063         118              414                   237
# 6064          99              377                   237
# 6065         116              392                   259
# 6066         111              375                   230
# 6067         112              390                   249
#
#       shouldercircumference  shoulderelbowlength  shoulderlength  \
# 0                      1151                  368             145
# 1                      1119                  353             141
# 2                      1276                  367             167
# 3                      1155                  330             148
# 4                      1231                  400             180
# ...                     ...                  ...             ...
# 6063                   1036                  354             145
# 6064                   1051                  318             142
# 6065                   1054                  338             136
# 6066                    996                  321             136
# 6067                    997                  339             135
#
#       sittingheight  sleevelengthspinewrist  sleeveoutseam  span  stature  \
# 0               928                     883            600  1782     1776
# 1               884                     868            564  1745     1702
# 2               917                     910            604  1867     1735
# 3               903                     848            550  1708     1655
# 4               919                     995            641  2035     1914
# ...             ...                     ...            ...   ...      ...
# 6063            865                     840            555  1716     1687
# 6064            881                     794            525  1620     1613
# 6065            841                     848            566  1740     1644
# 6066            854                     791            530  1628     1616
# 6067            861                     821            542  1685     1641
#
#       suprasternaleheight  tenthribheight  thighcircumference  thighclearance  \
# 0                    1449            1092                 610             164
# 1                    1387            1076                 572             169
# 2                    1438            1105                 685             198
# 3                    1346            1021                 604             180
# 4                    1596            1292                 672             194
# ...                   ...             ...                 ...             ...
# 6063                 1391            1119                 660             155
# 6064                 1316            1043                 616             157
# 6065                 1337            1054                 640             159
# 6066                 1288            1028                 623             163
# 6067                 1334            1089                 592             162
#
#       thumbtipreach  tibialheight  tragiontopofhead  trochanterionheight  \
# 0               786           491               140                  919
# 1               822           476               120                  918
# 2               807           477               125                  918
# 3               803           445               127                  847
# 4               962           584               122                 1090
# ...             ...           ...               ...                  ...
# 6063            749           446               136                  872
# 6064            721           422               131                  838
# 6065            758           449               127                  862
# 6066            725           419               135                  802
# 6067            762           436               130                  849
#
#       verticaltrunkcircumferenceusa  waistbacklength  waistbreadth  \
# 0                              1700              501           329
# 1                              1627              432           316
# 2                              1678              472           329
# 3                              1625              461           315
# 4                              1679              467           303
# ...                             ...              ...           ...
# 6063                           1706              447           334
# 6064                           1648              446           334
# 6065                           1590              444           335
# 6066                           1525              450           298
# 6067                           1547              462           299
#
#       waistcircumference  waistdepth  waistfrontlengthsitting  \
# 0                    933         240                      440
# 1                    870         225                      371
# 2                    964         255                      411
# 3                    857         205                      399
# 4                    868         214                      379
# ...                  ...         ...                      ...
# 6063                1043         265                      370
# 6064                 971         243                      374
# 6065                 982         254                      351
# 6066                 837         208                      335
# 6067                 891         223                      394
#
#       waistheightomphalion  weightkg  wristcircumference  wristheight  Gender  \
# 0                     1054    81.500                 175          853    Male
# 1                     1054    72.600                 167          815    Male
# 2                     1041    92.900                 180          831    Male
# 3                      968    79.400                 176          793    Male
# 4                     1245    94.600                 188          954    Male
# ...                    ...       ...                 ...          ...     ...
# 6063                  1002    83.200                 162          836  Female
# 6064                   958    71.700                 157          804  Female
# 6065                   970    76.200                 159          774  Female
# 6066                   952    63.200                 146          769  Female
# 6067                   943    61.000                 154          797  Female
#
#            Date  Installation            Component                  Branch  \
# 0      4-Oct-10     Fort Hood         Regular Army             Combat Arms
# 1      4-Oct-10     Fort Hood         Regular Army          Combat Support
# 2      4-Oct-10     Fort Hood         Regular Army          Combat Support
# 3     12-Oct-10     Fort Hood         Regular Army  Combat Service Support
# 4     12-Oct-10     Fort Hood         Regular Army  Combat Service Support
# ...         ...           ...                  ...                     ...
# 6063   5-Apr-12   Camp Shelby  Army National Guard          Combat Support
# 6064   5-Apr-12   Camp Shelby  Army National Guard          Combat Support
# 6065   5-Apr-12   Camp Shelby  Army National Guard          Combat Support
# 6066   5-Apr-12   Camp Shelby  Army National Guard          Combat Support
# 6067  28-May-11    Fort McCoy  Army National Guard          Combat Support
#
#       PrimaryMOS SubjectsBirthLocation DODRace Age Heightin Weightlbs  \
# 0            19D          North Dakota       1  41       71       180
# 1            68W              New York       1  35       68       160
# 2            68W              New York       2  42       68       205
# 3            88M             Wisconsin       1  31       66       175
# 4            92G        North Carolina       2  21       77       213
# ...          ...                   ...     ...  ..      ...       ...
# 6063         42A                 Texas       3  51       67       180
# 6064         25U                 Texas       3  40       63       150
# 6065         42A                 Texas       2  40       66       168
# 6066         92Y                 Texas       3  31       63       133
# 6067         92F                 Texas       3  27       66       132
#
#      WritingPreference
# 0           Right hand
# 1            Left hand
# 2            Left hand
# 3           Right hand
# 4           Right hand
# ...                ...
# 6063        Right hand
# 6064        Right hand
# 6065        Right hand
# 6066        Right hand
# 6067        Right hand
#
# [5248 rows x 106 columns]

# %%
df.Heightin.value_counts(dropna = False)
# Out:
# Heightin
# 69    566
# 66    516
# 70    503
# 68    493
# 67    477
# 71    455
# 72    382
# 64    368
# 65    297
# 63    248
# 73    221
# 62    208
# 74    165
# 61     89
# 60     72
# 75     70
# 76     37
# 59     29
# 77     19
# 78      9
# 80      6
# 57      5
# 58      4
# 79      3
# 81      2
# 94      1
# 56      1
# 87      1
# 86      1
# Name: count, dtype: int64

# %%
df[['Heightin', 'stature']]
# Out:
#       Heightin  stature
# 0           71     1776
# 1           68     1702
# 2           68     1735
# 3           66     1655
# 4           77     1914
# ...        ...      ...
# 6063        67     1687
# 6064        63     1613
# 6065        66     1644
# 6066        63     1616
# 6067        66     1641
#
# [5248 rows x 2 columns]

# %%
df = df[(df.Heightin >= 58) & (df.Heightin <= 84)]

# %%
df
# Out:
#       subjectid  abdominalextensiondepthsitting  acromialheight  \
# 0         10027                             266            1467
# 1         10032                             233            1395
# 2         10033                             287            1430
# 3         10092                             234            1347
# 4         10093                             250            1585
# ...         ...                             ...             ...
# 6063      29501                             285            1392
# 6064      29502                             262            1324
# 6065      29503                             260            1334
# 6066      29511                             205            1293
# 6067     920103                             238            1346
#
#       acromionradialelength  anklecircumference  axillaheight  \
# 0                       337                 222          1347
# 1                       326                 220          1293
# 2                       341                 230          1327
# 3                       310                 230          1239
# 4                       372                 247          1478
# ...                     ...                 ...           ...
# 6063                    335                 223          1297
# 6064                    301                 202          1204
# 6065                    318                 213          1259
# 6066                    302                 199          1207
# 6067                    308                 210          1256
#
#       balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                         253               202                401
# 1                         245               193                394
# 2                         256               196                427
# 3                         262               199                401
# 4                         267               224                435
# ...                       ...               ...                ...
# 6063                      252               196                368
# 6064                      236               181                378
# 6065                      234               183                363
# 6066                      213               163                376
# 6067                      236               188                361
#
#       bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  \
# 0                           369               274               493
# 1                           338               257               479
# 2                           408               261               544
# 3                           359               262               518
# 4                           356               263               524
# ...                         ...               ...               ...
# 6063                        299               312               477
# 6064                        294               287               468
# 6065                        332               299               460
# 6066                        276               280               426
# 6067                        285               279               433
#
#       bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  \
# 0                     71               319                        291
# 1                     67               344                        320
# 2                     75               345                        330
# 3                     73               328                        309
# 4                     80               340                        310
# ...                  ...               ...                        ...
# 6063                  72               306                        282
# 6064                  66               309                        311
# 6065                  70               317                        311
# 6066                  62               282                        267
# 6067                  71               304                        278
#
#       bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  \
# 0                    142                   979           240            882
# 1                    135                   944           232            870
# 2                    135                  1054           258            901
# 3                    143                   991           242            821
# 4                    138                  1029           275           1080
# ...                  ...                   ...           ...            ...
# 6063                 136                  1089           255            856
# 6064                 145                  1016           246            818
# 6065                 139                  1063           262            846
# 6066                 137                  1051           225            786
# 6067                 129                   974           217            820
#
#       buttockkneelength  buttockpopliteallength  calfcircumference  \
# 0                   619                     509                373
# 1                   584                     468                357
# 2                   623                     506                412
# 3                   560                     437                395
# 4                   706                     567                425
# ...                 ...                     ...                ...
# 6063                652                     541                373
# 6064                572                     464                375
# 6065                637                     525                370
# 6066                582                     480                370
# 6067                586                     479                343
#
#       cervicaleheight  chestbreadth  chestcircumference  chestdepth  \
# 0                1535           291                1074         259
# 1                1471           269                1021         253
# 2                1501           288                1120         267
# 3                1423           296                1114         262
# 4                1684           304                1048         232
# ...               ...           ...                 ...         ...
# 6063             1457           290                1082         293
# 6064             1390           291                1016         269
# 6065             1412           285                1093         286
# 6066             1377           270                 922         243
# 6067             1401           272                 902         219
#
#       chestheight  crotchheight  crotchlengthomphalion  \
# 0            1292           877                    607
# 1            1244           851                    615
# 2            1288           854                    636
# 3            1205           769                    590
# 4            1452          1014                    682
# ...           ...           ...                    ...
# 6063         1258           779                    732
# 6064         1151           732                    647
# 6065         1166           793                    609
# 6066         1137           763                    575
# 6067         1186           783                    536
#
#       crotchlengthposterioromphalion  earbreadth  earlength  earprotrusion  \
# 0                                351          36         71             19
# 1                                376          33         62             18
# 2                                359          40         61             23
# 3                                341          39         66             25
# 4                                382          32         56             19
# ...                              ...         ...        ...            ...
# 6063                             382          36         60             19
# 6064                             331          36         65             23
# 6065                             326          39         62             18
# 6066                             310          35         62             21
# 6067                             307          35         58             23
#
#       elbowrestheight  eyeheightsitting  footbreadthhorizontal  footlength  \
# 0                 247               802                    101         273
# 1                 232               781                     98         263
# 2                 237               810                    103         270
# 3                 272               794                    106         267
# 4                 188               814                    111         305
# ...               ...               ...                    ...         ...
# 6063              210               746                    103         259
# 6064              274               770                    101         245
# 6065              204               739                     97         249
# 6066              222               738                     91         226
# 6067              243               754                    100         239
#
#       forearmcenterofgriplength  forearmcircumferenceflexed  \
# 0                           349                         299
# 1                           348                         289
# 2                           355                         357
# 3                           352                         318
# 4                           399                         324
# ...                         ...                         ...
# 6063                        328                         262
# 6064                        319                         261
# 6065                        338                         288
# 6066                        306                         258
# 6067                        314                         259
#
#       forearmforearmbreadth  forearmhandlength  functionalleglength  \
# 0                       575                477                 1136
# 1                       523                476                 1096
# 2                       575                491                 1115
# 3                       593                467                 1034
# 4                       605                550                 1279
# ...                     ...                ...                  ...
# 6063                    514                456                 1085
# 6064                    514                440                  985
# 6065                    530                459                 1050
# 6066                    430                425                  995
# 6067                    464                439                 1053
#
#       handbreadth  handcircumference  handlength  headbreadth  \
# 0              90                214         193          150
# 1              86                203         195          146
# 2              93                220         203          148
# 3              91                217         194          158
# 4              94                222         218          153
# ...           ...                ...         ...          ...
# 6063           81                197         193          151
# 6064           81                196         183          160
# 6065           82                192         191          144
# 6066           74                177         176          149
# 6067           78                187         177          148
#
#       headcircumference  headlength  heelanklecircumference  heelbreadth  ...  \
# 0                   583         206                     326           70  ...
# 1                   568         201                     334           72  ...
# 2                   573         202                     356           70  ...
# 3                   576         199                     341           68  ...
# 4                   566         197                     374           69  ...
# ...                 ...         ...                     ...          ...  ...
# 6063                582         205                     321           75  ...
# 6064                570         186                     296           61  ...
# 6065                559         190                     318           72  ...
# 6066                558         186                     280           59  ...
# 6067                561         189                     310           78  ...
#
#       kneeheightmidpatella  kneeheightsitting  lateralfemoralepicondyleheight  \
# 0                      502                560                             500
# 1                      490                540                             488
# 2                      496                556                             482
# 3                      460                511                             452
# 4                      612                666                             585
# ...                    ...                ...                             ...
# 6063                   462                535                             486
# 6064                   433                483                             457
# 6065                   450                517                             476
# 6066                   432                491                             445
# 6067                   444                504                             445
#
#       lateralmalleolusheight  lowerthighcircumference  mentonsellionlength  \
# 0                         77                      391                  118
# 1                         73                      371                  131
# 2                         72                      409                  123
# 3                         76                      393                  106
# 4                         85                      458                  135
# ...                      ...                      ...                  ...
# 6063                      61                      423                  121
# 6064                      58                      383                  130
# 6065                      57                      412                  111
# 6066                      58                      400                  119
# 6067                      66                      372                  114
#
#       neckcircumference  neckcircumferencebase  overheadfingertipreachsitting  \
# 0                   400                    436                           1447
# 1                   380                    420                           1380
# 2                   403                    434                           1447
# 3                   407                    446                           1357
# 4                   398                    430                           1572
# ...                 ...                    ...                            ...
# 6063                369                    391                           1307
# 6064                359                    399                           1323
# 6065                352                    402                           1318
# 6066                326                    380                           1286
# 6067                325                    381                           1372
#
#       palmlength  poplitealheight  radialestylionlength  \
# 0            113              437                   273
# 1            118              417                   254
# 2            121              431                   268
# 3            118              393                   249
# 4            132              523                   302
# ...          ...              ...                   ...
# 6063         118              414                   237
# 6064          99              377                   237
# 6065         116              392                   259
# 6066         111              375                   230
# 6067         112              390                   249
#
#       shouldercircumference  shoulderelbowlength  shoulderlength  \
# 0                      1151                  368             145
# 1                      1119                  353             141
# 2                      1276                  367             167
# 3                      1155                  330             148
# 4                      1231                  400             180
# ...                     ...                  ...             ...
# 6063                   1036                  354             145
# 6064                   1051                  318             142
# 6065                   1054                  338             136
# 6066                    996                  321             136
# 6067                    997                  339             135
#
#       sittingheight  sleevelengthspinewrist  sleeveoutseam  span  stature  \
# 0               928                     883            600  1782     1776
# 1               884                     868            564  1745     1702
# 2               917                     910            604  1867     1735
# 3               903                     848            550  1708     1655
# 4               919                     995            641  2035     1914
# ...             ...                     ...            ...   ...      ...
# 6063            865                     840            555  1716     1687
# 6064            881                     794            525  1620     1613
# 6065            841                     848            566  1740     1644
# 6066            854                     791            530  1628     1616
# 6067            861                     821            542  1685     1641
#
#       suprasternaleheight  tenthribheight  thighcircumference  thighclearance  \
# 0                    1449            1092                 610             164
# 1                    1387            1076                 572             169
# 2                    1438            1105                 685             198
# 3                    1346            1021                 604             180
# 4                    1596            1292                 672             194
# ...                   ...             ...                 ...             ...
# 6063                 1391            1119                 660             155
# 6064                 1316            1043                 616             157
# 6065                 1337            1054                 640             159
# 6066                 1288            1028                 623             163
# 6067                 1334            1089                 592             162
#
#       thumbtipreach  tibialheight  tragiontopofhead  trochanterionheight  \
# 0               786           491               140                  919
# 1               822           476               120                  918
# 2               807           477               125                  918
# 3               803           445               127                  847
# 4               962           584               122                 1090
# ...             ...           ...               ...                  ...
# 6063            749           446               136                  872
# 6064            721           422               131                  838
# 6065            758           449               127                  862
# 6066            725           419               135                  802
# 6067            762           436               130                  849
#
#       verticaltrunkcircumferenceusa  waistbacklength  waistbreadth  \
# 0                              1700              501           329
# 1                              1627              432           316
# 2                              1678              472           329
# 3                              1625              461           315
# 4                              1679              467           303
# ...                             ...              ...           ...
# 6063                           1706              447           334
# 6064                           1648              446           334
# 6065                           1590              444           335
# 6066                           1525              450           298
# 6067                           1547              462           299
#
#       waistcircumference  waistdepth  waistfrontlengthsitting  \
# 0                    933         240                      440
# 1                    870         225                      371
# 2                    964         255                      411
# 3                    857         205                      399
# 4                    868         214                      379
# ...                  ...         ...                      ...
# 6063                1043         265                      370
# 6064                 971         243                      374
# 6065                 982         254                      351
# 6066                 837         208                      335
# 6067                 891         223                      394
#
#       waistheightomphalion  weightkg  wristcircumference  wristheight  Gender  \
# 0                     1054    81.500                 175          853    Male
# 1                     1054    72.600                 167          815    Male
# 2                     1041    92.900                 180          831    Male
# 3                      968    79.400                 176          793    Male
# 4                     1245    94.600                 188          954    Male
# ...                    ...       ...                 ...          ...     ...
# 6063                  1002    83.200                 162          836  Female
# 6064                   958    71.700                 157          804  Female
# 6065                   970    76.200                 159          774  Female
# 6066                   952    63.200                 146          769  Female
# 6067                   943    61.000                 154          797  Female
#
#            Date  Installation            Component                  Branch  \
# 0      4-Oct-10     Fort Hood         Regular Army             Combat Arms
# 1      4-Oct-10     Fort Hood         Regular Army          Combat Support
# 2      4-Oct-10     Fort Hood         Regular Army          Combat Support
# 3     12-Oct-10     Fort Hood         Regular Army  Combat Service Support
# 4     12-Oct-10     Fort Hood         Regular Army  Combat Service Support
# ...         ...           ...                  ...                     ...
# 6063   5-Apr-12   Camp Shelby  Army National Guard          Combat Support
# 6064   5-Apr-12   Camp Shelby  Army National Guard          Combat Support
# 6065   5-Apr-12   Camp Shelby  Army National Guard          Combat Support
# 6066   5-Apr-12   Camp Shelby  Army National Guard          Combat Support
# 6067  28-May-11    Fort McCoy  Army National Guard          Combat Support
#
#       PrimaryMOS SubjectsBirthLocation DODRace Age Heightin Weightlbs  \
# 0            19D          North Dakota       1  41       71       180
# 1            68W              New York       1  35       68       160
# 2            68W              New York       2  42       68       205
# 3            88M             Wisconsin       1  31       66       175
# 4            92G        North Carolina       2  21       77       213
# ...          ...                   ...     ...  ..      ...       ...
# 6063         42A                 Texas       3  51       67       180
# 6064         25U                 Texas       3  40       63       150
# 6065         42A                 Texas       2  40       66       168
# 6066         92Y                 Texas       3  31       63       133
# 6067         92F                 Texas       3  27       66       132
#
#      WritingPreference
# 0           Right hand
# 1            Left hand
# 2            Left hand
# 3           Right hand
# 4           Right hand
# ...                ...
# 6063        Right hand
# 6064        Right hand
# 6065        Right hand
# 6066        Right hand
# 6067        Right hand
#
# [5239 rows x 106 columns]

# %% [markdown]
# I've found 2 columns with the same information about weight in my dataset.Since the 'weightlbs','weightkg' columns give similar values, I drop the 'weightkg' column.

# %%
df.drop(["Weightlbs"], axis = 1, inplace=True)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#    subjectid  abdominalextensiondepthsitting  acromialheight  \
# 0      10027                             266            1467
# 1      10032                             233            1395
# 2      10033                             287            1430
# 3      10092                             234            1347
# 4      10093                             250            1585
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    337                 222          1347
# 1                    326                 220          1293
# 2                    341                 230          1327
# 3                    310                 230          1239
# 4                    372                 247          1478
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      253               202                401
# 1                      245               193                394
# 2                      256               196                427
# 3                      262               199                401
# 4                      267               224                435
#
#    bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  \
# 0                        369               274               493
# 1                        338               257               479
# 2                        408               261               544
# 3                        359               262               518
# 4                        356               263               524
#
#    bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  \
# 0                  71               319                        291
# 1                  67               344                        320
# 2                  75               345                        330
# 3                  73               328                        309
# 4                  80               340                        310
#
#    bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  \
# 0                 142                   979           240            882
# 1                 135                   944           232            870
# 2                 135                  1054           258            901
# 3                 143                   991           242            821
# 4                 138                  1029           275           1080
#
#    buttockkneelength  buttockpopliteallength  calfcircumference  \
# 0                619                     509                373
# 1                584                     468                357
# 2                623                     506                412
# 3                560                     437                395
# 4                706                     567                425
#
#    cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  \
# 0             1535           291                1074         259         1292
# 1             1471           269                1021         253         1244
# 2             1501           288                1120         267         1288
# 3             1423           296                1114         262         1205
# 4             1684           304                1048         232         1452
#
#    crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion  \
# 0           877                    607                             351
# 1           851                    615                             376
# 2           854                    636                             359
# 3           769                    590                             341
# 4          1014                    682                             382
#
#    earbreadth  earlength  earprotrusion  elbowrestheight  eyeheightsitting  \
# 0          36         71             19              247               802
# 1          33         62             18              232               781
# 2          40         61             23              237               810
# 3          39         66             25              272               794
# 4          32         56             19              188               814
#
#    footbreadthhorizontal  footlength  forearmcenterofgriplength  \
# 0                    101         273                        349
# 1                     98         263                        348
# 2                    103         270                        355
# 3                    106         267                        352
# 4                    111         305                        399
#
#    forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  \
# 0                         299                    575                477
# 1                         289                    523                476
# 2                         357                    575                491
# 3                         318                    593                467
# 4                         324                    605                550
#
#    functionalleglength  handbreadth  handcircumference  handlength  \
# 0                 1136           90                214         193
# 1                 1096           86                203         195
# 2                 1115           93                220         203
# 3                 1034           91                217         194
# 4                 1279           94                222         218
#
#    headbreadth  headcircumference  headlength  heelanklecircumference  \
# 0          150                583         206                     326
# 1          146                568         201                     334
# 2          148                573         202                     356
# 3          158                576         199                     341
# 4          153                566         197                     374
#
#    heelbreadth  ...  interscyeii  kneeheightmidpatella  kneeheightsitting  \
# 0           70  ...          441                   502                560
# 1           72  ...          447                   490                540
# 2           70  ...          475                   496                556
# 3           68  ...          461                   460                511
# 4           69  ...          505                   612                666
#
#    lateralfemoralepicondyleheight  lateralmalleolusheight  \
# 0                             500                      77
# 1                             488                      73
# 2                             482                      72
# 3                             452                      76
# 4                             585                      85
#
#    lowerthighcircumference  mentonsellionlength  neckcircumference  \
# 0                      391                  118                400
# 1                      371                  131                380
# 2                      409                  123                403
# 3                      393                  106                407
# 4                      458                  135                398
#
#    neckcircumferencebase  overheadfingertipreachsitting  palmlength  \
# 0                    436                           1447         113
# 1                    420                           1380         118
# 2                    434                           1447         121
# 3                    446                           1357         118
# 4                    430                           1572         132
#
#    poplitealheight  radialestylionlength  shouldercircumference  \
# 0              437                   273                   1151
# 1              417                   254                   1119
# 2              431                   268                   1276
# 3              393                   249                   1155
# 4              523                   302                   1231
#
#    shoulderelbowlength  shoulderlength  sittingheight  sleevelengthspinewrist  \
# 0                  368             145            928                     883
# 1                  353             141            884                     868
# 2                  367             167            917                     910
# 3                  330             148            903                     848
# 4                  400             180            919                     995
#
#    sleeveoutseam  span  stature  suprasternaleheight  tenthribheight  \
# 0            600  1782     1776                 1449            1092
# 1            564  1745     1702                 1387            1076
# 2            604  1867     1735                 1438            1105
# 3            550  1708     1655                 1346            1021
# 4            641  2035     1914                 1596            1292
#
#    thighcircumference  thighclearance  thumbtipreach  tibialheight  \
# 0                 610             164            786           491
# 1                 572             169            822           476
# 2                 685             198            807           477
# 3                 604             180            803           445
# 4                 672             194            962           584
#
#    tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  \
# 0               140                  919                           1700
# 1               120                  918                           1627
# 2               125                  918                           1678
# 3               127                  847                           1625
# 4               122                 1090                           1679
#
#    waistbacklength  waistbreadth  waistcircumference  waistdepth  \
# 0              501           329                 933         240
# 1              432           316                 870         225
# 2              472           329                 964         255
# 3              461           315                 857         205
# 4              467           303                 868         214
#
#    waistfrontlengthsitting  waistheightomphalion  weightkg  \
# 0                      440                  1054    81.500
# 1                      371                  1054    72.600
# 2                      411                  1041    92.900
# 3                      399                   968    79.400
# 4                      379                  1245    94.600
#
#    wristcircumference  wristheight  Gender       Date  Installation  \
# 0                 175          853    Male   4-Oct-10     Fort Hood
# 1                 167          815    Male   4-Oct-10     Fort Hood
# 2                 180          831    Male   4-Oct-10     Fort Hood
# 3                 176          793    Male  12-Oct-10     Fort Hood
# 4                 188          954    Male  12-Oct-10     Fort Hood
#
#       Component                  Branch PrimaryMOS SubjectsBirthLocation  \
# 0  Regular Army             Combat Arms        19D          North Dakota
# 1  Regular Army          Combat Support        68W              New York
# 2  Regular Army          Combat Support        68W              New York
# 3  Regular Army  Combat Service Support        88M             Wisconsin
# 4  Regular Army  Combat Service Support        92G        North Carolina
#
#   DODRace Age Heightin WritingPreference
# 0       1  41       71        Right hand
# 1       1  35       68         Left hand
# 2       2  42       68         Left hand
# 3       1  31       66        Right hand
# 4       2  21       77        Right hand
#
# [5 rows x 105 columns]

# %%
df.shape
# Out:
# (5239, 105)

# %%
df.drop(["Heightin"], axis = 1, inplace=True)

# %% [markdown]
# # Let's examine object columns

# %%
df.select_dtypes(include=['object'])
# Out:
#       Gender       Date Installation            Component  \
# 0       Male   4-Oct-10    Fort Hood         Regular Army
# 1       Male   4-Oct-10    Fort Hood         Regular Army
# 2       Male   4-Oct-10    Fort Hood         Regular Army
# 3       Male  12-Oct-10    Fort Hood         Regular Army
# 4       Male  12-Oct-10    Fort Hood         Regular Army
# ...      ...        ...          ...                  ...
# 5234  Female   5-Apr-12  Camp Shelby  Army National Guard
# 5235  Female   5-Apr-12  Camp Shelby  Army National Guard
# 5236  Female   5-Apr-12  Camp Shelby  Army National Guard
# 5237  Female   5-Apr-12  Camp Shelby  Army National Guard
# 5238  Female  28-May-11   Fort McCoy  Army National Guard
#
#                       Branch PrimaryMOS SubjectsBirthLocation  \
# 0                Combat Arms        19D          North Dakota
# 1             Combat Support        68W              New York
# 2             Combat Support        68W              New York
# 3     Combat Service Support        88M             Wisconsin
# 4     Combat Service Support        92G        North Carolina
# ...                      ...        ...                   ...
# 5234          Combat Support        42A                 Texas
# 5235          Combat Support        25U                 Texas
# 5236          Combat Support        42A                 Texas
# 5237          Combat Support        92Y                 Texas
# 5238          Combat Support        92F                 Texas
#
#      WritingPreference
# 0           Right hand
# 1            Left hand
# 2            Left hand
# 3           Right hand
# 4           Right hand
# ...                ...
# 5234        Right hand
# 5235        Right hand
# 5236        Right hand
# 5237        Right hand
# 5238        Right hand
#
# [5239 rows x 8 columns]

# %%
df.select_dtypes(include=['object']).columns
# Out:
# Index(['Gender', 'Date', 'Installation', 'Component', 'Branch', 'PrimaryMOS',
#        'SubjectsBirthLocation', 'WritingPreference'],
#       dtype='object')

# %%
for col in df.select_dtypes(include=['object']).columns:
    print(f"{col} has {df[col].nunique()} unique value")
# Out:
# Gender has 2 unique value
# Date has 253 unique value
# Installation has 12 unique value
# Component has 3 unique value
# Branch has 3 unique value
# PrimaryMOS has 275 unique value
# SubjectsBirthLocation has 133 unique value
# WritingPreference has 3 unique value

# %% [markdown]
# # Installation

# %% [markdown]
# – U.S. Army installation where the measurement occurred;

# %%
df.Installation.value_counts()
# Out:
# Installation
# Camp Shelby       1020
# Fort Bliss         829
# Fort Gordon        615
# Fort McCoy         381
# Camp Atterbury     366
# Fort Hood          360
# Fort Huachuca      360
# Fort Lee           352
# Fort Bragg         348
# Fort Drum          316
# Fort Stewart       291
# Fort Rucker          1
# Name: count, dtype: int64

# %% [markdown]
# Since the Intallation column is not a column that directly affects DODRace and I do not want to increase the number of columns when we make a dummy, I drop this column.

# %%
df.drop(columns='Installation', axis = 1 , inplace=True)

# %% [markdown]
# # Date

# %% [markdown]
# Date – Date the participant was measured, ranging from “04-Oct-10” to “05-Apr-12”

# %%
df.Date.nunique()
# Out:
# 253

# %%
df.drop(columns='Date', inplace = True)

# %%
df.drop(columns= ["Component","PrimaryMOS", 'Branch'], inplace= True)

# %%
df.shape
# Out:
# (5239, 99)

# %%
df.drop(columns = 'subjectid', inplace = True)

# %%
df.shape
# Out:
# (5239, 98)

# %%
df["DODRace"] = df.DODRace.map({1 : "White", 2 : "Black", 3 : "Hispanic"})
df.DODRace.value_counts()
# Out:
# DODRace
# White       3425
# Black       1174
# Hispanic     640
# Name: count, dtype: int64

# %%
df.select_dtypes(include = 'O')
# Out:
#       Gender SubjectsBirthLocation   DODRace WritingPreference
# 0       Male          North Dakota     White        Right hand
# 1       Male              New York     White         Left hand
# 2       Male              New York     Black         Left hand
# 3       Male             Wisconsin     White        Right hand
# 4       Male        North Carolina     Black        Right hand
# ...      ...                   ...       ...               ...
# 5234  Female                 Texas  Hispanic        Right hand
# 5235  Female                 Texas  Hispanic        Right hand
# 5236  Female                 Texas     Black        Right hand
# 5237  Female                 Texas  Hispanic        Right hand
# 5238  Female                 Texas  Hispanic        Right hand
#
# [5239 rows x 4 columns]

# %%
df.SubjectsBirthLocation.value_counts(dropna = True)
# Out:
# SubjectsBirthLocation
# California                384
# New York                  374
# Texas                     355
# Indiana                   228
# Florida                   194
# Oklahoma                  190
# Illinois                  185
# Minnesota                 179
# Michigan                  168
# Mississippi               161
# Georgia                   153
# Alabama                   146
# South Carolina            144
# North Carolina            135
# Ohio                      129
# Louisiana                 126
# Pennsylvania              117
# Virginia                  106
# Massachusetts             103
# Germany                    86
# New Jersey                 84
# Wisconsin                  83
# Puerto Rico                80
# Missouri                   75
# Maryland                   74
# Arizona                    71
# Tennessee                  70
# Colorado                   69
# Kentucky                   58
# Kansas                     56
# Washington                 55
# Arkansas                   48
# Iowa                       47
# South Dakota               44
# Mexico                     39
# Jamaica                    34
# Oregon                     34
# Connecticut                32
# Nebraska                   25
# Utah                       25
# West Virginia              23
# Nevada                     21
# District of Columbia       19
# Hawaii                     18
# Idaho                      17
# Delaware                   16
# Rhode Island               16
# North Dakota               16
# New Mexico                 16
# Maine                      15
# Dominican Republic         15
# Vermont                    13
# Colombia                   13
# Haiti                      12
# New Hampshire              11
# United Kingdom             11
# Montana                    10
# Panama                      9
# Canada                      8
# Russia                      8
# Peru                        8
# Trinidad and Tobago         7
# Japan                       7
# Ukraine                     7
# Alaska                      7
# Liberia                     6
# US Virgin Islands           6
# Wyoming                     6
# El Salvador                 5
# Poland                      5
# Guyana                      5
# Barbados                    5
# Philippines                 5
# Ecuador                     5
# Grenada                     4
# Honduras                    4
# South Africa                4
# Nicaragua                   4
# Cuba                        4
# Portugal                    4
# Nigeria                     3
# Belgium                     3
# Morocco                     3
# Israel                      3
# France                      3
# Guam                        3
# Romania                     3
# Kenya                       3
# Iraq                        2
# Italy                       2
# Turkey                      2
# Ghana                       2
# Cameroon                    2
# United States               2
# Sudan                       2
# Sierra Leone                2
# Bolivia                     2
# Dominica                    1
# Iceland                     1
# Bermuda                     1
# Argentina                   1
# Bosnia and Herzegovina      1
# Saint Lucia                 1
# Iran                        1
# Chile                       1
# Paraguay                    1
# Sri Lanka                   1
# Antigua and Barbuda         1
# Serbia                      1
# Bulgaria                    1
# Zambia                      1
# Venezuela                   1
# Lebanon                     1
# South Korea                 1
# Guatemala                   1
# Senegal                     1
# Brazil                      1
# Cape Verde                  1
# Syria                       1
# Bahamas                     1
# Netherlands                 1
# India                       1
# French Guiana               1
# Ethiopia                    1
# British Virgin Islands      1
# Costa Rica                  1
# Egypt                       1
# Togo                        1
# Ivory Coast                 1
# Belarus                     1
# New Zealand                 1
# South America               1
# Denmark                     1
# Name: count, dtype: int64

# %%
df = df[df['SubjectsBirthLocation'].map(df['SubjectsBirthLocation'].value_counts()) >= 10]

# %%
df.shape
# Out:
# (5028, 98)

# %%
df.describe().T
# Out:
#                                   count     mean     std      min      25%  \
# abdominalextensiondepthsitting 5028.000  241.486  32.651  155.000  217.000
# acromialheight                 5028.000 1400.636  74.111 1181.000 1347.750
# acromionradialelength          5028.000  326.349  19.593  260.000  313.000
# anklecircumference             5028.000  223.180  14.524  170.000  213.000
# axillaheight                   5028.000 1295.363  68.128 1082.000 1248.000
# balloffootcircumference        5028.000  242.424  15.755  194.000  231.000
# balloffootlength               5028.000  193.824  12.832  151.000  185.000
# biacromialbreadth              5028.000  396.578  28.628  311.000  375.000
# bicepscircumferenceflexed      5028.000  335.663  37.064  216.000  309.000
# bicristalbreadth               5028.000  273.016  18.286  197.000  261.000
# bideltoidbreadth               5028.000  485.347  37.320  358.000  458.000
# bimalleolarbreadth             5028.000   71.782   5.040   55.000   68.000
# bitragionchinarc               5028.000  322.936  16.079  267.000  313.000
# bitragionsubmandibulararc      5028.000  304.113  19.395  245.000  291.000
# bizygomaticbreadth             5028.000  138.670   6.840  116.000  134.000
# buttockcircumference           5028.000 1011.157  67.530  770.000  965.000
# buttockdepth                   5028.000  238.160  23.089  168.000  221.000
# buttockheight                  5028.000  867.598  51.823  695.000  831.000
# buttockkneelength              5028.000  606.595  30.543  501.000  586.000
# buttockpopliteallength         5028.000  495.845  27.093  405.000  477.000
# calfcircumference              5028.000  381.877  27.024  282.000  363.000
# cervicaleheight                5028.000 1471.747  79.724 1237.000 1415.000
# chestbreadth                   5028.000  280.903  19.023  213.000  268.000
# chestcircumference             5028.000 1008.613  88.077  695.000  945.000
# chestdepth                     5028.000  248.570  24.197  170.000  232.000
# chestheight                    5028.000 1246.881  75.927 1017.000 1193.000
# crotchheight                   5028.000  822.921  52.374  639.000  786.000
# crotchlengthomphalion          5028.000  617.790  41.646  473.000  589.000
# crotchlengthposterioromphalion 5028.000  350.086  28.584  243.000  330.000
# earbreadth                     5028.000   35.042   3.176   25.000   33.000
# earlength                      5028.000   62.243   4.750   46.000   59.000
# earprotrusion                  5028.000   22.128   3.150   13.000   20.000
# elbowrestheight                5028.000  238.676  27.604  138.000  221.000
# eyeheightsitting               5028.000  782.935  40.420  654.000  755.000
# footbreadthhorizontal          5028.000   98.121   6.218   77.000   94.000
# footlength                     5028.000  261.780  16.563  210.000  250.000
# forearmcenterofgriplength      5028.000  337.228  22.079  265.000  321.000
# forearmcircumferenceflexed     5028.000  291.619  27.245  200.000  271.000
# forearmforearmbreadth          5028.000  544.285  56.120  376.000  503.000
# forearmhandlength              5028.000  465.123  28.500  375.000  445.000
# functionalleglength            5028.000 1097.271  63.715  901.000 1053.000
# handbreadth                    5028.000   84.476   6.083   67.000   80.000
# handcircumference              5028.000  202.623  14.891  160.000  191.000
# handlength                     5028.000  188.503  10.931  155.000  181.000
# headbreadth                    5028.000  151.480   5.974  131.000  147.000
# headcircumference              5028.000  568.771  17.590  502.000  557.000
# headlength                     5028.000  196.041   8.075  168.000  191.000
# heelanklecircumference         5028.000  330.344  20.480  264.000  315.750
# heelbreadth                    5028.000   70.137   5.531   53.000   66.000
# hipbreadth                     5028.000  346.055  23.284  264.000  331.000
# hipbreadthsitting              5028.000  382.778  30.343  288.000  363.000
# iliocristaleheight             5028.000 1037.131  56.644  842.000  997.000
# interpupillarybreadth          5028.000  629.780  35.838  510.000  605.000
# interscyei                     5028.000  408.042  40.032  280.000  380.000
# interscyeii                    5028.000  428.839  36.028  310.000  402.000
# kneeheightmidpatella           5028.000  473.800  31.235  366.000  451.000
# kneeheightsitting              5028.000  537.917  31.860  431.000  515.000
# lateralfemoralepicondyleheight 5028.000  481.921  27.773  369.000  463.000
# lateralmalleolusheight         5028.000   69.148   7.057   47.000   64.000
# lowerthighcircumference        5028.000  402.133  29.490  302.000  382.000
# mentonsellionlength            5028.000  119.066   7.720   91.000  114.000
# neckcircumference              5028.000  371.062  36.870  275.000  339.000
# neckcircumferencebase          5028.000  409.813  35.347  302.000  380.000
# overheadfingertipreachsitting  5028.000 1382.138  81.547 1115.000 1324.000
# palmlength                     5028.000  113.420   6.799   92.000  109.000
# poplitealheight                5028.000  415.310  30.285  312.000  394.000
# radialestylionlength           5028.000  258.160  18.961  198.000  244.750
# shouldercircumference          5028.000 1118.533  83.774  871.000 1052.000
# shoulderelbowlength            5028.000  352.990  21.547  281.000  338.000
# shoulderlength                 5028.000  144.414  12.151  108.000  136.000
# sittingheight                  5028.000  894.849  43.738  750.000  864.000
# sleevelengthspinewrist         5028.000  862.241  53.653  693.000  822.000
# sleeveoutseam                  5028.000  574.978  36.489  455.000  549.000
# span                           5028.000 1756.701 105.096 1431.000 1683.000
# stature                        5028.000 1708.582  85.447 1447.000 1648.000
# suprasternaleheight            5028.000 1397.378  73.913 1168.000 1345.000
# tenthribheight                 5028.000 1095.923  56.748  917.000 1056.000
# thighcircumference             5028.000  615.132  50.859  448.000  581.000
# thighclearance                 5028.000  174.298  13.999  121.000  165.000
# thumbtipreach                  5028.000  785.715  50.768  632.000  750.750
# tibialheight                   5028.000  456.863  27.939  347.000  437.000
# tragiontopofhead               5028.000  129.309   6.590  105.000  125.000
# trochanterionheight            5028.000  880.245  51.529  714.000  845.000
# verticaltrunkcircumferenceusa  5028.000 1617.643  85.784 1342.000 1555.000
# waistbacklength                5028.000  456.881  34.453  345.000  432.000
# waistbreadth                   5028.000  312.963  31.948  211.000  290.000
# waistcircumference             5028.000  899.006  99.531  611.000  825.000
# waistdepth                     5028.000  225.034  31.070  138.000  202.000
# waistfrontlengthsitting        5028.000  373.816  29.544  289.000  353.000
# waistheightomphalion           5028.000 1029.208  60.172  828.000  987.000
# weightkg                       5028.000   77.252  12.658   35.800   67.800
# wristcircumference             5028.000  167.712  12.173  124.000  158.000
# wristheight                    5028.000  826.223  44.424  688.000  796.000
# Age                            5028.000   29.439   8.705   17.000   22.000
#
#                                     50%      75%      max
# abdominalextensiondepthsitting  239.000  264.000  358.000
# acromialheight                 1404.000 1453.000 1683.000
# acromionradialelength           327.000  340.000  393.000
# anklecircumference              223.000  233.000  281.000
# axillaheight                   1297.000 1343.000 1553.000
# balloffootcircumference         243.000  254.000  297.000
# balloffootlength                194.000  203.000  233.000
# biacromialbreadth               402.000  418.000  471.000
# bicepscircumferenceflexed       337.000  363.000  456.000
# bicristalbreadth                273.000  285.000  356.000
# bideltoidbreadth                489.000  513.000  604.000
# bimalleolarbreadth               72.000   76.000   88.000
# bitragionchinarc                324.000  334.000  378.000
# bitragionsubmandibulararc       305.000  318.000  378.000
# bizygomaticbreadth              139.000  144.000  161.000
# buttockcircumference           1011.000 1057.000 1314.000
# buttockdepth                    238.000  254.000  349.000
# buttockheight                   866.000  902.000 1080.000
# buttockkneelength               607.000  627.000  716.000
# buttockpopliteallength          495.000  514.000  597.000
# calfcircumference               383.000  400.000  480.000
# cervicaleheight                1478.000 1529.000 1738.000
# chestbreadth                    281.000  294.000  351.000
# chestcircumference             1011.000 1073.000 1290.000
# chestdepth                      248.000  265.000  342.000
# chestheight                    1253.000 1302.000 1506.000
# crotchheight                    823.000  859.000 1031.000
# crotchlengthomphalion           617.000  645.000  779.000
# crotchlengthposterioromphalion  349.000  369.000  451.000
# earbreadth                       35.000   37.000   46.000
# earlength                        62.000   65.000   81.000
# earprotrusion                    22.000   24.000   34.000
# elbowrestheight                 239.000  258.000  345.000
# eyeheightsitting                785.000  812.000  912.000
# footbreadthhorizontal            99.000  103.000  119.000
# footlength                      263.000  274.000  313.000
# forearmcenterofgriplength       338.000  353.000  411.000
# forearmcircumferenceflexed      294.000  312.000  383.000
# forearmforearmbreadth           546.000  586.000  743.000
# forearmhandlength               467.000  485.000  562.000
# functionalleglength            1099.000 1143.000 1308.000
# handbreadth                      85.000   89.000  102.000
# handcircumference               205.000  214.000  243.000
# handlength                      188.000  196.000  231.000
# headbreadth                     152.000  155.000  177.000
# headcircumference               569.000  580.000  635.000
# headlength                      196.000  202.000  225.000
# heelanklecircumference          333.000  345.000  388.000
# heelbreadth                      70.000   74.000   93.000
# hipbreadth                      345.000  361.000  470.000
# hipbreadthsitting               381.000  401.000  541.000
# iliocristaleheight             1038.000 1076.000 1253.000
# interpupillarybreadth           630.000  655.000  765.000
# interscyei                      408.000  436.000  532.000
# interscyeii                     430.000  455.000  530.000
# kneeheightmidpatella            474.000  495.000  612.000
# kneeheightsitting               539.000  560.000  666.000
# lateralfemoralepicondyleheight  482.000  500.000  588.000
# lateralmalleolusheight           69.000   74.000   93.000
# lowerthighcircumference         403.000  422.000  540.000
# mentonsellionlength             119.000  124.000  148.000
# neckcircumference               377.000  399.000  485.000
# neckcircumferencebase           414.000  437.000  520.000
# overheadfingertipreachsitting  1387.000 1440.000 1651.000
# palmlength                      114.000  118.000  137.000
# poplitealheight                 416.000  437.000  525.000
# radialestylionlength            259.000  272.000  323.000
# shouldercircumference          1130.000 1183.000 1342.000
# shoulderelbowlength             354.000  368.000  423.000
# shoulderlength                  145.000  153.000  185.000
# sittingheight                   897.000  927.000 1030.000
# sleevelengthspinewrist          867.000  902.000 1012.000
# sleeveoutseam                   575.000  600.000  709.000
# span                           1763.000 1830.000 2111.000
# stature                        1713.500 1770.000 1993.000
# suprasternaleheight            1402.000 1450.000 1650.000
# tenthribheight                 1096.000 1135.000 1294.000
# thighcircumference              616.000  649.000  832.000
# thighclearance                  174.000  184.000  221.000
# thumbtipreach                   788.000  821.000  998.000
# tibialheight                    457.000  476.000  584.000
# tragiontopofhead                130.000  134.000  150.000
# trochanterionheight             879.000  914.000 1090.000
# verticaltrunkcircumferenceusa  1620.000 1680.000 1894.000
# waistbacklength                 460.000  482.000  565.000
# waistbreadth                    313.000  336.000  419.000
# waistcircumference              898.000  972.000 1245.000
# waistdepth                      223.000  246.000  336.000
# waistfrontlengthsitting         373.000  394.000  468.000
# waistheightomphalion           1031.000 1072.000 1245.000
# weightkg                         77.300   86.900  123.100
# wristcircumference              169.000  177.000  211.000
# wristheight                     826.000  857.000 1009.000
# Age                              27.000   35.000   58.000

# %%
numeric_columns = df.select_dtypes(include=['number'])

ncols = 3
num_plots = len(numeric_columns.columns)
nrows = (num_plots - 1) // ncols + 1

fig, axes = plt.subplots(nrows, ncols, figsize=(15, 5 * nrows))

for i, column in enumerate(numeric_columns.columns):
    row = i // ncols
    col = i % ncols
    sns.boxplot(data=numeric_columns, y=column, ax=axes[row, col])
    axes[row, col].set_title(f'Boxplot of {column}')

for i in range(num_plots, nrows * ncols):
    fig.delaxes(axes.flatten()[i])

plt.tight_layout()
plt.show()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
corr_matrix = df.corr(numeric_only = True)

high_corr_columns = []

threshold = 0.9  

for i in range(len(corr_matrix.columns)):
    for j in range(i):
        corr_value = corr_matrix.iloc[i, j]
        if corr_value > threshold or corr_value < -threshold:
            col1 = corr_matrix.columns[i]
            col2 = corr_matrix.columns[j]
            high_corr_columns.append((col1, col2, corr_value))

print("Columns with High Correlation:")
for col1, col2, corr_value in high_corr_columns:
    print(f"{col1} and {col2} - Correlation Value: {corr_value:.2f}")
# Out:
# Columns with High Correlation:
# axillaheight and acromialheight - Correlation Value: 0.99
# buttockpopliteallength and buttockkneelength - Correlation Value: 0.95
# cervicaleheight and acromialheight - Correlation Value: 0.98
# cervicaleheight and axillaheight - Correlation Value: 0.97
# chestheight and acromialheight - Correlation Value: 0.96
# chestheight and axillaheight - Correlation Value: 0.95
# chestheight and cervicaleheight - Correlation Value: 0.96
# crotchheight and axillaheight - Correlation Value: 0.91
# crotchheight and buttockheight - Correlation Value: 0.92
# crotchheight and cervicaleheight - Correlation Value: 0.90
# footbreadthhorizontal and balloffootcircumference - Correlation Value: 0.91
# footlength and balloffootlength - Correlation Value: 0.96
# forearmforearmbreadth and bideltoidbreadth - Correlation Value: 0.91
# forearmhandlength and forearmcenterofgriplength - Correlation Value: 0.96
# handcircumference and handbreadth - Correlation Value: 0.96
# hipbreadth and buttockcircumference - Correlation Value: 0.91
# hipbreadthsitting and hipbreadth - Correlation Value: 0.90
# iliocristaleheight and acromialheight - Correlation Value: 0.93
# iliocristaleheight and axillaheight - Correlation Value: 0.94
# iliocristaleheight and buttockheight - Correlation Value: 0.92
# iliocristaleheight and cervicaleheight - Correlation Value: 0.93
# iliocristaleheight and chestheight - Correlation Value: 0.90
# iliocristaleheight and crotchheight - Correlation Value: 0.93
# interscyeii and interscyei - Correlation Value: 0.95
# kneeheightmidpatella and buttockheight - Correlation Value: 0.91
# kneeheightmidpatella and crotchheight - Correlation Value: 0.93
# kneeheightmidpatella and iliocristaleheight - Correlation Value: 0.91
# kneeheightsitting and acromialheight - Correlation Value: 0.92
# kneeheightsitting and axillaheight - Correlation Value: 0.93
# kneeheightsitting and cervicaleheight - Correlation Value: 0.93
# kneeheightsitting and chestheight - Correlation Value: 0.91
# kneeheightsitting and crotchheight - Correlation Value: 0.94
# kneeheightsitting and forearmhandlength - Correlation Value: 0.90
# kneeheightsitting and iliocristaleheight - Correlation Value: 0.94
# kneeheightsitting and kneeheightmidpatella - Correlation Value: 0.95
# lateralfemoralepicondyleheight and crotchheight - Correlation Value: 0.91
# lateralfemoralepicondyleheight and kneeheightmidpatella - Correlation Value: 0.94
# lateralfemoralepicondyleheight and kneeheightsitting - Correlation Value: 0.92
# neckcircumferencebase and neckcircumference - Correlation Value: 0.96
# poplitealheight and axillaheight - Correlation Value: 0.91
# poplitealheight and cervicaleheight - Correlation Value: 0.91
# poplitealheight and chestheight - Correlation Value: 0.91
# poplitealheight and crotchheight - Correlation Value: 0.93
# poplitealheight and iliocristaleheight - Correlation Value: 0.90
# poplitealheight and kneeheightmidpatella - Correlation Value: 0.93
# poplitealheight and kneeheightsitting - Correlation Value: 0.94
# radialestylionlength and forearmcenterofgriplength - Correlation Value: 0.92
# radialestylionlength and forearmhandlength - Correlation Value: 0.93
# shouldercircumference and bideltoidbreadth - Correlation Value: 0.94
# shoulderelbowlength and acromionradialelength - Correlation Value: 0.96
# sittingheight and eyeheightsitting - Correlation Value: 0.98
# sleeveoutseam and acromionradialelength - Correlation Value: 0.94
# sleeveoutseam and forearmhandlength - Correlation Value: 0.90
# sleeveoutseam and radialestylionlength - Correlation Value: 0.91
# sleeveoutseam and shoulderelbowlength - Correlation Value: 0.94
# span and forearmcenterofgriplength - Correlation Value: 0.92
# span and forearmhandlength - Correlation Value: 0.94
# span and kneeheightsitting - Correlation Value: 0.91
# span and radialestylionlength - Correlation Value: 0.91
# span and shoulderelbowlength - Correlation Value: 0.91
# span and sleevelengthspinewrist - Correlation Value: 0.92
# span and sleeveoutseam - Correlation Value: 0.93
# stature and acromialheight - Correlation Value: 0.98
# stature and axillaheight - Correlation Value: 0.97
# stature and cervicaleheight - Correlation Value: 0.99
# stature and chestheight - Correlation Value: 0.96
# stature and iliocristaleheight - Correlation Value: 0.92
# stature and kneeheightsitting - Correlation Value: 0.92
# stature and poplitealheight - Correlation Value: 0.90
# suprasternaleheight and acromialheight - Correlation Value: 0.98
# suprasternaleheight and axillaheight - Correlation Value: 0.98
# suprasternaleheight and cervicaleheight - Correlation Value: 0.99
# suprasternaleheight and chestheight - Correlation Value: 0.96
# suprasternaleheight and crotchheight - Correlation Value: 0.90
# suprasternaleheight and iliocristaleheight - Correlation Value: 0.93
# suprasternaleheight and kneeheightsitting - Correlation Value: 0.93
# suprasternaleheight and poplitealheight - Correlation Value: 0.90
# suprasternaleheight and stature - Correlation Value: 0.99
# tenthribheight and acromialheight - Correlation Value: 0.94
# tenthribheight and axillaheight - Correlation Value: 0.95
# tenthribheight and buttockheight - Correlation Value: 0.92
# tenthribheight and cervicaleheight - Correlation Value: 0.93
# tenthribheight and chestheight - Correlation Value: 0.91
# tenthribheight and crotchheight - Correlation Value: 0.92
# tenthribheight and iliocristaleheight - Correlation Value: 0.96
# tenthribheight and kneeheightmidpatella - Correlation Value: 0.91
# tenthribheight and kneeheightsitting - Correlation Value: 0.93
# tenthribheight and stature - Correlation Value: 0.92
# tenthribheight and suprasternaleheight - Correlation Value: 0.94
# thighcircumference and buttockcircumference - Correlation Value: 0.92
# tibialheight and buttockheight - Correlation Value: 0.90
# tibialheight and crotchheight - Correlation Value: 0.93
# tibialheight and iliocristaleheight - Correlation Value: 0.91
# tibialheight and kneeheightmidpatella - Correlation Value: 0.96
# tibialheight and kneeheightsitting - Correlation Value: 0.95
# tibialheight and lateralfemoralepicondyleheight - Correlation Value: 0.94
# tibialheight and poplitealheight - Correlation Value: 0.91
# tibialheight and tenthribheight - Correlation Value: 0.91
# trochanterionheight and buttockheight - Correlation Value: 0.96
# trochanterionheight and crotchheight - Correlation Value: 0.94
# trochanterionheight and iliocristaleheight - Correlation Value: 0.93
# trochanterionheight and kneeheightmidpatella - Correlation Value: 0.92
# trochanterionheight and kneeheightsitting - Correlation Value: 0.91
# trochanterionheight and tenthribheight - Correlation Value: 0.91
# trochanterionheight and tibialheight - Correlation Value: 0.92
# waistcircumference and abdominalextensiondepthsitting - Correlation Value: 0.92
# waistcircumference and waistbreadth - Correlation Value: 0.95
# waistdepth and abdominalextensiondepthsitting - Correlation Value: 0.95
# waistdepth and waistcircumference - Correlation Value: 0.94
# waistheightomphalion and acromialheight - Correlation Value: 0.93
# waistheightomphalion and axillaheight - Correlation Value: 0.95
# waistheightomphalion and cervicaleheight - Correlation Value: 0.94
# waistheightomphalion and chestheight - Correlation Value: 0.93
# waistheightomphalion and crotchheight - Correlation Value: 0.94
# waistheightomphalion and iliocristaleheight - Correlation Value: 0.94
# waistheightomphalion and kneeheightmidpatella - Correlation Value: 0.91
# waistheightomphalion and kneeheightsitting - Correlation Value: 0.93
# waistheightomphalion and poplitealheight - Correlation Value: 0.93
# waistheightomphalion and stature - Correlation Value: 0.94
# waistheightomphalion and suprasternaleheight - Correlation Value: 0.94
# waistheightomphalion and tenthribheight - Correlation Value: 0.94
# waistheightomphalion and tibialheight - Correlation Value: 0.91
# waistheightomphalion and trochanterionheight - Correlation Value: 0.91
# wristheight and acromialheight - Correlation Value: 0.91

# %% [markdown]
# # DATA Preprocessing
# - In this step we divide our data to X(Features) and y(Target) then ,
# - To train and evaluation purposes we create train and test sets,
# - Lastly, scale our data if features not in same scale. Why?

# %% [markdown]
# # Train| Test Split

# %%
X = df.drop(columns = 'DODRace', axis = 1)
y = df.DODRace

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, stratify= y, random_state = 101)

# %% [markdown]
# # OrdinalEncoder and Categoric Variables

# %%
cat = X_train.select_dtypes('O').columns
cat
# Out:
# Index(['Gender', 'SubjectsBirthLocation', 'WritingPreference'], dtype='object')

# %% [markdown]
# # Modeling with Pipeline

# %%
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder

onehot_enc = OneHotEncoder(handle_unknown = 'ignore', sparse_output = False)

column_trans = make_column_transformer((onehot_enc, cat),
                                       remainder = 'passthrough',
                                       verbose_feature_names_out = False).set_output(transform = 'pandas')

# %%
column_trans.fit_transform(X_train)
# Out:
#       Gender_Female  Gender_Male  SubjectsBirthLocation_Alabama  \
# 2304          0.000        1.000                          0.000
# 540           0.000        1.000                          0.000
# 3659          1.000        0.000                          0.000
# 1057          0.000        1.000                          0.000
# 5237          1.000        0.000                          0.000
# ...             ...          ...                            ...
# 1282          0.000        1.000                          0.000
# 916           0.000        1.000                          0.000
# 1454          0.000        1.000                          0.000
# 881           0.000        1.000                          0.000
# 3450          1.000        0.000                          1.000
#
#       SubjectsBirthLocation_Arizona  SubjectsBirthLocation_Arkansas  \
# 2304                          0.000                           0.000
# 540                           0.000                           0.000
# 3659                          0.000                           0.000
# 1057                          0.000                           0.000
# 5237                          0.000                           0.000
# ...                             ...                             ...
# 1282                          0.000                           0.000
# 916                           0.000                           0.000
# 1454                          0.000                           0.000
# 881                           0.000                           0.000
# 3450                          0.000                           0.000
#
#       SubjectsBirthLocation_California  SubjectsBirthLocation_Colombia  \
# 2304                             0.000                           0.000
# 540                              1.000                           0.000
# 3659                             0.000                           0.000
# 1057                             0.000                           0.000
# 5237                             0.000                           0.000
# ...                                ...                             ...
# 1282                             0.000                           0.000
# 916                              0.000                           0.000
# 1454                             0.000                           0.000
# 881                              0.000                           0.000
# 3450                             0.000                           0.000
#
#       SubjectsBirthLocation_Colorado  SubjectsBirthLocation_Connecticut  \
# 2304                           0.000                              0.000
# 540                            0.000                              0.000
# 3659                           0.000                              0.000
# 1057                           0.000                              0.000
# 5237                           0.000                              0.000
# ...                              ...                                ...
# 1282                           0.000                              0.000
# 916                            0.000                              0.000
# 1454                           0.000                              0.000
# 881                            0.000                              0.000
# 3450                           0.000                              0.000
#
#       SubjectsBirthLocation_Delaware  \
# 2304                           0.000
# 540                            0.000
# 3659                           0.000
# 1057                           0.000
# 5237                           0.000
# ...                              ...
# 1282                           0.000
# 916                            0.000
# 1454                           0.000
# 881                            0.000
# 3450                           0.000
#
#       SubjectsBirthLocation_District of Columbia  \
# 2304                                       0.000
# 540                                        0.000
# 3659                                       0.000
# 1057                                       0.000
# 5237                                       0.000
# ...                                          ...
# 1282                                       0.000
# 916                                        0.000
# 1454                                       0.000
# 881                                        0.000
# 3450                                       0.000
#
#       SubjectsBirthLocation_Dominican Republic  SubjectsBirthLocation_Florida  \
# 2304                                     0.000                          0.000
# 540                                      0.000                          0.000
# 3659                                     0.000                          1.000
# 1057                                     0.000                          0.000
# 5237                                     0.000                          0.000
# ...                                        ...                            ...
# 1282                                     0.000                          0.000
# 916                                      0.000                          0.000
# 1454                                     0.000                          0.000
# 881                                      0.000                          0.000
# 3450                                     0.000                          0.000
#
#       SubjectsBirthLocation_Georgia  SubjectsBirthLocation_Germany  \
# 2304                          0.000                          0.000
# 540                           0.000                          0.000
# 3659                          0.000                          0.000
# 1057                          0.000                          0.000
# 5237                          0.000                          0.000
# ...                             ...                            ...
# 1282                          0.000                          0.000
# 916                           0.000                          0.000
# 1454                          1.000                          0.000
# 881                           0.000                          0.000
# 3450                          0.000                          0.000
#
#       SubjectsBirthLocation_Haiti  SubjectsBirthLocation_Hawaii  \
# 2304                        0.000                         0.000
# 540                         0.000                         0.000
# 3659                        0.000                         0.000
# 1057                        0.000                         0.000
# 5237                        0.000                         0.000
# ...                           ...                           ...
# 1282                        0.000                         0.000
# 916                         0.000                         0.000
# 1454                        0.000                         0.000
# 881                         0.000                         0.000
# 3450                        0.000                         0.000
#
#       SubjectsBirthLocation_Idaho  SubjectsBirthLocation_Illinois  \
# 2304                        0.000                           0.000
# 540                         0.000                           0.000
# 3659                        0.000                           0.000
# 1057                        0.000                           0.000
# 5237                        0.000                           0.000
# ...                           ...                             ...
# 1282                        0.000                           0.000
# 916                         0.000                           0.000
# 1454                        0.000                           0.000
# 881                         0.000                           0.000
# 3450                        0.000                           0.000
#
#       SubjectsBirthLocation_Indiana  SubjectsBirthLocation_Iowa  \
# 2304                          0.000                       0.000
# 540                           0.000                       0.000
# 3659                          0.000                       0.000
# 1057                          1.000                       0.000
# 5237                          0.000                       0.000
# ...                             ...                         ...
# 1282                          0.000                       0.000
# 916                           0.000                       0.000
# 1454                          0.000                       0.000
# 881                           0.000                       0.000
# 3450                          0.000                       0.000
#
#       SubjectsBirthLocation_Jamaica  SubjectsBirthLocation_Kansas  \
# 2304                          0.000                         0.000
# 540                           0.000                         0.000
# 3659                          0.000                         0.000
# 1057                          0.000                         0.000
# 5237                          0.000                         0.000
# ...                             ...                           ...
# 1282                          0.000                         0.000
# 916                           0.000                         0.000
# 1454                          0.000                         0.000
# 881                           0.000                         0.000
# 3450                          0.000                         0.000
#
#       SubjectsBirthLocation_Kentucky  SubjectsBirthLocation_Louisiana  \
# 2304                           0.000                            0.000
# 540                            0.000                            0.000
# 3659                           0.000                            0.000
# 1057                           0.000                            0.000
# 5237                           0.000                            0.000
# ...                              ...                              ...
# 1282                           0.000                            0.000
# 916                            0.000                            0.000
# 1454                           0.000                            0.000
# 881                            0.000                            0.000
# 3450                           0.000                            0.000
#
#       SubjectsBirthLocation_Maine  SubjectsBirthLocation_Maryland  \
# 2304                        0.000                           0.000
# 540                         0.000                           0.000
# 3659                        0.000                           0.000
# 1057                        0.000                           0.000
# 5237                        0.000                           0.000
# ...                           ...                             ...
# 1282                        0.000                           0.000
# 916                         0.000                           0.000
# 1454                        0.000                           0.000
# 881                         0.000                           0.000
# 3450                        0.000                           0.000
#
#       SubjectsBirthLocation_Massachusetts  SubjectsBirthLocation_Mexico  \
# 2304                                0.000                         0.000
# 540                                 0.000                         0.000
# 3659                                0.000                         0.000
# 1057                                0.000                         0.000
# 5237                                0.000                         0.000
# ...                                   ...                           ...
# 1282                                1.000                         0.000
# 916                                 0.000                         0.000
# 1454                                0.000                         0.000
# 881                                 0.000                         0.000
# 3450                                0.000                         0.000
#
#       SubjectsBirthLocation_Michigan  SubjectsBirthLocation_Minnesota  \
# 2304                           0.000                            0.000
# 540                            0.000                            0.000
# 3659                           0.000                            0.000
# 1057                           0.000                            0.000
# 5237                           0.000                            0.000
# ...                              ...                              ...
# 1282                           0.000                            0.000
# 916                            1.000                            0.000
# 1454                           0.000                            0.000
# 881                            0.000                            0.000
# 3450                           0.000                            0.000
#
#       SubjectsBirthLocation_Mississippi  SubjectsBirthLocation_Missouri  \
# 2304                              0.000                           0.000
# 540                               0.000                           0.000
# 3659                              0.000                           0.000
# 1057                              0.000                           0.000
# 5237                              0.000                           0.000
# ...                                 ...                             ...
# 1282                              0.000                           0.000
# 916                               0.000                           0.000
# 1454                              0.000                           0.000
# 881                               0.000                           0.000
# 3450                              0.000                           0.000
#
#       SubjectsBirthLocation_Montana  SubjectsBirthLocation_Nebraska  \
# 2304                          0.000                           0.000
# 540                           0.000                           0.000
# 3659                          0.000                           0.000
# 1057                          0.000                           0.000
# 5237                          0.000                           0.000
# ...                             ...                             ...
# 1282                          0.000                           0.000
# 916                           0.000                           0.000
# 1454                          0.000                           0.000
# 881                           0.000                           0.000
# 3450                          0.000                           0.000
#
#       SubjectsBirthLocation_Nevada  SubjectsBirthLocation_New Hampshire  \
# 2304                         0.000                                0.000
# 540                          0.000                                0.000
# 3659                         0.000                                0.000
# 1057                         0.000                                0.000
# 5237                         0.000                                0.000
# ...                            ...                                  ...
# 1282                         0.000                                0.000
# 916                          0.000                                0.000
# 1454                         0.000                                0.000
# 881                          0.000                                0.000
# 3450                         0.000                                0.000
#
#       SubjectsBirthLocation_New Jersey  SubjectsBirthLocation_New Mexico  \
# 2304                             0.000                             0.000
# 540                              0.000                             0.000
# 3659                             0.000                             0.000
# 1057                             0.000                             0.000
# 5237                             0.000                             0.000
# ...                                ...                               ...
# 1282                             0.000                             0.000
# 916                              0.000                             0.000
# 1454                             0.000                             0.000
# 881                              0.000                             0.000
# 3450                             0.000                             0.000
#
#       SubjectsBirthLocation_New York  SubjectsBirthLocation_North Carolina  \
# 2304                           1.000                                 0.000
# 540                            0.000                                 0.000
# 3659                           0.000                                 0.000
# 1057                           0.000                                 0.000
# 5237                           0.000                                 0.000
# ...                              ...                                   ...
# 1282                           0.000                                 0.000
# 916                            0.000                                 0.000
# 1454                           0.000                                 0.000
# 881                            0.000                                 0.000
# 3450                           0.000                                 0.000
#
#       SubjectsBirthLocation_North Dakota  SubjectsBirthLocation_Ohio  \
# 2304                               0.000                       0.000
# 540                                0.000                       0.000
# 3659                               0.000                       0.000
# 1057                               0.000                       0.000
# 5237                               0.000                       0.000
# ...                                  ...                         ...
# 1282                               0.000                       0.000
# 916                                0.000                       0.000
# 1454                               0.000                       0.000
# 881                                1.000                       0.000
# 3450                               0.000                       0.000
#
#       SubjectsBirthLocation_Oklahoma  SubjectsBirthLocation_Oregon  \
# 2304                           0.000                         0.000
# 540                            0.000                         0.000
# 3659                           0.000                         0.000
# 1057                           0.000                         0.000
# 5237                           0.000                         0.000
# ...                              ...                           ...
# 1282                           0.000                         0.000
# 916                            0.000                         0.000
# 1454                           0.000                         0.000
# 881                            0.000                         0.000
# 3450                           0.000                         0.000
#
#       SubjectsBirthLocation_Pennsylvania  SubjectsBirthLocation_Puerto Rico  \
# 2304                               0.000                              0.000
# 540                                0.000                              0.000
# 3659                               0.000                              0.000
# 1057                               0.000                              0.000
# 5237                               0.000                              0.000
# ...                                  ...                                ...
# 1282                               0.000                              0.000
# 916                                0.000                              0.000
# 1454                               0.000                              0.000
# 881                                0.000                              0.000
# 3450                               0.000                              0.000
#
#       SubjectsBirthLocation_Rhode Island  \
# 2304                               0.000
# 540                                0.000
# 3659                               0.000
# 1057                               0.000
# 5237                               0.000
# ...                                  ...
# 1282                               0.000
# 916                                0.000
# 1454                               0.000
# 881                                0.000
# 3450                               0.000
#
#       SubjectsBirthLocation_South Carolina  \
# 2304                                 0.000
# 540                                  0.000
# 3659                                 0.000
# 1057                                 0.000
# 5237                                 0.000
# ...                                    ...
# 1282                                 0.000
# 916                                  0.000
# 1454                                 0.000
# 881                                  0.000
# 3450                                 0.000
#
#       SubjectsBirthLocation_South Dakota  ...  headbreadth  headcircumference  \
# 2304                               0.000  ...          149                584
# 540                                0.000  ...          162                578
# 3659                               0.000  ...          145                560
# 1057                               0.000  ...          161                594
# 5237                               0.000  ...          149                558
# ...                                  ...  ...          ...                ...
# 1282                               0.000  ...          156                585
# 916                                0.000  ...          150                572
# 1454                               0.000  ...          154                557
# 881                                0.000  ...          155                578
# 3450                               0.000  ...          136                554
#
#       headlength  heelanklecircumference  heelbreadth  hipbreadth  \
# 2304         206                     358           81         341
# 540          199                     337           78         337
# 3659         185                     297           64         337
# 1057         206                     364           74         396
# 5237         186                     280           59         369
# ...          ...                     ...          ...         ...
# 1282         210                     348           77         363
# 916          200                     334           69         345
# 1454         194                     323           64         315
# 881          200                     345           74         343
# 3450         184                     313           69         363
#
#       hipbreadthsitting  iliocristaleheight  interpupillarybreadth  \
# 2304                367                1040                    680
# 540                 360                 984                    695
# 3659                376                 998                    590
# 1057                421                1095                    690
# 5237                411                 971                    640
# ...                 ...                 ...                    ...
# 1282                398                1095                    670
# 916                 375                1042                    660
# 1454                332                1013                    625
# 881                 380                1098                    645
# 3450                422                 987                    640
#
#       interscyei  interscyeii  kneeheightmidpatella  kneeheightsitting  \
# 2304         410          450                   505                557
# 540          406          427                   449                528
# 3659         328          370                   455                513
# 1057         421          445                   496                571
# 5237         383          418                   432                491
# ...          ...          ...                   ...                ...
# 1282         455          482                   506                579
# 916          469          483                   460                541
# 1454         426          447                   467                531
# 881          443          455                   490                564
# 3450         360          392                   436                511
#
#       lateralfemoralepicondyleheight  lateralmalleolusheight  \
# 2304                             505                      74
# 540                              452                      74
# 3659                             463                      67
# 1057                             505                      74
# 5237                             445                      58
# ...                              ...                     ...
# 1282                             503                      75
# 916                              469                      70
# 1454                             474                      73
# 881                              501                      79
# 3450                             447                      59
#
#       lowerthighcircumference  mentonsellionlength  neckcircumference  \
# 2304                      393                  130                371
# 540                       410                  127                406
# 3659                      362                  108                308
# 1057                      440                  120                395
# 5237                      400                  119                326
# ...                       ...                  ...                ...
# 1282                      424                  122                395
# 916                       403                  123                378
# 1454                      347                  109                364
# 881                       412                  128                385
# 3450                      409                  109                318
#
#       neckcircumferencebase  overheadfingertipreachsitting  palmlength  \
# 2304                    411                           1415         121
# 540                     442                           1288         108
# 3659                    350                           1282         102
# 1057                    441                           1480         124
# 5237                    380                           1286         111
# ...                     ...                            ...         ...
# 1282                    437                           1435         125
# 916                     411                           1443         113
# 1454                    391                           1409         115
# 881                     413                           1449         112
# 3450                    357                           1315         110
#
#       poplitealheight  radialestylionlength  shouldercircumference  \
# 2304              447                   273                   1131
# 540               405                   251                   1158
# 3659              392                   240                    996
# 1057              437                   277                   1169
# 5237              375                   230                    996
# ...               ...                   ...                    ...
# 1282              446                   278                   1244
# 916               424                   255                   1173
# 1454              428                   256                   1101
# 881               435                   263                   1179
# 3450              378                   248                   1057
#
#       shoulderelbowlength  shoulderlength  sittingheight  \
# 2304                  370             157            923
# 540                   337             154            880
# 3659                  334             130            835
# 1057                  378             145            936
# 5237                  321             136            854
# ...                   ...             ...            ...
# 1282                  368             165            906
# 916                   367             149            923
# 1454                  361             156            890
# 881                   381             157            940
# 3450                  332             150            786
#
#       sleevelengthspinewrist  sleeveoutseam  span  stature  \
# 2304                     907            601  1858     1765
# 540                      850            554  1688     1674
# 3659                     794            537  1617     1603
# 1057                     925            617  1878     1785
# 5237                     791            530  1628     1616
# ...                      ...            ...   ...      ...
# 1282                     947            614  1909     1785
# 916                      875            582  1794     1720
# 1454                     874            576  1760     1686
# 881                      895            607  1843     1810
# 3450                     808            535  1676     1555
#
#       suprasternaleheight  tenthribheight  thighcircumference  thighclearance  \
# 2304                 1438            1125                 586             160
# 540                  1343            1033                 612             185
# 3659                 1314            1046                 590             163
# 1057                 1472            1127                 694             196
# 5237                 1288            1028                 623             163
# ...                   ...             ...                 ...             ...
# 1282                 1470            1151                 657             181
# 916                  1417            1081                 613             176
# 1454                 1370            1061                 501             159
# 881                  1488            1159                 629             189
# 3450                 1271            1049                 639             171
#
#       thumbtipreach  tibialheight  tragiontopofhead  trochanterionheight  \
# 2304            839           484               133                  882
# 540             777           435               139                  838
# 3659            690           447               118                  846
# 1057            819           482               135                  906
# 5237            725           419               135                  802
# ...             ...           ...               ...                  ...
# 1282            829           491               142                  901
# 916             817           453               115                  868
# 1454            780           452               120                  849
# 881             826           480               133                  926
# 3450            792           434               117                  826
#
#       verticaltrunkcircumferenceusa  waistbacklength  waistbreadth  \
# 2304                           1578              485           337
# 540                            1562              433           308
# 3659                           1543              395           283
# 1057                           1721              485           360
# 5237                           1525              450           298
# ...                             ...              ...           ...
# 1282                           1688              460           349
# 916                            1657              472           322
# 1454                           1524              458           268
# 881                            1754              489           301
# 3450                           1473              361           289
#
#       waistcircumference  waistdepth  waistfrontlengthsitting  \
# 2304                 901         210                      387
# 540                  886         222                      350
# 3659                 777         169                      346
# 1057                1027         239                      392
# 5237                 837         208                      335
# ...                  ...         ...                      ...
# 1282                1006         252                      381
# 916                  902         220                      408
# 1454                 733         180                      354
# 881                  869         217                      414
# 3450                 811         198                      326
#
#       waistheightomphalion  weightkg  wristcircumference  wristheight  Age
# 2304                  1070    76.600                 175          827   22
# 540                   1002    77.100                 174          767   36
# 3659                   974    56.100                 146          778   24
# 1057                  1087    96.200                 186          842   27
# 5237                   952    63.200                 146          769   31
# ...                    ...       ...                 ...          ...  ...
# 1282                  1108    91.600                 181          855   32
# 916                   1046    79.900                 176          839   28
# 1454                  1017    58.500                 158          805   26
# 881                   1084    86.100                 176          882   18
# 3450                   977    64.500                 149          728   20
#
# [4022 rows x 156 columns]

# %% [markdown]
# # Modelling
# - Fit the model with train dataset
# - Get predict from vanilla model on both train and test sets to examine if there is over/underfitting
# - Apply GridseachCV for both hyperparemeter tuning and sanity test of our model.
# - Use hyperparameters that you find from gridsearch and make final prediction and evaluate the result according to chosen metric.

# %% [markdown]
# ## 1. Logistic model

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

# %%
operations = [('OneHotEncoder', column_trans), ('scaler', MinMaxScaler()), ('logistic', LogisticRegression())]

pipe_model = Pipeline(steps = operations)

pipe_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('OneHotEncoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   Index(['Gender', 'SubjectsBirthLocation', 'WritingPreference'], dtype='object'))],
#                                    verbose_feature_names_out=False)),
#                 ('scaler', MinMaxScaler()),
#                 ('logistic', LogisticRegression())])

# %% [markdown]
# ### Vanilla Logistic Model

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, ConfusionMatrixDisplay

# %% [markdown]
# # With Default Parameters

# %%
y_pred = pipe_model.predict(X_test)
y_pred
# Out:
# array(['White', 'White', 'White', ..., 'White', 'White', 'White'],
#       dtype=object)

# %%
y_pred_proba = pipe_model.predict_proba(X_test)
y_pred_proba
# Out:
# array([[7.18787795e-03, 1.39705867e-01, 8.53106255e-01],
#        [1.63380092e-02, 1.53587471e-03, 9.82126116e-01],
#        [1.67061592e-02, 9.69743187e-03, 9.73596409e-01],
#        ...,
#        [2.79729734e-02, 1.22298375e-02, 9.59797189e-01],
#        [1.01302008e-02, 2.81164622e-01, 7.08705177e-01],
#        [9.38140866e-04, 2.03635743e-03, 9.97025502e-01]])

# %%
ConfusionMatrixDisplay.from_estimator(pipe_model, X_test, y_test);

# %%
def eval_metric(model, X_train, y_train, X_test, y_test):
    y_train_pred = model.predict(X_train)
    y_pred = model.predict(X_test)
    
    print('Test_Set')
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    print()
    print('Train_Set')
    print(confusion_matrix(y_train, y_train_pred))
    print(classification_report(y_train, y_train_pred))

# %%
eval_metric(pipe_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[205   1  15]
#  [  6  59  54]
#  [  8  13 645]]
#               precision    recall  f1-score   support
#
#        Black       0.94      0.93      0.93       221
#     Hispanic       0.81      0.50      0.61       119
#        White       0.90      0.97      0.93       666
#
#     accuracy                           0.90      1006
#    macro avg       0.88      0.80      0.83      1006
# weighted avg       0.90      0.90      0.90      1006
#
#
# Train_Set
# [[ 813   14   59]
#  [  24  281  169]
#  [  20   51 2591]]
#               precision    recall  f1-score   support
#
#        Black       0.95      0.92      0.93       886
#     Hispanic       0.81      0.59      0.69       474
#        White       0.92      0.97      0.95      2662
#
#     accuracy                           0.92      4022
#    macro avg       0.89      0.83      0.85      4022
# weighted avg       0.91      0.92      0.91      4022

# %% [markdown]
# # Cross Validate

# %%
from sklearn.model_selection import cross_validate

operations = [('OneHotEncoder', column_trans), ('scaler', MinMaxScaler()), ('logistic', LogisticRegression())]

pipe_model = Pipeline(steps = operations)

scores = cross_validate(pipe_model, X_train, y_train, scoring = ['accuracy', 'precision_macro','recall_macro',
                                                                   'f1_macro'], cv = 10, return_train_score=True)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_accuracy           0.907
# train_accuracy          0.917
# test_precision_macro    0.880
# train_precision_macro   0.896
# test_recall_macro       0.809
# train_recall_macro      0.827
# test_f1_macro           0.837
# train_f1_macro          0.855
# dtype: float64

# %% [markdown]
# # Cross Validate for Hispanic

# %%
from sklearn.metrics import make_scorer
from sklearn.metrics import precision_score, recall_score, accuracy_score, f1_score, roc_auc_score


f1_Hispanic = make_scorer(f1_score,pos_label = 'Hispanic', average = None, labels =["Hispanic"])
precision_Hispanic = make_scorer(precision_score, pos_label = 'Hispanic', average = None, labels =["Hispanic"])
recall_Hispanic = make_scorer(recall_score, pos_label = 'Hispanic', average = None, labels =["Hispanic"])


scoring = {"f1_Hispanic":f1_Hispanic,
           "precision_Hispanic":precision_Hispanic,
           "recall_Hispanic":recall_Hispanic}

# %%
from sklearn.model_selection import StratifiedKFold

operations = [('OneHotEncoder', column_trans), ('scaler', MinMaxScaler()), ('logistic', LogisticRegression())]

pipe_model = Pipeline(steps = operations)

scoring = {
           "f1_Hispanic":f1_Hispanic,
           "precision_Hispanic":precision_Hispanic,
           "recall_Hispanic":recall_Hispanic
}

cv = StratifiedKFold(n_splits =10, shuffle = True, random_state = 101)

scores = cross_validate(pipe_model, X, y, scoring = scoring, cv = cv, return_train_score = True)

df_scores = pd.DataFrame(scores, index = range(1,11))

print(df_scores.mean()[2:])
# Out:
# test_f1_Hispanic           0.642
# train_f1_Hispanic          0.675
# test_precision_Hispanic    0.782
# train_precision_Hispanic   0.820
# test_recall_Hispanic       0.546
# train_recall_Hispanic      0.574
# dtype: float64

# %%
operations = [('OneHotEncoder', column_trans), ('scaler', MinMaxScaler()), ('logistic', LogisticRegression())]

pipe_model = Pipeline(steps = operations)

scores = cross_validate(pipe_model, X_train, y_train, scoring = scoring, cv = 10, return_train_score = True)

df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_f1_Hispanic           0.648
# train_f1_Hispanic          0.685
# test_precision_Hispanic    0.783
# train_precision_Hispanic   0.819
# test_recall_Hispanic       0.555
# train_recall_Hispanic      0.588
# dtype: float64

# %% [markdown]
# ### Logistic Model GridsearchCV

# %%
f1_Hispanic = make_scorer(f1_score,pos_label = 'Hispanic', average = None, labels =["Hispanic"])

# %%
operations = [
    ('OrdinalEncoder', column_trans), 
    ('scaler', MinMaxScaler()), 
    ('logistic', LogisticRegression())
]

pipe_model = Pipeline(steps=operations)


penalty = ["l1", "l2"]
C = [0.01, 0.1, 1, 5, 16, 19, 22, 25]

param_grid = {"logistic__penalty" : penalty,
             "logistic__C" : C}

# %%
cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=101)

grid_search = GridSearchCV(pipe_model, param_grid, cv=cv, scoring=f1_Hispanic, return_train_score=True)

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=10, random_state=101, shuffle=True),
#              estimator=Pipeline(steps=[('OrdinalEncoder',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('onehotencoder',
#                                                                          OneHotEncoder(handle_unknown='ignore',
#                                                                                        sparse_output=False),
#                                                                          Index(['Gender', 'SubjectsBirthLocation', 'WritingPreference'], dtype='object'))],
#                                                           verbose_feature_names_out=False)),
#                                        ('scaler', MinMaxScaler()),
#                                        ('logistic', LogisticRegression())]),
#              param_grid={'logistic__C': [0.01, 0.1, 1, 5, 16, 19, 22, 25],
#                          'logistic__penalty': ['l1', 'l2']},
#              return_train_score=True,
#              scoring=make_scorer(f1_score, response_method='predict', pos_label=Hispanic, average=None, labels=['Hispanic']))

# %%
grid_search.best_params_
# Out:
# {'logistic__C': 5, 'logistic__penalty': 'l2'}

# %%
grid_search.best_estimator_
# Out:
# Pipeline(steps=[('OrdinalEncoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   Index(['Gender', 'SubjectsBirthLocation', 'WritingPreference'], dtype='object'))],
#                                    verbose_feature_names_out=False)),
#                 ('scaler', MinMaxScaler()),
#                 ('logistic', LogisticRegression(C=5))])

# %%
pd.DataFrame(grid_search.cv_results_).loc[grid_search.best_index_, ['mean_test_score', 'mean_train_score']]
# Out:
# mean_test_score    0.670
# mean_train_score   0.708
# Name: 7, dtype: object

# %%
y_pred = grid_search.predict(X_test)
y_pred
# Out:
# array(['White', 'White', 'White', ..., 'White', 'White', 'White'],
#       dtype=object)

# %%
ConfusionMatrixDisplay.from_estimator(grid_search, X_test, y_test);

# %%
eval_metric(grid_search, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[210   0  11]
#  [  6  64  49]
#  [  8  15 643]]
#               precision    recall  f1-score   support
#
#        Black       0.94      0.95      0.94       221
#     Hispanic       0.81      0.54      0.65       119
#        White       0.91      0.97      0.94       666
#
#     accuracy                           0.91      1006
#    macro avg       0.89      0.82      0.84      1006
# weighted avg       0.91      0.91      0.91      1006
#
#
# Train_Set
# [[ 826   14   46]
#  [  21  301  152]
#  [  23   60 2579]]
#               precision    recall  f1-score   support
#
#        Black       0.95      0.93      0.94       886
#     Hispanic       0.80      0.64      0.71       474
#        White       0.93      0.97      0.95      2662
#
#     accuracy                           0.92      4022
#    macro avg       0.89      0.85      0.87      4022
# weighted avg       0.92      0.92      0.92      4022

# %% [raw]
# Test_Set
# [[205   1  15]
#  [  6  59  54]
#  [  8  13 645]]
#               precision    recall  f1-score   support
#
#        Black       0.94      0.93      0.93       221
#     Hispanic       0.81      0.50      0.61       119
#        White       0.90      0.97      0.93       666
#
#     accuracy                           0.90      1006
#    macro avg       0.88      0.80      0.83      1006
# weighted avg       0.90      0.90      0.90      1006
#
#
# Train_Set
# [[ 813   14   59]
#  [  24  281  169]
#  [  20   51 2591]]
#               precision    recall  f1-score   support
#
#        Black       0.95      0.92      0.93       886
#     Hispanic       0.81      0.59      0.69       474
#        White       0.92      0.97      0.95      2662
#
#     accuracy                           0.92      4022
#    macro avg       0.89      0.83      0.85      4022
# weighted avg       0.91      0.92      0.91      4022

# %%
operations = [
    ('OneHotEncoder', column_trans), 
    ('scaler', MinMaxScaler()), 
    ('logistic', LogisticRegression(class_weight = 'balanced', C = 5, solver ='liblinear',
                                    penalty = 'l2', 
                                    random_state = 101))
]

pipe_model = Pipeline(steps=operations)

scores = cross_validate(pipe_model,
                       X_train,
                       y_train,
                       scoring = scoring,
                       cv = 10,
                       return_train_score = True)

df_scores = pd.DataFrame(scores, index = range(1, 11))

df_scores.mean()[2:]
# Out:
# test_f1_Hispanic           0.653
# train_f1_Hispanic          0.709
# test_precision_Hispanic    0.657
# train_precision_Hispanic   0.707
# test_recall_Hispanic       0.652
# train_recall_Hispanic      0.711
# dtype: float64

# %%
from scikitplot.metrics import plot_roc, plot_precision_recall, plot_precision_recall

operations = [
    ('OrdinalEncoder', column_trans), 
    ('scaler', MinMaxScaler()), 
    ('logistic', LogisticRegression(class_weight = 'balanced', C =5, solver ='liblinear',
                                    penalty = 'l2', 
                                    random_state = 101))
]

pipe_model = Pipeline(steps=operations)

pipe_model.fit(X_train, y_train)

y_pred_proba = pipe_model.predict_proba(X_test)

plot_precision_recall(y_test, y_pred_proba)
plt.show();

# %%
pd.get_dummies(y_test).values
# Out:
# array([[False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        ...,
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True]])

# %%
from sklearn.metrics import average_precision_score

y_test_dummies = pd.get_dummies(y_test).values

average_precision_score(y_test_dummies[:, 1], y_pred_proba[:, 1])
# Out:
# 0.681318271510991

# %%
y_pred = grid_search.predict(X_test)

log_AP = average_precision_score(y_test_dummies[:, 1], y_pred_proba[:, 1])
log_precision = precision_score(y_test, y_pred, average = None, labels = ['Hispanic'])
log_recall = recall_score(y_test, y_pred, average = None, labels = ['Hispanic'])

print(log_AP)
print(log_precision)
print(log_recall)
# Out:
# 0.681318271510991
# [0.81012658]
# [0.53781513]

# %% [markdown]
# ## 2. SVC

# %% [markdown]
# ### Vanilla SVC model

# %%
operations = [
    ('OneHotEncoder', column_trans), 
    ('scaler', MinMaxScaler()), 
    ('svc', SVC(class_weight = 'balanced', random_state = 101))
]

svc_model = Pipeline(steps=operations)

svc_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('OneHotEncoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   Index(['Gender', 'SubjectsBirthLocation', 'WritingPreference'], dtype='object'))],
#                                    verbose_feature_names_out=False)),
#                 ('scaler', MinMaxScaler()),
#                 ('svc', SVC(class_weight='balanced', random_state=101))])

# %%
eval_metric(svc_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[204   9   8]
#  [  5  87  27]
#  [ 16  78 572]]
#               precision    recall  f1-score   support
#
#        Black       0.91      0.92      0.91       221
#     Hispanic       0.50      0.73      0.59       119
#        White       0.94      0.86      0.90       666
#
#     accuracy                           0.86      1006
#    macro avg       0.78      0.84      0.80      1006
# weighted avg       0.88      0.86      0.87      1006
#
#
# Train_Set
# [[ 832   29   25]
#  [  16  406   52]
#  [  53  322 2287]]
#               precision    recall  f1-score   support
#
#        Black       0.92      0.94      0.93       886
#     Hispanic       0.54      0.86      0.66       474
#        White       0.97      0.86      0.91      2662
#
#     accuracy                           0.88      4022
#    macro avg       0.81      0.88      0.83      4022
# weighted avg       0.91      0.88      0.89      4022

# %% [markdown]
# # SVC Model Cross Validation

# %%
from sklearn.model_selection import cross_validate

operations = [('OneHotEncoder', column_trans), ('scaler', MinMaxScaler()), ('svc', SVC())]

svc_model = Pipeline(steps = operations)

scores = cross_validate(svc_model, X_train, y_train, scoring = ['accuracy', 'precision_macro','recall_macro',
                                                                   'f1_macro'], cv = 10, n_jobs = -1, return_train_score=True)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_accuracy           0.888
# train_accuracy          0.900
# test_precision_macro    0.915
# train_precision_macro   0.931
# test_recall_macro       0.734
# train_recall_macro      0.755
# test_f1_macro           0.776
# train_f1_macro          0.798
# dtype: float64

# %% [markdown]
# # SVC Model Gridsearch

# %%
recall_Hispanic =  make_scorer(recall_score, pos_label='Hispanic', average=None, labels=["Hispanic"])

# %%
param_grid = {
    'svc__C': [0.01,0.1,0.3,1.0],
    'svc__gamma': ['scale', 'auto', 0.2],
    'svc__kernel': ['linear','rbf'],
    
}

# %%
operations = [('OneHotEncoder', column_trans), ('scaler', MinMaxScaler()),
              ('svc', SVC(class_weight = 'balanced',
                                              random_state = 42))]

pipe_model = Pipeline(steps = operations)

svm_model_grid = GridSearchCV(pipe_model, param_grid=param_grid,
                              scoring=recall_Hispanic,
                              cv=10, 
                              n_jobs=-1, 
                              verbose=2,
                             return_train_score = True)

# %%
svm_model_grid.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 24 candidates, totalling 240 fits
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('OneHotEncoder',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('onehotencoder',
#                                                                          OneHotEncoder(handle_unknown='ignore',
#                                                                                        sparse_output=False),
#                                                                          Index(['Gender', 'SubjectsBirthLocation', 'WritingPreference'], dtype='object'))],
#                                                           verbose_feature_names_out=False)),
#                                        ('scaler', MinMaxScaler()),
#                                        ('svc',
#                                         SVC(class_weight='balanced',
#                                             random_state=42))]),
#              n_jobs=-1,
#              param_grid={'svc__C': [0.01, 0.1, 0.3, 1.0],
#                          'svc__gamma': ['scale', 'auto', 0.2],
#                          'svc__kernel': ['linear', 'rbf']},
#              return_train_score=True,
#              scoring=make_scorer(recall_score, response_method='predict', pos_label=Hispanic, average=None, labels=['Hispanic']),
#              verbose=2)

# %%
svm_model_grid.best_params_
# Out:
# {'svc__C': 0.3, 'svc__gamma': 'scale', 'svc__kernel': 'linear'}

# %%
svm_model_grid.best_estimator_
# Out:
# Pipeline(steps=[('OneHotEncoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   Index(['Gender', 'SubjectsBirthLocation', 'WritingPreference'], dtype='object'))],
#                                    verbose_feature_names_out=False)),
#                 ('scaler', MinMaxScaler()),
#                 ('svc',
#                  SVC(C=0.3, class_weight='balanced', kernel='linear',
#                      random_state=42))])

# %%
pd.DataFrame(svm_model_grid.cv_results_).loc[svm_model_grid.best_index_, ["mean_test_score", "mean_train_score"]]
# Out:
# mean_test_score    0.770
# mean_train_score   0.832
# Name: 12, dtype: object

# %%
eval_metric(svm_model_grid, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[208   6   7]
#  [  5  90  24]
#  [ 22  74 570]]
#               precision    recall  f1-score   support
#
#        Black       0.89      0.94      0.91       221
#     Hispanic       0.53      0.76      0.62       119
#        White       0.95      0.86      0.90       666
#
#     accuracy                           0.86      1006
#    macro avg       0.79      0.85      0.81      1006
# weighted avg       0.88      0.86      0.87      1006
#
#
# Train_Set
# [[ 830   34   22]
#  [  19  391   64]
#  [  59  317 2286]]
#               precision    recall  f1-score   support
#
#        Black       0.91      0.94      0.93       886
#     Hispanic       0.53      0.82      0.64       474
#        White       0.96      0.86      0.91      2662
#
#     accuracy                           0.87      4022
#    macro avg       0.80      0.87      0.83      4022
# weighted avg       0.90      0.87      0.88      4022

# %%
operations = [("OneHot_Encoder", column_trans), 
              ("svc", SVC(class_weight = 'balanced', kernel = 'linear',
                                              C = 0.01,
                                              random_state = 101))]


svc_model = Pipeline(steps=operations)

svc_model.fit(X_train, y_train)

decision_function = svc_model.decision_function(X_test)

#y_pred_proba = model.predict_proba(X_test) # should not use predict_proba  . should use decision func.
    
plot_precision_recall(y_test, decision_function)
plt.show();

# %% [markdown]
# ## 3. RF

# %% [markdown]
# ### Vanilla RF Model

# %%
ax = sns.countplot(x="DODRace", data = df)
ax.bar_label(ax.containers[0]);

# %%
ax = sns.countplot(x="DODRace", data = df, hue = "Gender")
for p in ax.containers:
    ax.bar_label(p)

# %%
X = df.drop('DODRace', axis = 1)
y = df.DODRace

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, stratify = y, random_state = 42)

# %%
cat = X_train.select_dtypes("object").columns
cat
# Out:
# Index(['Gender', 'SubjectsBirthLocation', 'WritingPreference'], dtype='object')

# %%
from sklearn.preprocessing import OrdinalEncoder

ord_enc = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)

column_trans = make_column_transformer((ord_enc, cat),
                                        remainder='passthrough',
                                        verbose_feature_names_out=False).set_output(transform="pandas")

# %%
operations = [("OrdinalEncoder", column_trans),
              ("RF_model", RandomForestClassifier(random_state=42))]

pipe_model = Pipeline(steps=operations)

pipe_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('OrdinalEncoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   Index(['Gender', 'SubjectsBirthLocation', 'WritingPreference'], dtype='object'))],
#                                    verbose_feature_names_out=False)),
#                 ('RF_model', RandomForestClassifier(random_state=42))])

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

def eval_metric(model, X_train, y_train, X_test, y_test):
    y_train_pred = model.predict(X_train)
    y_pred = model.predict(X_test)

    print("Test_Set")
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    print()
    print("Train_Set")
    print(confusion_matrix(y_train, y_train_pred))
    print(classification_report(y_train, y_train_pred))

# %%
eval_metric(pipe_model_rf, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[213   0   8]
#  [  3 103  13]
#  [  1   1 664]]
#               precision    recall  f1-score   support
#
#        Black       0.98      0.96      0.97       221
#     Hispanic       0.99      0.87      0.92       119
#        White       0.97      1.00      0.98       666
#
#     accuracy                           0.97      1006
#    macro avg       0.98      0.94      0.96      1006
# weighted avg       0.97      0.97      0.97      1006
#
#
# Train_Set
# [[ 853    2   31]
#  [   9  385   80]
#  [   7    1 2654]]
#               precision    recall  f1-score   support
#
#        Black       0.98      0.96      0.97       886
#     Hispanic       0.99      0.81      0.89       474
#        White       0.96      1.00      0.98      2662
#
#     accuracy                           0.97      4022
#    macro avg       0.98      0.92      0.95      4022
# weighted avg       0.97      0.97      0.97      4022

# %%
operations = [("OrdinalEncoder", column_trans),
              ("RF_model", RandomForestClassifier(random_state=42))]

model = Pipeline(steps=operations)

scores = cross_validate(model,
                        X_train,
                        y_train,
                        scoring=["accuracy",
                                 "precision_macro",
                                 "recall_macro",
                                 "f1_macro"],
                        cv = 10,
                        return_train_score=True)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_accuracy           0.819
# train_accuracy          1.000
# test_precision_macro    0.763
# train_precision_macro   1.000
# test_recall_macro       0.597
# train_recall_macro      1.000
# test_f1_macro           0.604
# train_f1_macro          1.000
# dtype: float64

# %%
operations = [("OrdinalEncoder", column_trans),
              ("RF_model", RandomForestClassifier(random_state=42))]

model = Pipeline(steps=operations)

scores = cross_validate(model,
                        X_train,
                        y_train,
                        scoring=["accuracy",
                                 "precision_micro",
                                 "recall_micro",
                                 "f1_micro"],
                        cv = 10,
                        return_train_score=True)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_accuracy           0.819
# train_accuracy          1.000
# test_precision_micro    0.819
# train_precision_micro   1.000
# test_recall_micro       0.819
# train_recall_micro      1.000
# test_f1_micro           0.819
# train_f1_micro          1.000
# dtype: float64

# %%
operations = [("ColumnTransformer", column_trans), 
              ("RF_model", RandomForestClassifier(class_weight="balanced", 
                                                  random_state=42))]


rf_model = Pipeline(steps=operations_rf)

scores = cross_validate(rf_model,
                        X_train, 
                        y_train,
                        scoring=scoring,
                        cv=10,
                        return_train_score=True)

df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_f1_Hispanic           0.327
# train_f1_Hispanic          0.351
# test_precision_Hispanic    0.223
# train_precision_Hispanic   0.240
# test_recall_Hispanic       0.615
# train_recall_Hispanic      0.650
# dtype: float64

# %%
from scikitplot.metrics import plot_roc, precision_recall_curve

y_pred_probe = pipe_model.predict_proba(X_test)

plot_roc(y_test, y_pred_probe)
plt.show();

# %% [markdown]
# ### RF Model GridsearchCV

# %%
recall_Hispanic =  make_scorer(recall_score, pos_label='Hispanic', average=None, labels=["Hispanic"])

# %%
operations = [("OrdinalEncoder", column_trans),
              ("RF_model", RandomForestClassifier(random_state= 42))]

pipe_model = Pipeline(steps=operations)

# %%
# Define the parameter grid with the correct prefixes
param_grid = {'RF_model__n_estimators':[300 , 400, 500], 
             'RF_model__max_depth':[2, None],
             'RF_model__min_samples_split':[5, 10, 20],
             'RF_model__min_samples_leaf': [100],
             'RF_model__max_samples':[0.1, 0.2, 0.3]}

# %%
# Create the GridSearchCV object
rf_grid_model = GridSearchCV(rf_model,
                             param_grid,
                             scoring = recall_Hispanic,  
                             n_jobs=-1,
                             cv=10,
                             return_train_score=True,
                             verbose=2)

# %%
# Fit the GridSearchCV object
rf_grid_model.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 54 candidates, totalling 540 fits
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('OrdinalEncoder',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('onehotencoder',
#                                                                          OneHotEncoder(handle_unknown='ignore',
#                                                                                        sparse_output=False),
#                                                                          Index(['Gender', 'SubjectsBirthLocation', 'WritingPreference'], dtype='object'))],
#                                                           verbose_feature_names_out=False)),
#                                        ('RF_model',
#                                         RandomForestClassifier(class_w...
#              n_jobs=-1,
#              param_grid={'RF_model__max_depth': [2, None],
#                          'RF_model__max_samples': [0.1, 0.2, 0.3],
#                          'RF_model__min_samples_leaf': [100],
#                          'RF_model__min_samples_split': [5, 10, 20],
#                          'RF_model__n_estimators': [300, 400, 500]},
#              return_train_score=True,
#              scoring=make_scorer(recall_score, response_method='predict', pos_label=Hispanic, average=None, labels=['Hispanic']),
#              verbose=2)

# %%
rf_grid_model.best_params_
# Out:
# {'RF_model__max_depth': None,
#  'RF_model__max_samples': 0.2,
#  'RF_model__min_samples_leaf': 100,
#  'RF_model__min_samples_split': 5,
#  'RF_model__n_estimators': 300}

# %%
pd.DataFrame(rf_grid_model.cv_results_).loc[rf_grid_model.best_index_, 
                                            ['mean_test_score', 'mean_train_score']]

# %%
rf_grid_model.best_estimator_

# %%
rf_grid_model.best_score_

# %%
ConfusionMatrixDisplay.from_estimator(rf_grid_model, X_test, y_test);

# %%
eval_metric(rf_grid_model, X_train, y_train, X_test, y_test)

# %%
operations_rf = [("OrdinalEncoder", column_trans), 
                 ("RF_model", RandomForestClassifier(class_weight="balanced",
                                                     max_depth= None,
                                                     max_samples= 0.3,
                                                     min_samples_leaf= 100,
                                                     min_samples_split= 5,
                                                     n_estimators= 300, 
                                                     random_state=101))]

model = Pipeline(steps=operations_rf)

model.fit(X_train, y_train)

y_pred_proba = model.predict_proba(X_test)
    
plot_precision_recall(y_test, y_pred_proba)
plt.show();

# %%
average_precision_score(y_test_dummies[:, 1], y_pred_proba[:, 1])

# %%
y_pred = rf_grid_model.predict(X_test)

rf_AP = average_precision_score(y_test_dummies[:, 1], y_pred_proba[:, 1])
rf_precision = precision_score(y_test, y_pred, average=None, labels=["Hispanic"])
rf_recall = recall_score(y_test, y_pred, average=None, labels=["Hispanic"])


print(rf_AP)
print(rf_precision)
print(rf_recall)
# Out:
# 0.20329797227863905
# [0.18285714]
# [0.53781513]

# %% [markdown]
# ## 4. XGBoost

# %% [markdown]
# ### Vanilla XGBoost Model

# %%
from xgboost import XGBClassifier

# %%
xgb = XGBClassifier()
xgb.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[531], line 2
#       1 xgb = XGBClassifier()
# ----> 2 xgb.fit(X_train, y_train)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:1491, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1486     expected_classes = self.classes_
#    1487 if (
#    1488     classes.shape != expected_classes.shape
#    1489     or not (classes == expected_classes).all()
#    1490 ):
# -> 1491     raise ValueError(
#    1492         f"Invalid classes inferred from unique values of `y`.  "
#    1493         f"Expected: {expected_classes}, got {classes}"
#    1494     )
#    1496 params = self.get_xgb_params()
#    1498 if callable(self.objective):
#
# ValueError: Invalid classes inferred from unique values of `y`.  Expected: [0 1 2], got ['Black' 'Hispanic' 'White']

# %%
operations_xgb = [("OrdinalEncoder", column_trans), 
                 ("XGB_model", XGBClassifier(random_state=42))]

pipe_model_xgb = Pipeline(steps=operations_xgb)

y_train_xgb = y_train.map({"Black":0, "Hispanic":1, "White":2})
y_test_xgb = y_test.map({"Black":0, "Hispanic":1, "White":2})

pipe_model_xgb.fit(X_train, y_train_xgb)
# Out:
# Pipeline(steps=[('OrdinalEncoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   Index(['Gender', 'SubjectsBirthLocation', 'WritingPreference'], dtype='object'))],
#                                    verbose_feature_names_out=False)),
#                 ('XGB_model',
#                  XGBClassifier(base_score=None, booster=None, callb...
#                                feature_types=None, gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=None,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=None, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=None, n_jobs=None,
#                                num_parallel_tree=None,
#                                objective='multi:softprob', ...))])

# %%
eval_metric(pipe_model_xgb, X_train, y_train_xgb, X_test, y_test_xgb)
# Out:
# Test_Set
# [[197   2  22]
#  [  5  33  81]
#  [ 14  11 641]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.89      0.90       221
#            1       0.72      0.28      0.40       119
#            2       0.86      0.96      0.91       666
#
#     accuracy                           0.87      1006
#    macro avg       0.83      0.71      0.74      1006
# weighted avg       0.86      0.87      0.85      1006
#
#
# Train_Set
# [[ 886    0    0]
#  [   0  474    0]
#  [   0    0 2662]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       886
#            1       1.00      1.00      1.00       474
#            2       1.00      1.00      1.00      2662
#
#     accuracy                           1.00      4022
#    macro avg       1.00      1.00      1.00      4022
# weighted avg       1.00      1.00      1.00      4022

# %% [markdown]
# ### XGBoost Model GridsearchCV

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Other Evaluation Metrics for Multiclass Classification

# %% [markdown]
# - Evaluation metrics
# https://towardsdatascience.com/comprehensive-guide-on-multiclass-classification-metrics-af94cfb83fbd

# %%
from sklearn.metrics import matthews_corrcoef
matthews_corrcoef?
matthews_corrcoef(y_test, y_pred)
# Out:
# 0.7380728719663084

# %%
from sklearn.metrics import cohen_kappa_score
cohen_kappa_score?
cohen_kappa_score(y_test, y_pred)
# Out:
# 0.7376215262514891

# %% [markdown]
# ## Before the Deployment
# - Choose the model that works best based on your chosen metric
# - For final step, fit the best model with whole dataset to get better performance.
# - And your model ready to deploy, dump your model and scaler.

# %% [markdown]
# ---
# ---

# %% [markdown]
# # SMOTE
# https://machinelearningmastery.com/smote-oversampling-for-imbalanced-classification/

# %% [markdown]
# ##  Smote implement

# %%
# !pip install imblearn

# %%
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline

# %% [markdown]
# ## Logistic Regression Over/ Under Sampling

# %% [markdown]
# #  SHAP
# - http://archive.today/2024.02.04-155206/https://towardsdatascience.com/shapley-values-clearly-explained-a7f7ef22b104
# - https://towardsdatascience.com/shap-explain-any-machine-learning-model-in-python-24207127cad7

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
